# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [10, 7]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle
import h5py
import multiprocessing
import itertools
from multiprocessing import sharedctypes
import scipy
from PyAstronomy.pyasl import dopplerShift
from astroquery.sdss import SDSS
from astropy.coordinates import SkyCoord
import glob
import astropy.io.votable as votable
from PyAstronomy.pyasl import crosscorrRV, quadExtreme
# %matplotlib inline
import pwlf

# %%
table = Table.read('filetable.fits')

# %%
spec_files = glob.glob('ks_spec/*')
lamgrid = np.arange(4000,8000)

def planck(wl,c1,c2):
    return 1e21*c1 / (wl**5 * (np.exp(1e4*c2/wl) - 1 ))

def planck(wl, c1, c2):
    return c1*wl + c2

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

def get_raw_spectrum(source_id):
    path = table[table['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        raise OSError('Spectrum file missing...')
    
    return lam,flux#,fluxsig


def continuum_normalize(flux,lam,sigarray = None):
    spec = flux
    pixels = lam-4000
    continuum = (pixels > 2900) + (pixels < 2200)*(pixels > 1050) + (pixels < 650)*(pixels > 530) \
             + (pixels < 220)*(pixels > 200) + (pixels < 35)*(pixels > 20) + (pixels < -200)*(pixels > -450)
    
    notnan = (~np.isnan(spec))+(~np.isnan(lam))
    skylinemask = (lam > 5578.5 - 10)*(lam < 5578.5 + 10) \
        + (lam > 6301.7 - 10)*(lam < 6301.7 + 10) + (lam > 7246.0 - 10)*(lam < 7246.0 + 10)
        
    pwfunc = pwlf.PiecewiseLinFit(lam[continuum*notnan],spec[continuum*notnan])
    breakpoints = np.asarray([-350,-200,20,35,200,220,400,530,650,850,1050,\
                        1400,1800,2200,2500,2900,3200,3400,3600,3800]) + 4000
    breaks = pwfunc.fit_with_breaks(breakpoints)
    cont = pwfunc.predict(lam)
    contcorr = spec / cont
    contcorr[skylinemask] = 1
    where = np.isnan(contcorr)+(contcorr > 1.25) + (contcorr < 0)
    #contcorr[where] = 1
    if sigarray is not None:
        stdev = np.sqrt(1.0/sigarray)
        contsigarray = stdev / cont
        normivar = (1.0/contsigarray)**2
        return contcorr,normivar
    
#     plt.figure(figsize = (15,5))
#     plt.plot(lam[continuum*notnan],spec[continuum*notnan])
#     plt.plot(lam,cont)
#     plt.figure(figsize = (15,5))
#     plt.plot(contcorr)
#     plt.plot(continuum)
#     plt.figure(figsize = (15,5))
    return contcorr

def rv_corr(normflux,lam):
    alphaline = find_nearest(lam,halpha)
    betaline = find_nearest(lam,hbeta)
    gammaline = find_nearest(lam,hgamma)
    deltaline = find_nearest(lam,hdelta)
    cores = (lam == alphaline) + (lam == betaline) + (lam == gammaline) + (lam == deltaline)
    cores = cores.astype(int)
    xcorrs = crosscorrRV(lam,1-normflux,lam,cores, -100, 100, 5, 'doppler', skipedge = 25)
    corrs = xcorrs[1]
    rvs = xcorrs[0]
    try:
        specrv = quadExtreme(rvs,corrs, 'max', (10,10), fullOutput = True)[0]
    except:
        specrv = 0
    shift_flux,shift_lam = dopplerShift(lam,normflux,specrv, edgeHandling = 'fillValue', fillValue = 1)
    return shift_flux,shift_lam

def interpolate_flux(normflux,lam):
    func = interp1d(lam,normflux,kind='linear',assume_sorted = True, fill_value = 'extrapolate')
    interpflux = func(lamgrid)
    return interpflux

def get_spectrum(source_id):
    path = table[table['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        raise FileNotFoundError('Spectrum file missing...')
        return
    ## RV Correction and Interpolation
    
    #normalized_spectrum = continuum_normalize(flux,lam)
    #rv_corrected_flux,rv_corrected_lam = rv_corr(normalized_spectrum,lam)
    interpolated_flux = interpolate_flux(flux, lam)
    
    return interpolated_flux

# %%
filetable = table

# %%
np.array(np.unique(filetable['spectral_class']))
# Out:
# array([b'CV', b'DA', b'DA:', b'DAB', b'DABZ', b'DAH', b'DAO', b'DAZ',
#        b'DA_MS', b'DB', b'DBA', b'DBAH', b'DBAZ', b'DBH', b'DBZ',
#        b'DB_MS', b'DC', b'DC:', b'DC_MS', b'DO', b'DQ', b'DQ:', b'DQZ',
#        b'DZ', b'DZ:', b'DZA', b'DZAB', b'DZB', b'DZBA', b'DZH', b'GALAXY',
#        b'MWD', b'PG1159', b'Pec', b'QSO', b'STAR', b'UNKN', b'Unreliable',
#        b'WD', b'WDpec', b'hotDQ', b'pecDQ'], dtype='|S10')

# %% [markdown]
# # Find Candidates

# %%
DA = filetable['spectral_class'] == 'DAH'
filetable = filetable[DA]
len(filetable)
# Out:
# 129

# %%
spectra = [];
for jj in tqdm(range(len(filetable))):
    obj = filetable[jj]
    try:
        spec = get_spectrum(obj['source_id'])
        spectra.append(spec)
    except:
        spectra.append(np.repeat(np.nan,4000))
# Out:
# 100%|██████████| 129/129 [00:03<00:00, 38.62it/s]

# %%
spectra = np.asarray(spectra)

# %%
normspectra = np.asarray([continuum_normalize(spec,lamgrid) for spec in spectra])

# %%
ii = 0
for ii in range(24):
    print(ii)
    print(filetable[ii]['source_id'])
    plt.figure()
    plt.plot(lamgrid,normspectra[ii])
    plt.figure()
    line = 5600 - 4000
    width = 600

    plt.plot(lamgrid[(line-width):(line+width)],normspectra[ii][(line-width):(line+width)])


    plt.figure()
    line = 5190 - 4000
    width = 100

    plt.plot(lamgrid[(line-width):(line+width)],normspectra[ii][(line-width):(line+width)])

    plt.figure()
    line = 5900 - 4000
    width = 200

    plt.plot(lamgrid[(line-width):(line+width)],normspectra[ii][(line-width):(line+width)])
    plt.show()
    print('#'*50)
# Out:
# 0
# 76937810758080512
# ##################################################
# 1
# 239717998989931136
# ##################################################
# 2
# 580558842594128256
# ##################################################
# 3
# 611482156153802240
# ##################################################
# 4
# 621979502901486720
# ##################################################
# 5
# 657714730316051712
# ##################################################
# 6
# 664325543977630464
# ##################################################
# 7
# 667924932731149312
# ##################################################
# 8
# 668251556403678592
# ##################################################
# 9
# 675590693439332096
# ##################################################
# 10
# 677023086508876032
# ##################################################
# 11
# 677312666087549568
# ##################################################
# 12
# 703440468274308224
# ...

# %% [markdown]
# # Sodium Splits - DZ Stars

# %% [markdown]
# ### Candidate 1

# %%
spec = get_spectrum(2869685937875719040)
normspec = continuum_normalize(spec,lamgrid)
line = 5900 - 4000
width = 100
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [5891, 5843, 5943, 5, 1, 1, 14, .7, 1.4]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

delwn1 = (1/core - 1/split1)*1e8
delwn2 = (1/core - 1/split2)*1e8

delwn1,delwn2

Bg1 = np.abs(delwn1) / 4.6686e-5
Bg2 = np.abs(delwn2) / 4.6686e-5

Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])

print('The mean surface field has strength = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# The mean surface field has strength = 3.35 ± 0.07 MG

# %% [markdown]
# ### Candidate 2

# %%
spec = get_spectrum(306779618349361920)
normspec = continuum_normalize(spec,lamgrid)
line = 5900 - 4000
width = 100
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [5891, 5833, 5953, 5, 1, 1, 14, .7, 1.4]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

delwn1 = (1/core - 1/split1)*1e8
delwn2 = (1/core - 1/split2)*1e8

delwn1,delwn2

Bg1 = np.abs(delwn1) / 4.6686e-5
Bg2 = np.abs(delwn2) / 4.6686e-5

Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])

print('The mean surface field has strength = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# The mean surface field has strength = 3.39 ± 0.05 MG

# %% [markdown]
# ### Candidate 3

# %%
spec = get_spectrum(1390317541196495104)
normspec = continuum_normalize(spec,lamgrid)
line = 5900 - 4000
width = 200
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [5891, 5733, 6053, 5, 1, 1, 14, .7, 1.4]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

delwn1 = (1/core - 1/split1)*1e8
delwn2 = (1/core - 1/split2)*1e8

delwn1,delwn2

Bg1 = np.abs(delwn1) / 4.6686e-5
Bg2 = np.abs(delwn2) / 4.6686e-5


Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])

print('The mean surface field has strength = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# The mean surface field has strength = 9.56 ± 0.31 MG

# %% [markdown]
# ### Candidate 4

# %%
spec = get_spectrum(1886301464050926720)
normspec = continuum_normalize(spec,lamgrid)
line = 5900 - 4000
width = 100
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [5891, 5853, 5925, 5, 5, 5, 14, 5, 5]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

delwn1 = (1/core - 1/split1)*1e8
delwn2 = (1/core - 1/split2)*1e8

delwn1,delwn2

Bg1 = np.abs(delwn1) / 4.6686e-5
Bg2 = np.abs(delwn2) / 4.6686e-5

Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])

print('The mean surface field has strength = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# The mean surface field has strength = 2.43 ± 0.01 MG

# %% [markdown]
# ## Balmer Splits - DAH Stars

# %% [markdown]
# ### Candidate 1

# %% [markdown]
# #### H-Beta Line

# %%
spec = get_spectrum(239717998989931136)
normspec = continuum_normalize(spec,lamgrid)

line = int(hbeta) - 4000
width = 400
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [4850, 4770, 4916, 45, 13, 13, 45, 13, 13]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

def B(deltalam, lam0, n1, n2, m):
    denom = 4.98e-23 * lam0**2 * (n1**4 - n2**4) * (1 + m**2)
    return np.sqrt(np.abs(deltalam)/denom)

Bg1 = B(del1, hbeta, 4, 2, 1)
Bg2 = B(del2, hbeta, 4, 2, -1)
Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])


print('mean surface field B = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# mean surface field B = 10.87 ± 0.57 MG

# %% [markdown]
# #### H-Alpha Line

# %%
spec = get_spectrum(239717998989931136)
normspec = continuum_normalize(spec,lamgrid)

line = int(halpha) - 4000
width = 400
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [6563, 6440, 6690, 45, 13, 13, 45, 8, 8]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

def B(deltalam, lam0, n1, n2, m):
    denom = 4.98e-23 * lam0**2 * (n1**4 - n2**4) * (1 + m**2)
    return np.sqrt(np.abs(deltalam)/denom)

Bg1 = B(del1, halpha, 4, 2, 1)
Bg2 = B(del2, halpha, 4, 2, -1)
Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])

print('mean surface field B = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# mean surface field B = 10.54 ± 0.08 MG

# %% [markdown]
# ### Candidate 2

# %% [markdown]
# #### H-Beta Line

# %%
spec = get_spectrum(677312666087549568)
normspec = continuum_normalize(spec,lamgrid)

line = int(hbeta) - 4000
width = 400
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [4850, 4760, 4936, 45, 23, 23, 45, 13, 13]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

def B(deltalam, lam0, n1, n2, m):
    denom = 4.98e-23 * lam0**2 * (n1**4 - n2**4) * (1 + m**2)
    return np.sqrt(np.abs(deltalam)/denom)

Bg1 = B(del1, hbeta, 4, 2, 1)
Bg2 = B(del2, hbeta, 4, 2, -1)
Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])


print('mean surface field B = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# mean surface field B = 11.69 ± 0.31 MG

# %% [markdown]
# #### H-Alpha Line

# %%
line = int(halpha) - 4000
width = 400
lam = lamgrid[(line-width):(line+width)]
flux = normspec[(line-width):(line+width)]

def three_norm(x, *args):
    m1, m2, m3, s1, s2, s3, k1, k2, k3 = args
    ret = k1*scipy.stats.norm.pdf(x, loc=m1 ,scale=s1)
    ret += k2*scipy.stats.norm.pdf(x, loc=m2 ,scale=s2)
    ret += k3*scipy.stats.norm.pdf(x, loc=m3 ,scale=s3)
    return 1-ret

params = [6563, 6420, 6710, 45, 13, 13, 45, 13, 13]

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*params),'r')

# %%
fitted_params,_ = scipy.optimize.curve_fit(three_norm,lam, flux, p0=params)

plt.plot(lam,flux,'k')
plt.plot(lam,three_norm(lam,*fitted_params),'r')

# %%
core = fitted_params[0]
split1 = fitted_params[1]
split2 = fitted_params[2]
del1 = core - split1
del2 = core - split2

def B(deltalam, lam0, n1, n2, m):
    denom = 4.98e-23 * lam0**2 * (n1**4 - n2**4) * (1 + m**2)
    return np.sqrt(np.abs(deltalam)/denom)

Bg1 = B(del1, halpha, 4, 2, 1)
Bg2 = B(del2, halpha, 4, 2, -1)
Bg = np.mean([Bg1,Bg2])
err = np.std([Bg1,Bg2])


print('mean surface field B = %.2f ± %.2f MG'%(Bg/1e6, err/1e6))
# Out:
# mean surface field B = 11.74 ± 0.12 MG
