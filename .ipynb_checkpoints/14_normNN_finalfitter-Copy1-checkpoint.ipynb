# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle
import h5py
import multiprocessing
import itertools
from multiprocessing import sharedctypes
import scipy
from PyAstronomy.pyasl import dopplerShift

# %%
def get_spectrum(source_id):
    path = wdtable[wdtable['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        print('Spectrum file missing...')
        return
    return lam,flux,fluxsig

def adapted_ch_cont(array,continuum,sigarray = None):
    spec = array
    notnan = ~np.isnan(spec)
    p = np.polynomial.chebyshev.chebfit(lamgrid[continuum*notnan],spec[continuum*notnan],10)
    cont = np.polynomial.chebyshev.chebval(lamgrid,p)
    contcorr = spec / cont
    if sigarray is not None:
        stdev = np.sqrt(1.0/sigarray)
        contsigarray = stdev / cont
        normivar = (1.0/contsigarray)**2
        return contcorr,normivar
    return contcorr

def norm_dataspec(array,sigarray=None):
    contcorr,contsig = adapted_ch_cont(array,continuum,sigarray)
    skylinemask = (lamgrid > 5578.5 - 10)*(lamgrid < 5578.5 + 10) + (lamgrid > 5894.6 - 10)*(lamgrid < 5894.6 + 10)\
        + (lamgrid > 6301.7 - 10)*(lamgrid < 6301.7 + 10) + (lamgrid > 7246.0 - 10)*(lamgrid < 7246.0 + 10)
    contcorr[skylinemask] = 1
    #where = np.isnan(contcorr)+(contcorr > 1.25) + (contcorr < 0)
    #contcorr[where] = 1
    return contcorr,contsig

# %% [markdown]
# ## Model

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler
import multiprocessing

# %%
sc = MinMaxScaler()
msc = StandardScaler()

# %%
## Load Model Spectra

searchparameter = '_'

prefilenames = os.listdir('koester2/')
filenames = []
for i in range(len(prefilenames)):
    if searchparameter in prefilenames[i]:
        filenames.append(prefilenames[i])
        
len(filenames)

modelspectra = [];
modelwl = [];
loggs = [];
teffs = [];
for i in (filenames):
    specname=i
    f = open('koester2/'+specname)
    data = f.readlines()
    f.close()
    headerdata = data[0:7]
    spectraldata = data[6:]
    lam = []
    flux = []

    for i in range(len(spectraldata)):
        l=float(spectraldata[i].split()[0])
        lam.append(l)
        f = float(spectraldata[i].split()[1])
        flux.append(f)

    lam = np.asarray(lam)
    flux = np.asarray(flux) / 1e7

    teff = float(headerdata[1].split()[3])
    logg = float(headerdata[2].split()[3])
    
    in1 = find_nearest(lam,4000)
    in2 = find_nearest(lam,8000)

    flux = flux[in1:in2]
    lam = lam[in1:in2]
    
    flux = flux[:-1][~ (np.diff(lam) == 0)]
    lam = lam[:-1][~ (np.diff(lam) == 0)]
    
    lamgrid = np.arange(4000,8000)
    
    func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
    flux = func(lamgrid)
    
    modelspectra.append(flux)
    modelwl.append(lam)
    teffs.append(teff)
    loggs.append(logg)

modelspectra = np.asarray(modelspectra)
loggs = np.asarray(loggs)
teffs = np.asarray(teffs)

# %%
pixels = np.arange(0,4000)
continuum = (pixels > 2900) + (pixels < 2200)*(pixels > 1200) + (pixels < 650)*(pixels > 530) \
            + (pixels < 35)*(pixels > 20) + (pixels < 220)*(pixels > 200)

norm_modelspectra = [adapted_ch_cont(i,continuum) for i in modelspectra]
norm_modelspectra = np.asarray(norm_modelspectra)

# %%
plt.plot(norm_modelspectra[2:20].T);

# %%
X = np.stack((teffs,loggs)).T
t = norm_modelspectra

X_scaled = sc.fit_transform(X)
t_scaled = msc.fit_transform(t)

# %%
def vloss(ypred,ytrue):
    resid = ypred-ytrue
    return K.mean(K.exp(resid**2))

# %%
H = 10
reg = 0.0001
def generator():
    x = Input(shape=(2,))
    y = Dense(H,activation='sigmoid',trainable = True)(x)
    y = Dense(H,activation='sigmoid',trainable = True)(y)
    y = Dense(H,activation='sigmoid',trainable = True)(y)
    y = Dense(H,activation='sigmoid',trainable = True)(y)
    out = Dense(4000,activation='linear',trainable = True)(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adamax(), loss = 'mse', \
                  metrics = ['mae'])
    return model
model = generator()
history = [];
#model.load_weights('normNN.h5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_81 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_82 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_84 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_85 (Dense)             (None, 4000)              44000
# =================================================================
# Total params: 44,360
# Trainable params: 44,360
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
for i in tqdm(range(250)): 
    print('Training meta-batch %i'%i)
    
    n_epochs = 10000
    batch = 1040
    
    
    h = model.fit(X_scaled,t_scaled, epochs = n_epochs, verbose = 1, batch_size = batch, shuffle = True)
    history = np.append(history, h.history['loss'])
    model.save_weights('normNN.h5')
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Training meta-batch 0
# Epoch 1/10000
# 1040/1040 [==============================] - 1s 648us/step - loss: 1.0009 - mean_absolute_error: 0.8033
# Epoch 2/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0007 - mean_absolute_error: 0.8032
# Epoch 3/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0004 - mean_absolute_error: 0.8031
# Epoch 4/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0002 - mean_absolute_error: 0.8030
# Epoch 5/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 6/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 7/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 8/10000
# 1040/1040 [==============================] - 0s 72us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 9/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 10/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 11/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 12/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 1.0001 - mean_absolute_error: 0.8030
# Epoch 13/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 14/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 15/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 16/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 17/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 18/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 19/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 20/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 21/10000
# 1040/1040 [==============================] - 0s 72us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 22/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 23/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 24/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 25/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 26/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 27/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 28/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 29/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 30/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 31/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 32/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 33/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 34/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 35/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 36/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 37/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 38/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 39/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 40/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 41/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 42/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 43/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 44/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 45/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 46/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 47/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 48/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 49/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 50/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 51/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 52/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 53/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 54/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 55/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 1.0000 - mean_absolute_error: 0.8030
# Epoch 56/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 57/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 58/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 59/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 60/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 61/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 62/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 63/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9999 - mean_absolute_error: 0.8030
# Epoch 64/10000
# 1040/1040 [==============================] - 0s 72us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 65/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 66/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 67/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 68/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 69/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 70/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 71/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 72/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 73/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 74/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 75/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 76/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 77/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9999 - mean_absolute_error: 0.8029
# Epoch 78/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 79/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 80/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 81/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 82/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 83/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 84/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 85/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 86/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 87/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 88/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9998 - mean_absolute_error: 0.8029
# Epoch 89/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9997 - mean_absolute_error: 0.8029
# Epoch 90/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9997 - mean_absolute_error: 0.8029
# Epoch 91/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9997 - mean_absolute_error: 0.8029
# Epoch 92/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9997 - mean_absolute_error: 0.8029
# Epoch 93/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9997 - mean_absolute_error: 0.8028
# Epoch 94/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9997 - mean_absolute_error: 0.8028
# Epoch 95/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9997 - mean_absolute_error: 0.8028
# Epoch 96/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9996 - mean_absolute_error: 0.8028
# Epoch 97/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9996 - mean_absolute_error: 0.8028
# Epoch 98/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9996 - mean_absolute_error: 0.8028
# Epoch 99/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9996 - mean_absolute_error: 0.8028
# Epoch 100/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.9996 - mean_absolute_error: 0.8028
# Epoch 101/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.9995 - mean_absolute_error: 0.8028
# Epoch 102/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9995 - mean_absolute_error: 0.8028
# Epoch 103/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9995 - mean_absolute_error: 0.8028
# Epoch 104/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9995 - mean_absolute_error: 0.8028
# Epoch 105/10000
# 1040/1040 [==============================] - 0s 76us/step - loss: 0.9995 - mean_absolute_error: 0.8027
# Epoch 106/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9994 - mean_absolute_error: 0.8027
# Epoch 107/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9994 - mean_absolute_error: 0.8027
# Epoch 108/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9994 - mean_absolute_error: 0.8027
# Epoch 109/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9993 - mean_absolute_error: 0.8027
# Epoch 110/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9993 - mean_absolute_error: 0.8027
# Epoch 111/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9993 - mean_absolute_error: 0.8027
# Epoch 112/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9993 - mean_absolute_error: 0.8026
# Epoch 113/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.9992 - mean_absolute_error: 0.8026
# Epoch 114/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9992 - mean_absolute_error: 0.8026
# Epoch 115/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9991 - mean_absolute_error: 0.8026
# Epoch 116/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9991 - mean_absolute_error: 0.8026
# Epoch 117/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9991 - mean_absolute_error: 0.8026
# Epoch 118/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9990 - mean_absolute_error: 0.8025
# Epoch 119/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9990 - mean_absolute_error: 0.8025
# Epoch 120/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9989 - mean_absolute_error: 0.8025
# Epoch 121/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9989 - mean_absolute_error: 0.8025
# Epoch 122/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9988 - mean_absolute_error: 0.8025
# Epoch 123/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.9988 - mean_absolute_error: 0.8025
# Epoch 124/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9987 - mean_absolute_error: 0.8024
# Epoch 125/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9987 - mean_absolute_error: 0.8024
# Epoch 126/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9986 - mean_absolute_error: 0.8024
# Epoch 127/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9986 - mean_absolute_error: 0.8024
# Epoch 128/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9985 - mean_absolute_error: 0.8023
# Epoch 129/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9984 - mean_absolute_error: 0.8023
# Epoch 130/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9984 - mean_absolute_error: 0.8023
# Epoch 131/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9983 - mean_absolute_error: 0.8022
# Epoch 132/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9982 - mean_absolute_error: 0.8022
# Epoch 133/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9982 - mean_absolute_error: 0.8022
# Epoch 134/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.9981 - mean_absolute_error: 0.8021
# Epoch 135/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9980 - mean_absolute_error: 0.8021
# Epoch 136/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9979 - mean_absolute_error: 0.8021
# Epoch 137/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9978 - mean_absolute_error: 0.8020
# Epoch 138/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9978 - mean_absolute_error: 0.8020
# Epoch 139/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9977 - mean_absolute_error: 0.8020
# Epoch 140/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9976 - mean_absolute_error: 0.8019
# Epoch 141/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9975 - mean_absolute_error: 0.8019
# Epoch 142/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9974 - mean_absolute_error: 0.8018
# Epoch 143/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.9973 - mean_absolute_error: 0.8018
# Epoch 144/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9972 - mean_absolute_error: 0.8018
# Epoch 145/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9970 - mean_absolute_error: 0.8017
# Epoch 146/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9969 - mean_absolute_error: 0.8016
# Epoch 147/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9968 - mean_absolute_error: 0.8016
# Epoch 148/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9967 - mean_absolute_error: 0.8015
# Epoch 149/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9966 - mean_absolute_error: 0.8015
# Epoch 150/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9964 - mean_absolute_error: 0.8014
# Epoch 151/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9963 - mean_absolute_error: 0.8013
# Epoch 152/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9961 - mean_absolute_error: 0.8013
# Epoch 153/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9960 - mean_absolute_error: 0.8012
# Epoch 154/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9958 - mean_absolute_error: 0.8011
# Epoch 155/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9957 - mean_absolute_error: 0.8011
# Epoch 156/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9955 - mean_absolute_error: 0.8010
# Epoch 157/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9953 - mean_absolute_error: 0.8010
# Epoch 158/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9952 - mean_absolute_error: 0.8009
# Epoch 159/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9950 - mean_absolute_error: 0.8008
# Epoch 160/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9948 - mean_absolute_error: 0.8008
# Epoch 161/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9946 - mean_absolute_error: 0.8007
# Epoch 162/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9944 - mean_absolute_error: 0.8006
# Epoch 163/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9942 - mean_absolute_error: 0.8005
# Epoch 164/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9940 - mean_absolute_error: 0.8005
# Epoch 165/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9938 - mean_absolute_error: 0.8004
# Epoch 166/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9936 - mean_absolute_error: 0.8003
# Epoch 167/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9933 - mean_absolute_error: 0.8002
# Epoch 168/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9931 - mean_absolute_error: 0.8000
# Epoch 169/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9928 - mean_absolute_error: 0.7999
# Epoch 170/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9926 - mean_absolute_error: 0.7997
# Epoch 171/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9923 - mean_absolute_error: 0.7996
# Epoch 172/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9921 - mean_absolute_error: 0.7994
# Epoch 173/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9918 - mean_absolute_error: 0.7993
# Epoch 174/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9915 - mean_absolute_error: 0.7991
# Epoch 175/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9912 - mean_absolute_error: 0.7990
# Epoch 176/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9909 - mean_absolute_error: 0.7988
# Epoch 177/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9906 - mean_absolute_error: 0.7987
# Epoch 178/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9903 - mean_absolute_error: 0.7985
# Epoch 179/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9899 - mean_absolute_error: 0.7984
# Epoch 180/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9896 - mean_absolute_error: 0.7983
# Epoch 181/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9892 - mean_absolute_error: 0.7982
# Epoch 182/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.9889 - mean_absolute_error: 0.7981
# Epoch 183/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9885 - mean_absolute_error: 0.7980
# Epoch 184/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9881 - mean_absolute_error: 0.7979
# Epoch 185/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9877 - mean_absolute_error: 0.7979
# Epoch 186/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9873 - mean_absolute_error: 0.7978
# Epoch 187/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9869 - mean_absolute_error: 0.7977
# Epoch 188/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9865 - mean_absolute_error: 0.7976
# Epoch 189/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9861 - mean_absolute_error: 0.7975
# Epoch 190/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9856 - mean_absolute_error: 0.7973
# Epoch 191/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9852 - mean_absolute_error: 0.7972
# Epoch 192/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9847 - mean_absolute_error: 0.7970
# Epoch 193/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9842 - mean_absolute_error: 0.7967
# Epoch 194/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9837 - mean_absolute_error: 0.7965
# Epoch 195/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9832 - mean_absolute_error: 0.7962
# Epoch 196/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9827 - mean_absolute_error: 0.7958
# Epoch 197/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9822 - mean_absolute_error: 0.7955
# Epoch 198/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9816 - mean_absolute_error: 0.7951
# Epoch 199/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9811 - mean_absolute_error: 0.7947
# Epoch 200/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9805 - mean_absolute_error: 0.7943
# Epoch 201/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9799 - mean_absolute_error: 0.7938
# Epoch 202/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9794 - mean_absolute_error: 0.7934
# Epoch 203/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9788 - mean_absolute_error: 0.7930
# Epoch 204/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9782 - mean_absolute_error: 0.7927
# Epoch 205/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.9775 - mean_absolute_error: 0.7923
# Epoch 206/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9769 - mean_absolute_error: 0.7920
# Epoch 207/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9762 - mean_absolute_error: 0.7918
# Epoch 208/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9755 - mean_absolute_error: 0.7915
# Epoch 209/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9748 - mean_absolute_error: 0.7913
# Epoch 210/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9741 - mean_absolute_error: 0.7912
# Epoch 211/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9734 - mean_absolute_error: 0.7910
# Epoch 212/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9726 - mean_absolute_error: 0.7909
# Epoch 213/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9719 - mean_absolute_error: 0.7908
# Epoch 214/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9711 - mean_absolute_error: 0.7906
# Epoch 215/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9703 - mean_absolute_error: 0.7905
# Epoch 216/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9695 - mean_absolute_error: 0.7904
# Epoch 217/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9687 - mean_absolute_error: 0.7902
# Epoch 218/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9679 - mean_absolute_error: 0.7900
# Epoch 219/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9670 - mean_absolute_error: 0.7897
# Epoch 220/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.9662 - mean_absolute_error: 0.7894
# Epoch 221/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.9653 - mean_absolute_error: 0.7891
# Epoch 222/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9644 - mean_absolute_error: 0.7887
# Epoch 223/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9634 - mean_absolute_error: 0.7882
# Epoch 224/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9625 - mean_absolute_error: 0.7877
# Epoch 225/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9615 - mean_absolute_error: 0.7871
# Epoch 226/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9604 - mean_absolute_error: 0.7865
# Epoch 227/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9594 - mean_absolute_error: 0.7858
# Epoch 228/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9584 - mean_absolute_error: 0.7851
# Epoch 229/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9573 - mean_absolute_error: 0.7844
# Epoch 230/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9562 - mean_absolute_error: 0.7837
# Epoch 231/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9552 - mean_absolute_error: 0.7829
# Epoch 232/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9541 - mean_absolute_error: 0.7822
# Epoch 233/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9530 - mean_absolute_error: 0.7815
# Epoch 234/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9518 - mean_absolute_error: 0.7808
# Epoch 235/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9507 - mean_absolute_error: 0.7801
# Epoch 236/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9495 - mean_absolute_error: 0.7795
# Epoch 237/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9483 - mean_absolute_error: 0.7789
# Epoch 238/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9471 - mean_absolute_error: 0.7784
# Epoch 239/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9458 - mean_absolute_error: 0.7779
# Epoch 240/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.9445 - mean_absolute_error: 0.7775
# Epoch 241/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9431 - mean_absolute_error: 0.7771
# Epoch 242/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9418 - mean_absolute_error: 0.7767
# Epoch 243/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.9404 - mean_absolute_error: 0.7763
# Epoch 244/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9390 - mean_absolute_error: 0.7760
# Epoch 245/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9376 - mean_absolute_error: 0.7757
# Epoch 246/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9362 - mean_absolute_error: 0.7753
# Epoch 247/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9348 - mean_absolute_error: 0.7749
# Epoch 248/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9334 - mean_absolute_error: 0.7745
# Epoch 249/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9319 - mean_absolute_error: 0.7741
# Epoch 250/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9305 - mean_absolute_error: 0.7736
# Epoch 251/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9290 - mean_absolute_error: 0.7730
# Epoch 252/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9275 - mean_absolute_error: 0.7724
# Epoch 253/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9259 - mean_absolute_error: 0.7717
# Epoch 254/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9243 - mean_absolute_error: 0.7709
# Epoch 255/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9226 - mean_absolute_error: 0.7700
# Epoch 256/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9210 - mean_absolute_error: 0.7690
# Epoch 257/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.9192 - mean_absolute_error: 0.7680
# Epoch 258/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.9175 - mean_absolute_error: 0.7670
# Epoch 259/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9157 - mean_absolute_error: 0.7659
# Epoch 260/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.9140 - mean_absolute_error: 0.7648
# Epoch 261/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.9122 - mean_absolute_error: 0.7637
# Epoch 262/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9104 - mean_absolute_error: 0.7626
# Epoch 263/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.9086 - mean_absolute_error: 0.7615
# Epoch 264/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9068 - mean_absolute_error: 0.7604
# Epoch 265/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.9049 - mean_absolute_error: 0.7594
# Epoch 266/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9031 - mean_absolute_error: 0.7584
# Epoch 267/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.9012 - mean_absolute_error: 0.7574
# Epoch 268/10000
# 1040/1040 [==============================] - 0s 73us/step - loss: 0.8992 - mean_absolute_error: 0.7565
# Epoch 269/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.8973 - mean_absolute_error: 0.7557
# Epoch 270/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.8952 - mean_absolute_error: 0.7549
# Epoch 271/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.8932 - mean_absolute_error: 0.7541
# Epoch 272/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8911 - mean_absolute_error: 0.7533
# Epoch 273/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8890 - mean_absolute_error: 0.7526
# Epoch 274/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8868 - mean_absolute_error: 0.7519
# Epoch 275/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.8847 - mean_absolute_error: 0.7512
# Epoch 276/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8825 - mean_absolute_error: 0.7504
# Epoch 277/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8804 - mean_absolute_error: 0.7497
# Epoch 278/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8782 - mean_absolute_error: 0.7489
# Epoch 279/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.8761 - mean_absolute_error: 0.7480
# Epoch 280/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8739 - mean_absolute_error: 0.7471
# Epoch 281/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8717 - mean_absolute_error: 0.7461
# Epoch 282/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8694 - mean_absolute_error: 0.7450
# Epoch 283/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8671 - mean_absolute_error: 0.7438
# Epoch 284/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8648 - mean_absolute_error: 0.7425
# Epoch 285/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8624 - mean_absolute_error: 0.7411
# Epoch 286/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8600 - mean_absolute_error: 0.7397
# Epoch 287/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8576 - mean_absolute_error: 0.7382
# Epoch 288/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8551 - mean_absolute_error: 0.7367
# Epoch 289/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8527 - mean_absolute_error: 0.7353
# Epoch 290/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8502 - mean_absolute_error: 0.7338
# Epoch 291/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8478 - mean_absolute_error: 0.7324
# Epoch 292/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8453 - mean_absolute_error: 0.7310
# Epoch 293/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.8428 - mean_absolute_error: 0.7297
# Epoch 294/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.8403 - mean_absolute_error: 0.7284
# Epoch 295/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8377 - mean_absolute_error: 0.7271
# Epoch 296/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8352 - mean_absolute_error: 0.7259
# Epoch 297/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8326 - mean_absolute_error: 0.7248
# Epoch 298/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8299 - mean_absolute_error: 0.7236
# Epoch 299/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8273 - mean_absolute_error: 0.7225
# Epoch 300/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.8246 - mean_absolute_error: 0.7213
# Epoch 301/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.8219 - mean_absolute_error: 0.7201
# Epoch 302/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.8192 - mean_absolute_error: 0.7188
# Epoch 303/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8165 - mean_absolute_error: 0.7175
# Epoch 304/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.8138 - mean_absolute_error: 0.7161
# Epoch 305/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.8111 - mean_absolute_error: 0.7146
# Epoch 306/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.8083 - mean_absolute_error: 0.7131
# Epoch 307/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.8056 - mean_absolute_error: 0.7115
# Epoch 308/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.8028 - mean_absolute_error: 0.7098
# Epoch 309/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.8000 - mean_absolute_error: 0.7081
# Epoch 310/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7972 - mean_absolute_error: 0.7065
# Epoch 311/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7945 - mean_absolute_error: 0.7049
# Epoch 312/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.7917 - mean_absolute_error: 0.7033
# Epoch 313/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7889 - mean_absolute_error: 0.7017
# Epoch 314/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7861 - mean_absolute_error: 0.7002
# Epoch 315/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.7833 - mean_absolute_error: 0.6988
# Epoch 316/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.7805 - mean_absolute_error: 0.6974
# Epoch 317/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.7778 - mean_absolute_error: 0.6960
# Epoch 318/10000
# 1040/1040 [==============================] - 0s 77us/step - loss: 0.7750 - mean_absolute_error: 0.6945
# Epoch 319/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.7722 - mean_absolute_error: 0.6930
# Epoch 320/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.7695 - mean_absolute_error: 0.6915
# Epoch 321/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.7667 - mean_absolute_error: 0.6899
# Epoch 322/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.7640 - mean_absolute_error: 0.6883
# Epoch 323/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.7613 - mean_absolute_error: 0.6867
# Epoch 324/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7586 - mean_absolute_error: 0.6850
# Epoch 325/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.7560 - mean_absolute_error: 0.6834
# Epoch 326/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.7534 - mean_absolute_error: 0.6818
# Epoch 327/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7508 - mean_absolute_error: 0.6803
# Epoch 328/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.7482 - mean_absolute_error: 0.6788
# Epoch 329/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.7457 - mean_absolute_error: 0.6773
# Epoch 330/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7432 - mean_absolute_error: 0.6759
# Epoch 331/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7408 - mean_absolute_error: 0.6745
# Epoch 332/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.7384 - mean_absolute_error: 0.6732
# Epoch 333/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7361 - mean_absolute_error: 0.6718
# Epoch 334/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7338 - mean_absolute_error: 0.6705
# Epoch 335/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7315 - mean_absolute_error: 0.6691
# Epoch 336/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.7293 - mean_absolute_error: 0.6677
# Epoch 337/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7272 - mean_absolute_error: 0.6664
# Epoch 338/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.7251 - mean_absolute_error: 0.6651
# Epoch 339/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.7231 - mean_absolute_error: 0.6638
# Epoch 340/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7212 - mean_absolute_error: 0.6626
# Epoch 341/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.7193 - mean_absolute_error: 0.6615
# Epoch 342/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7174 - mean_absolute_error: 0.6604
# Epoch 343/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7157 - mean_absolute_error: 0.6594
# Epoch 344/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.7140 - mean_absolute_error: 0.6584
# Epoch 345/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.7123 - mean_absolute_error: 0.6574
# Epoch 346/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.7107 - mean_absolute_error: 0.6565
# Epoch 347/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7092 - mean_absolute_error: 0.6556
# Epoch 348/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7078 - mean_absolute_error: 0.6547
# Epoch 349/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.7064 - mean_absolute_error: 0.6539
# Epoch 350/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7051 - mean_absolute_error: 0.6531
# Epoch 351/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7038 - mean_absolute_error: 0.6524
# Epoch 352/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.7026 - mean_absolute_error: 0.6517
# Epoch 353/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7014 - mean_absolute_error: 0.6510
# Epoch 354/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.7003 - mean_absolute_error: 0.6504
# Epoch 355/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6993 - mean_absolute_error: 0.6499
# Epoch 356/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6983 - mean_absolute_error: 0.6493
# Epoch 357/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6973 - mean_absolute_error: 0.6489
# Epoch 358/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6965 - mean_absolute_error: 0.6484
# Epoch 359/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6956 - mean_absolute_error: 0.6480
# Epoch 360/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6948 - mean_absolute_error: 0.6476
# Epoch 361/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6941 - mean_absolute_error: 0.6472
# Epoch 362/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6933 - mean_absolute_error: 0.6469
# Epoch 363/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6927 - mean_absolute_error: 0.6466
# Epoch 364/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.6920 - mean_absolute_error: 0.6463
# Epoch 365/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.6914 - mean_absolute_error: 0.6460
# Epoch 366/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6909 - mean_absolute_error: 0.6458
# Epoch 367/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6903 - mean_absolute_error: 0.6456
# Epoch 368/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6898 - mean_absolute_error: 0.6454
# Epoch 369/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6893 - mean_absolute_error: 0.6452
# Epoch 370/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6889 - mean_absolute_error: 0.6451
# Epoch 371/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6884 - mean_absolute_error: 0.6449
# Epoch 372/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6880 - mean_absolute_error: 0.6448
# Epoch 373/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6876 - mean_absolute_error: 0.6447
# Epoch 374/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.6872 - mean_absolute_error: 0.6445
# Epoch 375/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6869 - mean_absolute_error: 0.6444
# Epoch 376/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.6865 - mean_absolute_error: 0.6444
# Epoch 377/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6862 - mean_absolute_error: 0.6443
# Epoch 378/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6859 - mean_absolute_error: 0.6442
# Epoch 379/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6856 - mean_absolute_error: 0.6441
# Epoch 380/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6853 - mean_absolute_error: 0.6441
# Epoch 381/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6850 - mean_absolute_error: 0.6440
# Epoch 382/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6848 - mean_absolute_error: 0.6439
# Epoch 383/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6845 - mean_absolute_error: 0.6439
# Epoch 384/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.6842 - mean_absolute_error: 0.6438
# Epoch 385/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6840 - mean_absolute_error: 0.6438
# Epoch 386/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6838 - mean_absolute_error: 0.6437
# Epoch 387/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6835 - mean_absolute_error: 0.6437
# Epoch 388/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6833 - mean_absolute_error: 0.6436
# Epoch 389/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.6831 - mean_absolute_error: 0.6436
# Epoch 390/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.6829 - mean_absolute_error: 0.6436
# Epoch 391/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6827 - mean_absolute_error: 0.6435
# Epoch 392/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.6825 - mean_absolute_error: 0.6435
# Epoch 393/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6823 - mean_absolute_error: 0.6434
# Epoch 394/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.6821 - mean_absolute_error: 0.6434
# Epoch 395/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6819 - mean_absolute_error: 0.6434
# Epoch 396/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.6818 - mean_absolute_error: 0.6433
# Epoch 397/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6816 - mean_absolute_error: 0.6433
# Epoch 398/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6814 - mean_absolute_error: 0.6433
# Epoch 399/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.6813 - mean_absolute_error: 0.6432
# Epoch 400/10000
# 1040/1040 [==============================] - 0s 63us/step - loss: 0.6811 - mean_absolute_error: 0.6432
# Epoch 401/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.6810 - mean_absolute_error: 0.6432
# Epoch 402/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.6808 - mean_absolute_error: 0.6431
# Epoch 403/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.6807 - mean_absolute_error: 0.6431
# Epoch 404/10000
# ...
# Epoch 5103/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0499 - mean_absolute_error: 0.1199
# Epoch 5104/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0499 - mean_absolute_error: 0.1199
# Epoch 5105/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1199
# Epoch 5106/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1199
# Epoch 5107/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5108/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5109/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5110/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5111/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5112/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5113/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5114/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1198
# Epoch 5115/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5116/10000
# 1040/1040 [==============================] - 0s 54us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5117/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5118/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5119/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5120/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5121/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5122/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5123/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1197
# Epoch 5124/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0498 - mean_absolute_error: 0.1196
# Epoch 5125/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0498 - mean_absolute_error: 0.1196
# Epoch 5126/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5127/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5128/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5129/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5130/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5131/10000
# 1040/1040 [==============================] - 0s 62us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5132/10000
# 1040/1040 [==============================] - 0s 48us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5133/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5134/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5135/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5136/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5137/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0497 - mean_absolute_error: 0.1196
# Epoch 5138/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5139/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5140/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5141/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5142/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.0497 - mean_absolute_error: 0.1194
# Epoch 5143/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5144/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1195
# Epoch 5145/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0497 - mean_absolute_error: 0.1194
# Epoch 5146/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0497 - mean_absolute_error: 0.1194
# Epoch 5147/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0497 - mean_absolute_error: 0.1194
# Epoch 5148/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0497 - mean_absolute_error: 0.1194
# Epoch 5149/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0496 - mean_absolute_error: 0.1194
# Epoch 5150/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1194
# Epoch 5151/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1194
# Epoch 5152/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5153/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5154/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5155/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5156/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5157/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5158/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5159/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5160/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5161/10000
# 1040/1040 [==============================] - 0s 54us/step - loss: 0.0496 - mean_absolute_error: 0.1193
# Epoch 5162/10000
# 1040/1040 [==============================] - 0s 54us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5163/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5164/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5165/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5166/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5167/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5168/10000
# 1040/1040 [==============================] - 0s 54us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5169/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5170/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5171/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0496 - mean_absolute_error: 0.1192
# Epoch 5172/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0496 - mean_absolute_error: 0.1191
# Epoch 5173/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0496 - mean_absolute_error: 0.1191
# Epoch 5174/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5175/10000
# 1040/1040 [==============================] - 0s 54us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5176/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5177/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5178/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5179/10000
# 1040/1040 [==============================] - 0s 59us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5180/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5181/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1191
# Epoch 5182/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5183/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5184/10000
# 1040/1040 [==============================] - 0s 60us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5185/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5186/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5187/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5188/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5189/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5190/10000
# 1040/1040 [==============================] - 0s 55us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5191/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5192/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0495 - mean_absolute_error: 0.1190
# Epoch 5193/10000
# 1040/1040 [==============================] - 0s 58us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5194/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5195/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5196/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5197/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5198/10000
# 1040/1040 [==============================] - 0s 56us/step - loss: 0.0495 - mean_absolute_error: 0.1189
# Epoch 5199/10000
# 1040/1040 [==============================] - 0s 57us/step - loss: 0.0494 - mean_absolute_error: 0.1189
# Epoch 5200/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.0494 - mean_absolute_error: 0.1189
# Epoch 5201/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0494 - mean_absolute_error: 0.1189
# Epoch 5202/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0494 - mean_absolute_error: 0.1189
# Epoch 5203/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5204/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5205/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5206/10000
# 1040/1040 [==============================] - 0s 65us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5207/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5208/10000
# 1040/1040 [==============================] - 0s 61us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5209/10000
# 1040/1040 [==============================] - 0s 72us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5210/10000
# 1040/1040 [==============================] - 0s 74us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5211/10000
# 1040/1040 [==============================] - 0s 76us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5212/10000
# 1040/1040 [==============================] - 0s 78us/step - loss: 0.0494 - mean_absolute_error: 0.1188
# Epoch 5213/10000
# 1040/1040 [==============================] - 0s 81us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5214/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5215/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5216/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5217/10000
# 1040/1040 [==============================] - 0s 69us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5218/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5219/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5220/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5221/10000
# 1040/1040 [==============================] - 0s 71us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5222/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.0494 - mean_absolute_error: 0.1187
# Epoch 5223/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5224/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5225/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5226/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5227/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5228/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5229/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5230/10000
# 1040/1040 [==============================] - 0s 64us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5231/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5232/10000
# 1040/1040 [==============================] - 0s 70us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5233/10000
# 1040/1040 [==============================] - 0s 67us/step - loss: 0.0493 - mean_absolute_error: 0.1186
# Epoch 5234/10000
# 1040/1040 [==============================] - 0s 68us/step - loss: 0.0493 - mean_absolute_error: 0.1185
# Epoch 5235/10000
# 1040/1040 [==============================] - 0s 66us/step - loss: 0.0493 - mean_absolute_error: 0.1185

# %%
plt.plot(history)

# %%
plt.figure(figsize=(10,13))

plt.subplot(211)
ts = np.linspace(8000,25000,5)
ls = np.linspace(8,8,5)
plt.rcParams.update({'font.size': 22})             
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = msc.inverse_transform(model.predict(samples))
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(lamgrid[720:1000],adapted_ch_cont(gens[i],continuum)[720:1000],label='$T_{eff} = %i$ K'%ts[i])
plt.legend(fontsize=17)
plt.ylabel('Normalized Flux')
plt.xlabel('Wavelength ($\AA$)')

plt.subplot(212)
ts = np.linspace(25000,25000,5)
ls = np.linspace(7,9,5)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = msc.inverse_transform(model.predict(samples))
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(lamgrid[720:1000],adapted_ch_cont(gens[i],continuum)[720:1000],label='$Logg = %.2f$ dex'%ls[i])
plt.legend(fontsize=17)
plt.ylabel('Normalized Flux')
plt.xlabel('Wavelength ($\AA$)')
# Out:
# Text(0.5, 0, 'Wavelength ($\\AA$)')

# %%
pixel = int(hbeta)-4000+352

temp = 14000


ts = teffs[teffs == temp]
ls = loggs[teffs == temp]
labels = np.stack((ts,ls)).T
tflux = np.exp(t)[teffs == temp][:,pixel]

plt.scatter(ls,tflux,color='k')

linls = np.linspace(min(ls),max(ls),100)
lints = np.repeat(temp,100)
linlabels = np.stack((lints,linls)).T
lintflux = np.exp(msc.inverse_transform(model.predict(sc.transform(linlabels))))[:,pixel]
plt.plot(linls,lintflux)

# %% [markdown]
# ## SDSS Data

# %%
filetable = Table.read('filetable.fits')
wdtable = Table.read('tremblay_final.fits')
print(len(wdtable))
wdtable = join(filetable,wdtable,keys = ['source_id','Teff','log_g','spectral_class','S/N'])

DA = (wdtable['spectral_class'] == 'DA')*(~np.isnan(wdtable['Teff']))*(~np.isnan(wdtable['log_g']))*\
        (wdtable['S/N'] > 55)*(wdtable['spec_Teff'] < 80000)
wdtable = wdtable[DA]
print(len(wdtable))
wdtable = wdtable[np.random.randint(0,len(wdtable),len(wdtable))]
# Out:
# 5396
# 105

# %%
plt.scatter(wdtable['spec_Teff'],wdtable['spec_logg'], s = 5, c = wdtable['S/N'], vmax = 100, cmap = 'rainbow')

# %%
interpfluxs = [];
sigs = [];
lamgrid = np.arange(4000,8000)
for i in tqdm(range(len(wdtable))):
    spec = get_spectrum(wdtable['source_id'][i])
    lam  = spec[0]
    flux = spec[1]
    sig = spec[2]
    func2 = interp1d(lam,sig,kind='linear',assume_sorted = False,fill_value='extrapolate')
    interpsig = func2(lamgrid)
    #trans = ((wdtable['center_b'][i] - hbeta)+(wdtable['center_a'][i]-halpha))/2
    #shiftedflux = interpolation.shift(flux,-trans,cval=np.nan)
    func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
    interpflux = func(lamgrid)
    interpfluxs.append(interpflux)
    sigs.append(interpsig)
# Out:
#   0%|          | 0/105 [00:00<?, ?it/s]
#   2%|▏         | 2/105 [00:00<00:08, 12.01it/s]
#   4%|▍         | 4/105 [00:00<00:08, 12.36it/s]
#   6%|▌         | 6/105 [00:00<00:07, 12.59it/s]
#   8%|▊         | 8/105 [00:00<00:07, 12.66it/s]
#  10%|▉         | 10/105 [00:00<00:07, 12.64it/s]
#  11%|█▏        | 12/105 [00:00<00:07, 12.85it/s]
#  13%|█▎        | 14/105 [00:01<00:07, 12.91it/s]
#  15%|█▌        | 16/105 [00:01<00:06, 12.78it/s]
#  17%|█▋        | 18/105 [00:01<00:06, 12.87it/s]
#  19%|█▉        | 20/105 [00:01<00:06, 12.75it/s]
#  21%|██        | 22/105 [00:01<00:06, 12.90it/s]
#  23%|██▎       | 24/105 [00:01<00:06, 12.63it/s]
#  25%|██▍       | 26/105 [00:02<00:06, 12.31it/s]
#  27%|██▋       | 28/105 [00:02<00:06, 12.50it/s]
#  29%|██▊       | 30/105 [00:02<00:06, 12.50it/s]
#  30%|███       | 32/105 [00:02<00:05, 12.34it/s]
#  32%|███▏      | 34/105 [00:02<00:05, 12.23it/s]
#  34%|███▍      | 36/105 [00:02<00:05, 12.55it/s]
#  36%|███▌      | 38/105 [00:03<00:05, 12.43it/s]
#  38%|███▊      | 40/105 [00:03<00:05, 11.97it/s]
#  40%|████      | 42/105 [00:03<00:05, 11.47it/s]
#  42%|████▏     | 44/105 [00:03<00:05, 12.06it/s]
#  44%|████▍     | 46/105 [00:03<00:04, 12.00it/s]
#  46%|████▌     | 48/105 [00:03<00:04, 12.09it/s]
#  48%|████▊     | 50/105 [00:04<00:04, 12.16it/s]
#  50%|████▉     | 52/105 [00:04<00:04, 12.57it/s]
#  51%|█████▏    | 54/105 [00:04<00:03, 12.84it/s]
#  53%|█████▎    | 56/105 [00:04<00:03, 12.53it/s]
#  55%|█████▌    | 58/105 [00:04<00:03, 12.88it/s]
#  57%|█████▋    | 60/105 [00:04<00:03, 13.11it/s]
#  59%|█████▉    | 62/105 [00:04<00:03, 13.01it/s]
#  61%|██████    | 64/105 [00:05<00:03, 12.98it/s]
#  63%|██████▎   | 66/105 [00:05<00:03, 12.48it/s]
#  65%|██████▍   | 68/105 [00:05<00:02, 12.54it/s]
#  67%|██████▋   | 70/105 [00:05<00:03,  8.82it/s]
#  69%|██████▊   | 72/105 [00:05<00:03,  9.62it/s]
#  70%|███████   | 74/105 [00:06<00:02, 10.34it/s]
#  72%|███████▏  | 76/105 [00:06<00:02, 11.06it/s]
#  74%|███████▍  | 78/105 [00:06<00:02, 11.43it/s]
#  76%|███████▌  | 80/105 [00:06<00:02, 11.62it/s]
#  78%|███████▊  | 82/105 [00:06<00:01, 11.81it/s]
#  80%|████████  | 84/105 [00:06<00:01, 12.06it/s]
#  82%|████████▏ | 86/105 [00:07<00:01, 12.53it/s]
#  84%|████████▍ | 88/105 [00:07<00:01, 12.88it/s]
#  86%|████████▌ | 90/105 [00:07<00:01, 12.33it/s]
#  88%|████████▊ | 92/105 [00:07<00:01, 12.45it/s]
#  90%|████████▉ | 94/105 [00:07<00:00, 12.59it/s]
#  91%|█████████▏| 96/105 [00:07<00:00, 12.60it/s]
#  93%|█████████▎| 98/105 [00:08<00:00, 12.67it/s]
#  95%|█████████▌| 100/105 [00:08<00:00, 12.71it/s]
#  97%|█████████▋| 102/105 [00:08<00:00, 12.99it/s]
#  99%|█████████▉| 104/105 [00:08<00:00, 12.87it/s]
# 100%|██████████| 105/105 [00:08<00:00, 12.26it/s]

# %%
spectra = np.asarray(interpfluxs)
sigs = np.asarray(sigs)
lamgrid = np.arange(4000,8000)

# %%
# %%time
plt.figure(figsize=(18,3))
plt.plot(adapted_ch_cont(spectra[24],continuum))
plt.plot(continuum)
# Out:
# CPU times: user 53.6 ms, sys: 2.64 ms, total: 56.3 ms
# Wall time: 15.7 ms

# %%
wdtable['spectrum'] = spectra
wdtable['ivar'] = sigs

# %%
clamgrid = np.linspace(4000,7000,3000)

# %%
norms = [norm_dataspec(np.asarray(wdtable['spectrum'][ii]),np.asarray(wdtable['ivar'][ii])) for ii in range(len(wdtable))]
wdtable['normspectrum'] = np.asarray(norms)[:,0]
wdtable['normivar'] = np.asarray(norms)[:,0]

# %% [markdown]
# # Fitting

# %%
lines = ((lamgrid > hbeta-200) & (lamgrid < hbeta + 300)) | ((lamgrid > halpha-250) & (lamgrid < halpha + 300))\
        | ((lamgrid > hgamma-120) & (lamgrid < hgamma + 400))| ((lamgrid > hdelta-90) & (lamgrid < hdelta + 150))
def spectrum_sampler(wl,teff,logg,trans):
    label = sc.transform(np.asarray(np.stack((teff,logg)).reshape(1,-1)))
    synth = dopplerShift(wl,np.ravel(
                        msc.inverse_transform(
                                model.predict(label))[0]
                        ), trans*1000
                    )[0]
    return (np.ravel(synth).astype('float64'))

def norm_spectrum_sampler(wl,teff,logg,trans):
    synth = spectrum_sampler(lamgrid,teff,logg,trans)
    return synth[lines]

def chisquare(residual):
    return sum(residual**2)

def get_prior_teff(array):
    spec = np.asarray(array)
    priorfitter = lmfit.Model(spectrum_sampler)
    priorparams = priorfitter.make_params()
    priorparams['logg'].set(value = 8., vary = False)
    priorparams['teff'].set(value = 10000,min = 5500, max = 80000)
    priorparams['trans'].set(value = 0., vary = False)
    priorfitter.eval(priorparams, wl = lamgrid)
    prior_result = priorfitter.fit(spec, priorparams, wl = lamgrid, method = 'Powell', nan_policy = 'omit');
    #print(prior_result.fit_report())
    return prior_result.params['teff'].value

def get_posteriors(array, n_eval = 3000):
    spec = array
    normspec = adapted_ch_cont(spec,continuum)
    def chisq(params):
        teff,logg,trans = params
        res = normspec[lines] - norm_spectrum_sampler(lamgrid,teff,logg,trans)
        res = res[~np.isnan(res)]
        chisq = np.sum(res**2)
        return chisq
    teff_init = get_prior_teff(spec)
   # p = scipy.optimize.minimize(chisq, bounds = [(5500,80000),(6.5,9.5),(-3,3)], x0 = [teff_init, 8., 0],\
                             #  method = 'dual_annealing')
    p = scipy.optimize.dual_annealing(chisq,bounds = [(5500,80000),(6.5,9.5),(-3,3)],maxfun = n_eval,\
                                      x0 = [teff_init, 8., 0])
    #p = scipy.optimize.differential_evolution(chisq,bounds = [(5500,80000),(6.5,9.5),(-3,3)],\
       #                              disp = True)
    
#     plt.plot(normspec[lines])
#     plt.plot(norm_spectrum_sampler(lamgrid,p.x[0],p.x[1],p.x[2]))
    return p.x

# %% [markdown]
# #### Evaluate NFev

# %% [raw]
# evals = [50,100,250,500,750,1000,1500,2000,2500,3000,4000,5000];
#
# evals
#
# ps = [];
# for i in range(len(evals)):
#     p = get_posteriors(interpfluxs[124],evals[i])
#     ps.append(p)
#
# ps = np.asarray(ps)
#
# plt.plot(evals,ps[:,0])

# %% [markdown]
# ### Evaluate on Synthetics

# %% [raw]
# searchparameter = '_'
#
# prefilenames = os.listdir('koester2/')
# filenames = []
# for i in range(len(prefilenames)):
#     if searchparameter in prefilenames[i]:
#         filenames.append(prefilenames[i])
#
# len(filenames)

# %% [raw]
# modelspectra = [];
# modelwl = [];
# loggs = [];
# teffs = [];
# for i in (filenames):
#     specname=i
#     f = open('koester2/'+specname)
#     data = f.readlines()
#     f.close()
#     headerdata = data[0:7]
#     spectraldata = data[6:]
#     lam = []
#     flux = []
#
#     for i in range(len(spectraldata)):
#         l=float(spectraldata[i].split()[0])
#         lam.append(l)
#         f = float(spectraldata[i].split()[1])
#         flux.append(f)
#
#     lam = np.asarray(lam)
#     flux = np.asarray(flux) / 1e7
#
#     teff = float(headerdata[1].split()[3])
#     logg = float(headerdata[2].split()[3])
#
#     in1 = find_nearest(lam,4000)
#     in2 = find_nearest(lam,8000)
#
#     flux = flux[in1:in2]
#     lam = lam[in1:in2]
#
#     flux = flux[:-1][~ (np.diff(lam) == 0)]
#     lam = lam[:-1][~ (np.diff(lam) == 0)]
#
#     lamgrid = np.arange(4000,8000)
#
#     func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
#     flux = func(lamgrid)
#
#     modelspectra.append(flux)
#     modelwl.append(lam)
#     teffs.append(teff)
#     loggs.append(logg)
#
# modelspectra = np.asarray(modelspectra)
# loggs = np.asarray(loggs)
# teffs = np.asarray(teffs)

# %% [markdown]
# ### Test on Model Spectra

# %% [raw]
# fitparams = [];
# for ii in tqdm(range(len(modelspectra[np.random.randint(0,1040,100)]))):
#     fitparams.append(get_posteriors(modelspectra[ii]))
# fitparams = np.asarray(fitparams)

# %% [raw]
# resid = teffs[0:len(fitparams)]-fitparams[:,0]
# mask = fitparams[:,0] < 25000
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(teffs[0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');
# plt.figure()
# resid = loggs[0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(loggs[0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# mask = (fitparams[:,0] > 10000)&(fitparams[:,0] < 50000)
# resid = teffs[0:len(fitparams)][mask]-fitparams[:,0][mask]
#
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(teffs[0:len(fitparams)][mask],fitparams[:,0][mask])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');
# plt.figure()
# resid = loggs[0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(loggs[0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [markdown]
# ### Fit SDSS

# %% [raw]
# fitparams = [];
# for ii in tqdm(range(len(wdtable))):
#     fitparams.append(get_posteriors(wdtable['spectrum'][ii]))
#
# fitparams = np.asarray(fitparams)

# %% [raw]
# fitparams = np.asarray(fitparams)

# %% [raw]
# resid = wdtable['Teff'][0:len(fitparams)]-fitparams[:,0]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['Teff'][0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['log_g'][0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['log_g'][0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['spec_Teff'][0:len(fitparams)]-fitparams[:,0]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['spec_Teff'][0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['spec_logg'][0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['spec_logg'][0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [markdown]
# ### MCMC Fitting

# %% [raw]
# results = [];
# for ii in tqdm(range(len(wdtable[0:25]))):
#     spec = interpfluxs[ii]
#     sig = sigs[ii]
#     normspec,normsig = norm_dataspec(spec,sig)
#     normspec = normspec[lines]
#     normsig = normsig[lines]
#     teff_prior = get_prior_teff(spec)
#     def lnlike(prms):
#         ivar = normsig
#         model = norm_spectrum_sampler(lamgrid,prms[0],prms[1],prms[2])
#         diff = model - normspec
#         diff = diff[~np.isnan(model)]
#         ivar = ivar[~np.isnan(model)]
#         chisq = np.sum(diff**2 * ivar)
#         lnlike = -0.5 * chisq
#     #     plt.plot(model)
#     #     plt.plot(normspec)
#         return lnlike
#
#     def lnprior(prms):
#         if prms[0] < 6000 or prms[0] > 80000:
#             return -np.Inf
#         elif prms[1] < 6.5 or prms[1] > 9.5:
#             return -np.Inf
#         elif prms[2] < -3 or prms[2] > 3:
#             return -np.Inf
#
#         mu = teff_prior
#         sigma = 5000
#         return 0#np.log(1.0/(np.sqrt(2*np.pi)*sigma))-0.5*(prms[0]-mu)**2/sigma**2
#
#     def lnprob(prms):
#         lp = lnprior(prms)
#         if not np.isfinite(lp):
#             return -np.Inf
#         return lp + lnlike(prms)
#
#
#     ndim,nwalkers = 3,50
#
#
#     steps = 250
#     burn = 25
#
#     nll = lambda *args: -lnlike(*args)
#
#
#     p = scipy.optimize.dual_annealing(nll,bounds = [(5500,80000),(6.5,9.5),(-3,3)],maxfun = 5000,\
#                                       x0 = [teff_prior, 8., 0])
#
#     param_disps = [0.01]*3
#     #p0 = np.asarray(get_posteriors(spec))
#     p0 = p.x
#     pos0 = np.zeros((nwalkers,ndim))
#     for jj in range(ndim):
#         pos0[:,jj] = ( p0[jj] + param_disps[jj]*p0[jj]*np.random.randn(nwalkers) )
#
#
#
#     sampler = emcee.EnsembleSampler(nwalkers,ndim,lnprob,threads = 1)
#     b = sampler.run_mcmc(pos0,burn)
#     sampler.reset()
#     s = sampler.run_mcmc(b[0],steps)
#     values = np.median(sampler.flatchain,0)
#     meanvalues = np.mean(sampler.flatchain,0)
#     modevalues = stats.mode(sampler.flatchain,0)[0]
#     mlevalues = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
#     lower = np.quantile(sampler.flatchain,.3173,axis=0)
#     upper = np.quantile(sampler.flatchain,.6827,axis=0)
#     std = np.std(sampler.flatchain,axis=0)
#
#     results.append([values, meanvalues, modevalues, mlevalues, lower, upper, std])
#
#     fig,axs = plt.subplots(2,2,figsize=(10,10))
#     f = corner.corner(sampler.flatchain[:,0:2],show_titles = True,smooth = 0,truths = (wdtable['spec_Teff'][ii],\
#             wdtable['spec_logg'][ii]),labels = ('$T_{eff}$','logg'),title_kwargs={'fontsize':18}, fig = fig)
#     plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_corner.png')
#
#     plt.figure(figsize = (15,5))
#     plt.title('Gaia '+str(wdtable[ii]['source_id']))
#     plt.plot(normspec,'k', label = 'Data Spectrum')
#     plt.plot(norm_spectrum_sampler(lamgrid,mlevalues[0],mlevalues[1],mlevalues[2]),'r',\
#              label = 'Fitted Synthetic',linewidth=2)
#     #plt.legend()
#     plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_fit.png')
#     #plt.close()
#     plt.show()

# %%
plt.hist(1e5*(wdtable['centre_beta']-hbeta)/hbeta, range = (-100,100), histtype = 'step', bins = 25);
plt.hist(1e5*(wdtable['centre_alpha']-halpha)/halpha, range = (-100,100), histtype = 'step', bins = 25);

# %%
plt.hist((1e5*(wdtable['centre_beta']-hbeta)/hbeta) - (1e5*(wdtable['centre_alpha']-halpha)/halpha), range = (-100,100));

# %%
50e-5 * hbeta
# Out:
# 2.43134

# %%
# %%timeit

norm_spectrum_sampler(lamgrid,15000,8.,0)
# Out:
# 1.56 ms ± 93.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit 

spectrum_sampler(lamgrid,15000,8.,0)
# Out:
# 901 µs ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit

msc.inverse_transform(model.predict(sc.transform(np.asarray([15000,8]).reshape(-1,1).T)))
# Out:
# 375 µs ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
results = [];
for ii in tqdm(range(len(wdtable[0:1]))):
    
    spec = wdtable['spectrum'][ii]
    sig = wdtable['ivar'][ii]
    normspec,normsig = norm_dataspec(spec,sig)
    normspec = normspec[lines]
    normsig = normsig[lines]
    teff_prior = get_prior_teff(spec)
    def lnlike(prms):
        ivar = normsig
        model = spectrum_sampler(lamgrid,prms[0],prms[1],prms[2])[lines]
        diff = model - normspec
        diff = diff[~np.isnan(model)]
        ivar = ivar[~np.isnan(model)]
        chisq = np.sum(diff**2 * ivar)
        lnlike = -0.5 * chisq
    #     plt.plot(model)
    #     plt.plot(normspec)
        return lnlike

    def lnprior(prms):
        if prms[0] < 6000 or prms[0] > 80000:
            return -np.Inf
        elif prms[1] < 6.5 or prms[1] > 9.5:
            return -np.Inf
        elif prms[2] < -3 or prms[2] > 3:
            return -np.Inf

        mu = teff_prior
        sigma = 5000
        return 0#np.log(1.0/(np.sqrt(2*np.pi)*sigma))-0.5*(prms[0]-mu)**2/sigma**2

    def lnprob(prms):
        lp = lnprior(prms)
        if not np.isfinite(lp):
            return -np.Inf
        return lp + lnlike(prms)


    ndim,nwalkers = 3,100


    steps = 100
    burn_step = 25
    total_burned = 0
    
    nll = lambda *args: -lnlike(*args)
    #p0 = np.asarray(get_posteriors(spec))
    #p0 = p.x
    pos0 = np.zeros((nwalkers,ndim))
    
    lows = [5500,6.5,-3]
    highs = [80000,9.5,3]
    
    for jj in range(ndim):
        pos0[:,jj] = ( np.random.uniform(lows[jj], highs[jj], nwalkers) )
        
        

    sampler = emcee.EnsembleSampler(nwalkers,ndim,lnprob,threads = 1)
    
    acorrtime = 1e5
    #Initialize sampler
    print('Finding MLE Point...')
    b = sampler.run_mcmc(pos0,100)
    print('Restarting MCMC around MLE...')
    
    plt.plot(sampler.chain[:,:,0].T, alpha = 0.3, color = 'k');
    plt.figure()
    plt.plot(sampler.chain[:,:,1].T, alpha = 0.3, color = 'k');
    plt.show()
    
    mlpt = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
    pos1 = np.zeros((nwalkers,ndim))
    
    for jj in range(ndim):
        pos1[:,jj] = (mlpt[jj] + 0.01 * mlpt[jj] * np.random.randn(nwalkers))
    
    b = sampler.run_mcmc(pos1,1) #Initialize
    
    while acorrtime > (0.25 * total_burned):
        print('Burning in %i samples... (%i done)'%(burn_step,total_burned))
        b = sampler.run_mcmc(b[0],burn_step)
        total_burned = total_burned + burn_step
        try:
            acorr_teff = emcee.autocorr.function(sampler.chain[0][:,0])
            acorrtime_teff = np.argmax(acorr_teff < (1/np.exp(1)))
            acorr_logg = emcee.autocorr.function(sampler.chain[0][:,1])
            acorrtime_logg = np.argmax(acorr_logg < (1/np.exp(1)))
            acorrtime = np.mean([acorrtime_teff, acorrtime_logg])
            print('Autocorr Time = %i samples.'%int(acorrtime))
        except :
            print('Chain too short.')
            continue;
            
        if (total_burned > 1000) and (acorrtime != 1e5):
            print('Maximum burn time reached.')
            break;
    
    print('Burn-in terminated with correlation fraction = %.2f'%(acorrtime/total_burned))
    
    n_draws = np.max([acorrtime, 100]) 
    print('Sampling %i draws from posterior'%n_draws)
    
    sampler.reset()
    s = sampler.run_mcmc(b[0],int(n_draws))
    values = np.median(sampler.flatchain,0)
    meanvalues = np.mean(sampler.flatchain,0)
    modevalues = stats.mode(sampler.flatchain,0)[0]
    mlevalues = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
    chi2 = -2*lnlike(mlevalues)
    lower = np.quantile(sampler.flatchain,.3173,axis=0)
    upper = np.quantile(sampler.flatchain,.6827,axis=0)
    std = np.std(sampler.flatchain,axis=0)
    
    results.append([values, meanvalues, modevalues, mlevalues, lower, upper, std, chi2])
    
    fig,axs = plt.subplots(2,2,figsize=(10,10))
    f = corner.corner(sampler.flatchain[:,0:2],show_titles = True,smooth = 0,truths = (mlevalues[0],\
            mlevalues[1]),labels = ('$T_{eff}$','$\log{g}$'),title_kwargs={'fontsize':18}, fig = fig)
    plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_corner.png')

    plt.figure(figsize = (15,5))
    plt.title('Gaia '+str(wdtable[ii]['source_id']))
    plt.plot(normspec,'k', label = 'Data Spectrum')
    plt.plot(norm_spectrum_sampler(lamgrid,mlevalues[0],mlevalues[1],mlevalues[2]),'r',\
             label = 'Fitted Synthetic',linewidth=2)
    #plt.legend()
    plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_fit.png')
    #plt.close()
    plt.show()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Finding MLE Point...
# Restarting MCMC around MLE...
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.13
# Sampling 100 draws from posterior
# 100%|██████████| 1/1 [00:42<00:00, 42.66s/it]

# %% [raw]
# plt.plot(sampler.chain[:,:,0].T, alpha = 0.3, color = 'k');

# %% [raw]
# ts = np.linspace(6000,60000,100)
# liks = [lnlike([i,8.42,0]) for i in ts]
# plt.plot(ts,np.exp(1e-3*np.asarray(liks)))

# %% [raw]
# ts = np.linspace(6000,60000,100)
# liks = [nll([i,8.42,0]) for i in ts]
# plt.plot(ts,np.asarray(liks))

# %%
results = np.asarray(results)
mles = results[:,3]
lowers = results[:,4]
uppers = results[:,5]
stds = results[:,6]
chi2s = results[:,7]/(4000 - 3)

# %% [markdown]
# ### Compare to Tremblay

# %%
plt.rcParams.update({'font.size': 22})

mlespec_Teff = [i[0] for i in mles]
lowspec_Teff = [i[0] for i in stds]
highspec_Teff = [i[0] for i in stds]
plt.figure(figsize=(15,5))
plt.subplot(121)
resid = wdtable['spec_Teff'][0:len(mles)]-mlespec_Teff
rms = np.sqrt(np.mean(resid**2))
f = plt.scatter(wdtable['spec_Teff'][0:len(mles)],mlespec_Teff, c = wdtable['log_g'][0:len(mles)])
plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');

# %%
mlespec_Teff = [i[0] for i in mles]
mask = np.asarray(mlespec_Teff) < 25000
resid = wdtable['spec_Teff'][0:len(mles)]-mlespec_Teff
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['spec_Teff'][0:len(mles)],mlespec_Teff, yerr = (lowspec_Teff,highspec_Teff), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Tremblay $T_{eff}$ (K)')
plt.ylabel('Fitted $T_{eff}$ (K)')
# Out:
# Text(0, 0.5, 'Fitted $T_{eff}$ (K)')

# %%
mlespec_Teff = [i[0] for i in mles]
mask = np.asarray(mlespec_Teff) < 25000
resid = wdtable['spec_Teff'][0:len(mles)][mask]-np.asarray(mlespec_Teff)[mask]
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['spec_Teff'][0:len(mles)][mask],np.asarray(mlespec_Teff)[mask], yerr = (np.asarray(lowspec_Teff)[mask],np.asarray(highspec_Teff)[mask]), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Tremblay $T_{eff}$ (K)')
plt.ylabel('Fitted $T_{eff}$ (K)')
rms
# Out:
# 823.8155335857884

# %%
mlespec_logg = [i[1] for i in mles]
lowspec_logg = [i[1] for i in stds]
highspec_logg = [i[1] for i in stds]
plt.figure(figsize=(15,5))
resid = wdtable['spec_logg'][0:len(mles)]-mlespec_logg
rms = np.sqrt(np.mean(resid**2))
plt.subplot(121)
f = plt.scatter(wdtable['spec_logg'][0:len(mles)],mlespec_logg, c = chi2s, cmap = 'cool')
plt.colorbar()
plt.text(0.4,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');
plt.tight_layout()

# %%
mlespec_logg = [i[1] for i in mles]
resid = wdtable['spec_logg'][0:len(mles)]-mlespec_logg
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['spec_logg'][0:len(mles)],mlespec_logg, yerr = (lowspec_logg,highspec_logg), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.xlabel('Tremblay $\log{g}$ (dex)')
plt.ylabel('Fitted $\log{g}$ (dex)')
# Out:
# Text(0, 0.5, 'Fitted $\\log{g}$ (dex)')

# %% [raw]
# pickle.dump(results,open('223wdfits.p','wb'))

# %%
results = pickle.load(open('223wdfits.p','rb'))

# %% [markdown]
# ### Compare to Fusilio

# %%
mleteff = [i[0] for i in mles]
lowteff = [i[0] for i in stds]
highteff = [i[0] for i in stds]
plt.figure(figsize=(15,5))
plt.subplot(121)
resid = wdtable['Teff'][0:len(mles)]-mleteff
rms = np.sqrt(np.mean(resid**2))
f = plt.scatter(wdtable['Teff'][0:len(mles)],mleteff, color = 'k')
plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');

# %%
mleteff = [i[0] for i in mles]
resid = wdtable['Teff'][0:len(mles)]-mleteff
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['Teff'][0:len(mles)],mleteff, yerr = (lowteff,highteff), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Gaia $T_{eff}$ (K)')
plt.ylabel('Fitted $T_{eff}$ (K)')
# Out:
# Text(0, 0.5, 'Fitted $T_{eff}$ (K)')

# %%
mlelog_g = [i[1] for i in mles]
lowlog_g = [i[1] for i in stds]
highlog_g = [i[1] for i in stds]
plt.figure(figsize=(15,5))
resid = wdtable['log_g'][0:len(mles)]-mlelog_g
rms = np.sqrt(np.mean(resid**2))
plt.subplot(121)
f = plt.scatter(wdtable['log_g'][0:len(mles)],mlelog_g)
plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');
plt.tight_layout()

# %%
mlelog_g = [i[1] for i in mles]
resid = wdtable['log_g'][0:len(mles)]-mlelog_g
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['log_g'][0:len(mles)],mlelog_g, yerr = (lowlog_g,highlog_g), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.xlabel('Gaia $\log{g}$ (dex)')
plt.ylabel('Fitted $\log{g}$ (dex)')
# Out:
# Text(0, 0.5, 'Fitted $\\log{g}$ (dex)')
