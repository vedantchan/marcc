# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle
import h5py
import multiprocessing
import itertools
from multiprocessing import sharedctypes
import scipy
from PyAstronomy.pyasl import dopplerShift

# %%
def get_spectrum(source_id):
    path = wdtable[wdtable['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        print('Spectrum file missing...')
        return
    return lam,flux,fluxsig

def adapted_ch_cont(array,continuum,sigarray = None):
    spec = array
    notnan = ~np.isnan(spec)
    p = np.polynomial.chebyshev.chebfit(lamgrid[continuum*notnan],spec[continuum*notnan],10)
    cont = np.polynomial.chebyshev.chebval(lamgrid,p)
    contcorr = spec / cont
    if sigarray is not None:
        stdev = np.sqrt(1.0/sigarray)
        contsigarray = stdev / cont
        normivar = (1.0/contsigarray)**2
        return contcorr,normivar
    return contcorr

def norm_dataspec(array,sigarray=None):
    contcorr,contsig = adapted_ch_cont(array,continuum,sigarray)
    skylinemask = (lamgrid > 5578.5 - 10)*(lamgrid < 5578.5 + 10) + (lamgrid > 5894.6 - 10)*(lamgrid < 5894.6 + 10)\
        + (lamgrid > 6301.7 - 10)*(lamgrid < 6301.7 + 10) + (lamgrid > 7246.0 - 10)*(lamgrid < 7246.0 + 10)
    contcorr[skylinemask] = 1
    #where = np.isnan(contcorr)+(contcorr > 1.25) + (contcorr < 0)
    #contcorr[where] = 1
    return contcorr,contsig

# %% [markdown]
# ## Model

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler
import multiprocessing
# Out:
# Using TensorFlow backend.

# %%
sc = MinMaxScaler()
msc = StandardScaler()

# %%
## Load Model Spectra

searchparameter = '_'

prefilenames = os.listdir('koester2/')
filenames = []
for i in range(len(prefilenames)):
    if searchparameter in prefilenames[i]:
        filenames.append(prefilenames[i])
        
len(filenames)

modelspectra = [];
modelwl = [];
loggs = [];
teffs = [];
for i in (filenames):
    specname=i
    f = open('koester2/'+specname)
    data = f.readlines()
    f.close()
    headerdata = data[0:7]
    spectraldata = data[6:]
    lam = []
    flux = []

    for i in range(len(spectraldata)):
        l=float(spectraldata[i].split()[0])
        lam.append(l)
        f = float(spectraldata[i].split()[1])
        flux.append(f)

    lam = np.asarray(lam)
    flux = np.asarray(flux) / 1e7

    teff = float(headerdata[1].split()[3])
    logg = float(headerdata[2].split()[3])
    
    in1 = find_nearest(lam,4000)
    in2 = find_nearest(lam,8000)

    flux = flux[in1:in2]
    lam = lam[in1:in2]
    
    flux = flux[:-1][~ (np.diff(lam) == 0)]
    lam = lam[:-1][~ (np.diff(lam) == 0)]
    
    lamgrid = np.arange(4000,8000)
    
    func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
    flux = func(lamgrid)
    
    modelspectra.append(flux)
    modelwl.append(lam)
    teffs.append(teff)
    loggs.append(logg)

modelspectra = np.asarray(modelspectra)
loggs = np.asarray(loggs)
teffs = np.asarray(teffs)

# %%
pixels = np.arange(0,4000)
continuum = (pixels > 2900) + (pixels < 2200)*(pixels > 1200) + (pixels < 650)*(pixels > 530) \
            + (pixels < 35)*(pixels > 20) + (pixels < 220)*(pixels > 200)

norm_modelspectra = [adapted_ch_cont(i,continuum) for i in modelspectra]
norm_modelspectra = np.asarray(norm_modelspectra)

# %%
plt.plot(norm_modelspectra[2:20].T);

# %%
X = np.stack((teffs,loggs)).T
t = norm_modelspectra

X_scaled = sc.fit_transform(X)
t_scaled = msc.fit_transform(t)

# %%
def vloss(ypred,ytrue):
    resid = ypred-ytrue
    return K.mean(K.exp(resid**2))

# %%
H = 32
reg = 0.0001
def generator():
    x = Input(shape=(2,))
    y = Dense(H,activation='sigmoid',trainable = True)(x)
    y = Dense(H,activation='sigmoid',trainable = True)(y)
    out = Dense(4000,activation='linear',trainable = True)(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adamax(), loss = 'mse', \
                  metrics = ['mae'])
    return model
model = generator()
history = [];
model.load_weights('normNN.h5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                96
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_12 (Dense)             (None, 4000)              132000
# =================================================================
# Total params: 133,152
# Trainable params: 133,152
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
for i in tqdm(range(2500)): 
    print('Training meta-batch %i'%i)
    
    n_epochs = 1000
    batch = 1040
    
    
    h = model.fit(X_scaled,t_scaled, epochs = n_epochs, verbose = 0, batch_size = batch, shuffle = True)
    history = np.append(history, h.history['loss'])
    model.save_weights('normNN.h5')
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Training meta-batch 0
#   0%|          | 1/2500 [01:12<50:32:49, 72.82s/it]
# Training meta-batch 1
#   0%|          | 2/2500 [02:22<49:54:00, 71.91s/it]
# Training meta-batch 2
#   0%|          | 3/2500 [03:33<49:36:40, 71.53s/it]
# Training meta-batch 3
#   0%|          | 4/2500 [04:44<49:28:51, 71.37s/it]
# Training meta-batch 4
#   0%|          | 5/2500 [05:53<48:59:43, 70.69s/it]
# Training meta-batch 5
#   0%|          | 6/2500 [07:02<48:45:09, 70.37s/it]
# Training meta-batch 6
#   0%|          | 7/2500 [08:12<48:33:56, 70.13s/it]
# Training meta-batch 7
#   0%|          | 8/2500 [09:21<48:21:23, 69.86s/it]
# Training meta-batch 8
#   0%|          | 9/2500 [10:31<48:20:35, 69.87s/it]
# Training meta-batch 9
#   0%|          | 10/2500 [11:44<48:51:51, 70.65s/it]
# Training meta-batch 10
#   0%|          | 11/2500 [12:55<49:00:06, 70.87s/it]
# Training meta-batch 11
#   0%|          | 12/2500 [14:09<49:36:58, 71.79s/it]
# Training meta-batch 12
#   1%|          | 13/2500 [15:20<49:26:24, 71.57s/it]
# Training meta-batch 13

# %%
plt.plot(history[-10000:])

# %%
plt.figure(figsize=(10,13))

plt.subplot(211)
ts = np.linspace(8000,25000,5)
ls = np.linspace(8,8,5)
plt.rcParams.update({'font.size': 22})             
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = msc.inverse_transform(model.predict(samples))
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(lamgrid[720:1000],adapted_ch_cont(gens[i],continuum)[720:1000],label='$T_{eff} = %i$ K'%ts[i])
plt.legend(fontsize=17)
plt.ylabel('Normalized Flux')
plt.xlabel('Wavelength ($\AA$)')

plt.subplot(212)
ts = np.linspace(25000,25000,5)
ls = np.linspace(7,9,5)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = msc.inverse_transform(model.predict(samples))
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(lamgrid[720:1000],adapted_ch_cont(gens[i],continuum)[720:1000],label='$Logg = %.2f$ dex'%ls[i])
plt.legend(fontsize=17)
plt.ylabel('Normalized Flux')
plt.xlabel('Wavelength ($\AA$)')
# Out:
# Text(0.5, 0, 'Wavelength ($\\AA$)')

# %%
pixel = int(halpha)-4000+23

temp = 14000


ts = teffs[teffs == temp]
ls = loggs[teffs == temp]
labels = np.stack((ts,ls)).T
tflux = np.exp(t)[teffs == temp][:,pixel]

plt.scatter(ls,tflux,color='k')

linls = np.linspace(min(ls),max(ls),100)
lints = np.repeat(temp,100)
linlabels = np.stack((lints,linls)).T
lintflux = np.exp(msc.inverse_transform(model.predict(sc.transform(linlabels))))[:,pixel]
plt.plot(linls,lintflux)

# %% [markdown]
# ## SDSS Data

# %%
filetable = Table.read('filetable.fits')
wdtable = Table.read('tremblay_final.fits')
print(len(wdtable))
wdtable = join(filetable,wdtable,keys = ['source_id','Teff','log_g','spectral_class','S/N'])

DA = (wdtable['spectral_class'] == 'DA')*(~np.isnan(wdtable['Teff']))*(~np.isnan(wdtable['log_g']))*\
        (wdtable['S/N'] > 40)*(wdtable['spec_Teff'] < 80000)
wdtable = wdtable[DA]
print(len(wdtable))
wdtable = wdtable[np.random.randint(0,len(wdtable),len(wdtable))]
# Out:
# 5396
# 603

# %%
plt.scatter(wdtable['spec_Teff'],wdtable['spec_logg'], s = 5, c = wdtable['S/N'], vmax = 100, cmap = 'rainbow')

# %%
interpfluxs = [];
sigs = [];
lamgrid = np.arange(4000,8000)
for i in tqdm(range(len(wdtable))):
    spec = get_spectrum(wdtable['source_id'][i])
    lam  = spec[0]
    flux = spec[1]
    sig = spec[2]
    func2 = interp1d(lam,sig,kind='linear',assume_sorted = False,fill_value='extrapolate')
    interpsig = func2(lamgrid)
    #trans = ((wdtable['center_b'][i] - hbeta)+(wdtable['center_a'][i]-halpha))/2
    #shiftedflux = interpolation.shift(flux,-trans,cval=np.nan)
    func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
    interpflux = func(lamgrid)
    interpfluxs.append(interpflux)
    sigs.append(interpsig)
# Out:
#   0%|          | 0/603 [00:00<?, ?it/s]
#
#
#
#   0%|          | 1/603 [00:00<04:29,  2.23it/s]
#
#
#
#   0%|          | 3/603 [00:00<03:21,  2.98it/s]
#
#
#
#   1%|          | 5/603 [00:00<02:34,  3.87it/s]
#
#
#
#   1%|          | 7/603 [00:00<02:00,  4.94it/s]
#
#
#
#   1%|▏         | 9/603 [00:01<01:36,  6.15it/s]
#
#
#
#   2%|▏         | 11/603 [00:01<01:20,  7.32it/s]
#
#
#
#   2%|▏         | 13/603 [00:01<01:09,  8.46it/s]
#
#
#
#   2%|▏         | 15/603 [00:01<01:03,  9.29it/s]
#
#
#
#   3%|▎         | 17/603 [00:01<00:58, 10.01it/s]
#
#
#
#   3%|▎         | 19/603 [00:01<00:55, 10.61it/s]
#
#
#
#   3%|▎         | 21/603 [00:01<00:52, 11.14it/s]
#
#
#
#   4%|▍         | 23/603 [00:02<00:49, 11.74it/s]
#
#
#
#   4%|▍         | 25/603 [00:02<00:47, 12.29it/s]
#
#
#
#   4%|▍         | 27/603 [00:02<00:45, 12.59it/s]
#
#
#
#   5%|▍         | 29/603 [00:02<00:44, 12.81it/s]
#
#
#
#   5%|▌         | 31/603 [00:02<00:43, 13.05it/s]
#
#
#
#   5%|▌         | 33/603 [00:02<00:43, 13.24it/s]
#
#
#
#   6%|▌         | 35/603 [00:03<00:43, 13.07it/s]
#
#
#
#   6%|▌         | 37/603 [00:03<00:44, 12.81it/s]
#
#
#
#   6%|▋         | 39/603 [00:03<00:45, 12.39it/s]
#
#
#
#   7%|▋         | 41/603 [00:03<00:54, 10.29it/s]
#
#
#
#   7%|▋         | 43/603 [00:03<00:51, 10.84it/s]
#
#
#
#   7%|▋         | 45/603 [00:03<00:48, 11.48it/s]
#
#
#
#   8%|▊         | 47/603 [00:04<00:47, 11.62it/s]
#
#
#
#   8%|▊         | 49/603 [00:04<00:47, 11.68it/s]
#
#
#
#   8%|▊         | 51/603 [00:04<00:46, 11.88it/s]
#
#
#
#   9%|▉         | 53/603 [00:04<00:46, 11.73it/s]
#
#
#
#   9%|▉         | 55/603 [00:04<00:44, 12.19it/s]
#
#
#
#   9%|▉         | 57/603 [00:04<00:45, 11.91it/s]
#
#
#
#  10%|▉         | 59/603 [00:05<00:46, 11.74it/s]
#
#
#
#  10%|█         | 61/603 [00:05<00:44, 12.18it/s]
#
#
#
#  10%|█         | 63/603 [00:05<00:43, 12.28it/s]
#
#
#
#  11%|█         | 65/603 [00:05<00:44, 12.17it/s]
#
#
#
#  11%|█         | 67/603 [00:05<00:43, 12.38it/s]
#
#
#
#  11%|█▏        | 69/603 [00:05<00:41, 12.82it/s]
#
#
#
#  12%|█▏        | 71/603 [00:06<00:42, 12.54it/s]
#
#
#
#  12%|█▏        | 73/603 [00:06<00:42, 12.56it/s]
#
#
#
#  12%|█▏        | 75/603 [00:06<00:41, 12.58it/s]
#
#
#
#  13%|█▎        | 77/603 [00:06<00:41, 12.79it/s]
#
#
#
#  13%|█▎        | 79/603 [00:06<00:41, 12.68it/s]
#
#
#
#  13%|█▎        | 81/603 [00:06<00:41, 12.44it/s]
#
#
#
#  14%|█▍        | 83/603 [00:07<00:43, 12.04it/s]
#
#
#
#  14%|█▍        | 85/603 [00:07<00:52,  9.84it/s]
#
#
#
#  14%|█▍        | 87/603 [00:07<00:50, 10.18it/s]
#
#
#
#  15%|█▍        | 89/603 [00:07<00:47, 10.83it/s]
#
#
#
#  15%|█▌        | 91/603 [00:07<00:45, 11.21it/s]
#
#
#
#  15%|█▌        | 93/603 [00:07<00:43, 11.74it/s]
#
#
#
#  16%|█▌        | 95/603 [00:08<00:42, 12.08it/s]
#
#
#
#  16%|█▌        | 97/603 [00:08<00:40, 12.36it/s]
#
#
#
#  16%|█▋        | 99/603 [00:08<00:40, 12.37it/s]
#
#
#
#  17%|█▋        | 101/603 [00:08<00:40, 12.34it/s]
#
#
#
#  17%|█▋        | 103/603 [00:08<00:40, 12.23it/s]
#
#
#
#  17%|█▋        | 105/603 [00:08<00:39, 12.61it/s]
#
#
#
#  18%|█▊        | 107/603 [00:09<00:40, 12.31it/s]
#
#
#
#  18%|█▊        | 109/603 [00:09<00:41, 11.99it/s]
#
#
#
#  18%|█▊        | 111/603 [00:09<00:42, 11.61it/s]
#
#
#
#  19%|█▊        | 113/603 [00:09<00:42, 11.45it/s]
#
#
#
#  19%|█▉        | 115/603 [00:09<00:41, 11.66it/s]
#
#
#
#  19%|█▉        | 117/603 [00:09<00:40, 12.14it/s]
#
#
#
#  20%|█▉        | 119/603 [00:10<00:39, 12.27it/s]
#
#
#
#  20%|██        | 121/603 [00:10<00:39, 12.34it/s]
#
#
#
#  20%|██        | 123/603 [00:10<00:37, 12.71it/s]
#
#
#
#  21%|██        | 125/603 [00:10<00:37, 12.62it/s]
#
#
#
#  21%|██        | 127/603 [00:10<00:37, 12.63it/s]
#
#
#
#  21%|██▏       | 129/603 [00:10<00:36, 12.88it/s]
#
#
#
#  22%|██▏       | 131/603 [00:11<00:44, 10.70it/s]
#
#
#
#  22%|██▏       | 133/603 [00:11<00:40, 11.49it/s]
#
#
#
#  22%|██▏       | 135/603 [00:11<00:39, 11.77it/s]
#
#
#
#  23%|██▎       | 137/603 [00:11<00:38, 12.18it/s]
#
#
#
#  23%|██▎       | 139/603 [00:11<00:36, 12.57it/s]
#
#
#
#  23%|██▎       | 141/603 [00:11<00:35, 12.85it/s]
#
#
#
#  24%|██▎       | 143/603 [00:12<00:36, 12.49it/s]
#
#
#
#  24%|██▍       | 145/603 [00:12<00:36, 12.53it/s]
#
#
#
#  24%|██▍       | 147/603 [00:12<00:36, 12.50it/s]
#
#
#
#  25%|██▍       | 149/603 [00:12<00:36, 12.29it/s]
#
#
#
#  25%|██▌       | 151/603 [00:12<00:38, 11.80it/s]
#
#
#
#  25%|██▌       | 153/603 [00:12<00:37, 12.13it/s]
#
#
#
#  26%|██▌       | 155/603 [00:13<00:36, 12.19it/s]
#
#
#
#  26%|██▌       | 157/603 [00:13<00:38, 11.67it/s]
#
#
#
#  26%|██▋       | 159/603 [00:13<00:37, 11.76it/s]
#
#
#
#  27%|██▋       | 161/603 [00:13<00:37, 11.85it/s]
#
#
#
#  27%|██▋       | 163/603 [00:13<00:36, 12.17it/s]
#
#
#
#  27%|██▋       | 165/603 [00:13<00:35, 12.24it/s]
#
#
#
#  28%|██▊       | 167/603 [00:14<00:35, 12.25it/s]
#
#
#
#  28%|██▊       | 169/603 [00:14<00:35, 12.18it/s]
#
#
#
#  28%|██▊       | 171/603 [00:14<00:35, 12.29it/s]
#
#
#
#  29%|██▊       | 173/603 [00:14<00:34, 12.53it/s]
#
#
#
#  29%|██▉       | 175/603 [00:14<00:39, 10.75it/s]
#
#
#
#  29%|██▉       | 177/603 [00:14<00:38, 11.01it/s]
#
#
#
#  30%|██▉       | 179/603 [00:15<00:36, 11.67it/s]
#
#
#
#  30%|███       | 181/603 [00:15<00:34, 12.09it/s]
#
#
#
#  30%|███       | 183/603 [00:15<00:34, 12.29it/s]
#
#
#
#  31%|███       | 185/603 [00:15<00:33, 12.64it/s]
#
#
#
#  31%|███       | 187/603 [00:15<00:32, 12.69it/s]
#
#
#
#  31%|███▏      | 189/603 [00:15<00:33, 12.48it/s]
#
#
#
#  32%|███▏      | 191/603 [00:16<00:32, 12.49it/s]
#
#
#
#  32%|███▏      | 193/603 [00:16<00:32, 12.50it/s]
#
#
#
#  32%|███▏      | 195/603 [00:16<00:33, 12.19it/s]
#
#
#
#  33%|███▎      | 197/603 [00:16<00:32, 12.52it/s]
#
#
#
#  33%|███▎      | 199/603 [00:16<00:31, 12.77it/s]
#
#
#
#  33%|███▎      | 201/603 [00:16<00:31, 12.87it/s]
#
#
#
#  34%|███▎      | 203/603 [00:16<00:31, 12.88it/s]
#
#
#
#  34%|███▍      | 205/603 [00:17<00:29, 13.33it/s]
#
#
#
#  34%|███▍      | 207/603 [00:17<00:30, 12.97it/s]
#
#
#
#  35%|███▍      | 209/603 [00:17<00:29, 13.16it/s]
#
#
#
#  35%|███▍      | 211/603 [00:17<00:29, 13.16it/s]
#
#
#
#  35%|███▌      | 213/603 [00:17<00:30, 12.79it/s]
#
#
#
#  36%|███▌      | 215/603 [00:17<00:30, 12.60it/s]
#
#
#
#  36%|███▌      | 217/603 [00:18<00:31, 12.39it/s]
#
#
#
#  36%|███▋      | 219/603 [00:18<00:38,  9.99it/s]
#
#
#
#  37%|███▋      | 221/603 [00:18<00:35, 10.69it/s]
#
#
#
#  37%|███▋      | 223/603 [00:18<00:33, 11.21it/s]
#
#
#
#  37%|███▋      | 225/603 [00:18<00:32, 11.57it/s]
#
#
#
#  38%|███▊      | 227/603 [00:18<00:30, 12.15it/s]
#
#
#
#  38%|███▊      | 229/603 [00:19<00:30, 12.35it/s]
#
#
#
#  38%|███▊      | 231/603 [00:19<00:29, 12.69it/s]
#
#
#
#  39%|███▊      | 233/603 [00:19<00:29, 12.47it/s]
#
#
#
#  39%|███▉      | 235/603 [00:19<00:29, 12.64it/s]
#
#
#
#  39%|███▉      | 237/603 [00:19<00:30, 11.99it/s]
#
#
#
#  40%|███▉      | 239/603 [00:19<00:30, 12.08it/s]
#
#
#
#  40%|███▉      | 241/603 [00:20<00:28, 12.57it/s]
#
#
#
#  40%|████      | 243/603 [00:20<00:27, 13.08it/s]
#
#
#
#  41%|████      | 245/603 [00:20<00:26, 13.53it/s]
#
#
#
#  41%|████      | 247/603 [00:20<00:25, 13.77it/s]
#
#
#
#  41%|████▏     | 249/603 [00:20<00:25, 13.79it/s]
#
#
#
#  42%|████▏     | 251/603 [00:20<00:25, 13.98it/s]
#  42%|████▏     | 253/603 [00:20<00:25, 13.71it/s]
#
#
#
#  42%|████▏     | 255/603 [00:21<00:25, 13.49it/s]
#
#
#
#  43%|████▎     | 257/603 [00:21<00:24, 13.86it/s]
#
#
#
#  43%|████▎     | 259/603 [00:21<00:30, 11.11it/s]
#
#
#
#  43%|████▎     | 261/603 [00:21<00:28, 11.99it/s]
#
#
#
#  44%|████▎     | 263/603 [00:21<00:27, 12.58it/s]
#
#
#
#  44%|████▍     | 265/603 [00:21<00:26, 12.63it/s]
#
#
#
#  44%|████▍     | 267/603 [00:22<00:25, 12.97it/s]
#
#
#
#  45%|████▍     | 269/603 [00:22<00:25, 13.03it/s]
#
#
#
#  45%|████▍     | 271/603 [00:22<00:25, 13.15it/s]
#
#
#
#  45%|████▌     | 273/603 [00:22<00:25, 12.88it/s]
#
#
#
#  46%|████▌     | 275/603 [00:22<00:25, 13.08it/s]
#
#
#
#  46%|████▌     | 277/603 [00:22<00:25, 12.85it/s]
#
#
#
#  46%|████▋     | 279/603 [00:23<00:24, 13.18it/s]
#
#
#
#  47%|████▋     | 281/603 [00:23<00:24, 12.98it/s]
#
#
#
#  47%|████▋     | 283/603 [00:23<00:24, 13.32it/s]
#
#
#
#  47%|████▋     | 285/603 [00:23<00:24, 13.03it/s]
#
#
#
#  48%|████▊     | 287/603 [00:23<00:24, 13.15it/s]
#
#
#
#  48%|████▊     | 289/603 [00:23<00:23, 13.19it/s]
#
#
#
#  48%|████▊     | 291/603 [00:23<00:23, 13.12it/s]
#
#
#
#  49%|████▊     | 293/603 [00:24<00:23, 13.24it/s]
#
#
#
#  49%|████▉     | 295/603 [00:24<00:22, 13.50it/s]
#
#
#
#  49%|████▉     | 297/603 [00:24<00:22, 13.59it/s]
#
#
#
#  50%|████▉     | 299/603 [00:24<00:23, 13.10it/s]
#
#
#
#  50%|████▉     | 301/603 [00:24<00:29, 10.26it/s]
#
#
#
#  50%|█████     | 303/603 [00:24<00:27, 10.82it/s]
#
#
#
#  51%|█████     | 305/603 [00:25<00:25, 11.48it/s]
#
#
#
#  51%|█████     | 307/603 [00:25<00:24, 12.00it/s]
#
#
#
#  51%|█████     | 309/603 [00:25<00:23, 12.43it/s]
#
#
#
#  52%|█████▏    | 311/603 [00:25<00:22, 12.98it/s]
#
#
#
#  52%|█████▏    | 313/603 [00:25<00:22, 12.77it/s]
#
#
#
#  52%|█████▏    | 315/603 [00:25<00:22, 12.78it/s]
#
#
#
#  53%|█████▎    | 317/603 [00:26<00:23, 12.38it/s]
#
#
#
#  53%|█████▎    | 319/603 [00:26<00:23, 12.21it/s]
#
#
#
#  53%|█████▎    | 321/603 [00:26<00:22, 12.30it/s]
#
#
#
#  54%|█████▎    | 323/603 [00:26<00:22, 12.21it/s]
#
#
#
#  54%|█████▍    | 325/603 [00:26<00:22, 12.16it/s]
#
#
#
#  54%|█████▍    | 327/603 [00:26<00:22, 12.17it/s]
#
#
#
#  55%|█████▍    | 329/603 [00:27<00:21, 12.61it/s]
#
#
#
#  55%|█████▍    | 331/603 [00:27<00:22, 12.35it/s]
#
#
#
#  55%|█████▌    | 333/603 [00:27<00:21, 12.51it/s]
#
#
#
#  56%|█████▌    | 335/603 [00:27<00:20, 12.85it/s]
#
#
#
#  56%|█████▌    | 337/603 [00:27<00:20, 12.93it/s]
#
#
#
#  56%|█████▌    | 339/603 [00:27<00:20, 13.18it/s]
#
#
#
#  57%|█████▋    | 341/603 [00:27<00:19, 13.40it/s]
#
#
#
#  57%|█████▋    | 343/603 [00:28<00:24, 10.77it/s]
#
#
#
#  57%|█████▋    | 345/603 [00:28<00:23, 11.01it/s]
#
#
#
#  58%|█████▊    | 347/603 [00:28<00:22, 11.33it/s]
#
#
#
#  58%|█████▊    | 349/603 [00:28<00:21, 11.81it/s]
#
#
#
#  58%|█████▊    | 351/603 [00:28<00:20, 12.05it/s]
#
#
#
#  59%|█████▊    | 353/603 [00:28<00:19, 12.63it/s]
#
#
#
#  59%|█████▉    | 355/603 [00:29<00:19, 12.66it/s]
#
#
#
#  59%|█████▉    | 357/603 [00:29<00:19, 12.68it/s]
#
#
#
#  60%|█████▉    | 359/603 [00:29<00:19, 12.58it/s]
#
#
#
#  60%|█████▉    | 361/603 [00:29<00:19, 12.64it/s]
#
#
#
#  60%|██████    | 363/603 [00:29<00:18, 12.80it/s]
#
#
#
#  61%|██████    | 365/603 [00:29<00:18, 12.58it/s]
#
#
#
#  61%|██████    | 367/603 [00:30<00:18, 12.94it/s]
#
#
#
#  61%|██████    | 369/603 [00:30<00:18, 12.89it/s]
#
#
#
#  62%|██████▏   | 371/603 [00:30<00:18, 12.61it/s]
#
#
#
#  62%|██████▏   | 373/603 [00:30<00:17, 12.95it/s]
#
#
#
#  62%|██████▏   | 375/603 [00:30<00:18, 12.56it/s]
#
#
#
#  63%|██████▎   | 377/603 [00:30<00:18, 12.54it/s]
#
#
#
#  63%|██████▎   | 379/603 [00:31<00:17, 12.71it/s]
#
#
#
#  63%|██████▎   | 381/603 [00:31<00:17, 12.51it/s]
#
#
#
#  64%|██████▎   | 383/603 [00:31<00:17, 12.29it/s]
#
#
#
#  64%|██████▍   | 385/603 [00:31<00:17, 12.70it/s]
#
#
#
#  64%|██████▍   | 387/603 [00:31<00:20, 10.71it/s]
#
#
#
#  65%|██████▍   | 389/603 [00:31<00:18, 11.29it/s]
#
#
#
#  65%|██████▍   | 391/603 [00:32<00:18, 11.76it/s]
#
#
#
#  65%|██████▌   | 393/603 [00:32<00:17, 12.00it/s]
#
#
#
#  66%|██████▌   | 395/603 [00:32<00:16, 12.32it/s]
#
#
#
#  66%|██████▌   | 397/603 [00:32<00:16, 12.36it/s]
#
#
#
#  66%|██████▌   | 399/603 [00:32<00:15, 12.84it/s]
#
#
#
#  67%|██████▋   | 401/603 [00:32<00:15, 12.93it/s]
#
#
#
#  67%|██████▋   | 403/603 [00:32<00:15, 13.13it/s]
#
#
#
#  67%|██████▋   | 405/603 [00:33<00:14, 13.44it/s]
#
#
#
#  67%|██████▋   | 407/603 [00:33<00:14, 13.52it/s]
#
#
#
#  68%|██████▊   | 409/603 [00:33<00:14, 13.34it/s]
#
#
#
#  68%|██████▊   | 411/603 [00:33<00:14, 13.58it/s]
#
#
#
#  68%|██████▊   | 413/603 [00:33<00:14, 13.39it/s]
#
#
#
#  69%|██████▉   | 415/603 [00:33<00:14, 13.34it/s]
#
#
#
#  69%|██████▉   | 417/603 [00:34<00:13, 13.31it/s]
#
#
#
#  69%|██████▉   | 419/603 [00:34<00:13, 13.22it/s]
#
#
#
#  70%|██████▉   | 421/603 [00:34<00:13, 13.20it/s]
#
#
#
#  70%|███████   | 423/603 [00:34<00:13, 13.46it/s]
#
#
#
#  70%|███████   | 425/603 [00:34<00:13, 13.13it/s]
#
#
#
#  71%|███████   | 427/603 [00:34<00:13, 12.90it/s]
#
#
#
#  71%|███████   | 429/603 [00:34<00:13, 12.98it/s]
#
#
#
#  71%|███████▏  | 431/603 [00:35<00:17, 10.05it/s]
#
#
#
#  72%|███████▏  | 433/603 [00:35<00:15, 10.71it/s]
#
#
#
#  72%|███████▏  | 435/603 [00:35<00:14, 11.47it/s]
#
#
#
#  72%|███████▏  | 437/603 [00:35<00:13, 12.05it/s]
#
#
#
#  73%|███████▎  | 439/603 [00:35<00:13, 12.48it/s]
#
#
#
#  73%|███████▎  | 441/603 [00:36<00:12, 12.52it/s]
#
#
#
#  73%|███████▎  | 443/603 [00:36<00:12, 12.85it/s]
#
#
#
#  74%|███████▍  | 445/603 [00:36<00:12, 12.92it/s]
#
#
#
#  74%|███████▍  | 447/603 [00:36<00:11, 13.03it/s]
#
#
#
#  74%|███████▍  | 449/603 [00:36<00:11, 13.26it/s]
#
#
#
#  75%|███████▍  | 451/603 [00:36<00:11, 13.41it/s]
#
#
#
#  75%|███████▌  | 453/603 [00:36<00:11, 13.53it/s]
#
#
#
#  75%|███████▌  | 455/603 [00:37<00:10, 13.54it/s]
#
#
#
#  76%|███████▌  | 457/603 [00:37<00:10, 13.41it/s]
#
#
#
#  76%|███████▌  | 459/603 [00:37<00:10, 13.45it/s]
#
#
#
#  76%|███████▋  | 461/603 [00:37<00:10, 13.42it/s]
#
#
#
#  77%|███████▋  | 463/603 [00:37<00:10, 13.64it/s]
#
#
#
#  77%|███████▋  | 465/603 [00:37<00:10, 13.33it/s]
#
#
#
#  77%|███████▋  | 467/603 [00:37<00:09, 13.62it/s]
#
#
#
#  78%|███████▊  | 469/603 [00:38<00:09, 13.81it/s]
#
#
#
#  78%|███████▊  | 471/603 [00:38<00:09, 13.64it/s]
#
#
#
#  78%|███████▊  | 473/603 [00:38<00:11, 11.20it/s]
#
#
#
#  79%|███████▉  | 475/603 [00:38<00:10, 11.92it/s]
#
#
#
#  79%|███████▉  | 477/603 [00:38<00:10, 12.60it/s]
#
#
#
#  79%|███████▉  | 479/603 [00:38<00:09, 12.96it/s]
#
#
#
#  80%|███████▉  | 481/603 [00:39<00:09, 12.94it/s]
#
#
#
#  80%|████████  | 483/603 [00:39<00:09, 12.95it/s]
#
#
#
#  80%|████████  | 485/603 [00:39<00:09, 12.96it/s]
#
#
#
#  81%|████████  | 487/603 [00:39<00:08, 13.21it/s]
#
#
#
#  81%|████████  | 489/603 [00:39<00:08, 13.17it/s]
#
#
#
#  81%|████████▏ | 491/603 [00:39<00:08, 13.18it/s]
#
#
#
#  82%|████████▏ | 493/603 [00:39<00:08, 13.27it/s]
#
#
#
#  82%|████████▏ | 495/603 [00:40<00:08, 13.28it/s]
#
#
#
#  82%|████████▏ | 497/603 [00:40<00:08, 12.86it/s]
#
#
#
#  83%|████████▎ | 499/603 [00:40<00:07, 13.03it/s]
#
#
#
#  83%|████████▎ | 501/603 [00:40<00:07, 13.13it/s]
#
#
#
#  83%|████████▎ | 503/603 [00:40<00:07, 12.96it/s]
#  84%|████████▎ | 505/603 [00:40<00:07, 13.27it/s]
#
#
#
#  84%|████████▍ | 507/603 [00:41<00:07, 13.38it/s]
#
#
#
#  84%|████████▍ | 509/603 [00:41<00:07, 13.17it/s]
#
#
#
#  85%|████████▍ | 511/603 [00:41<00:07, 13.12it/s]
#
#
#
#  85%|████████▌ | 513/603 [00:41<00:08, 10.88it/s]
#
#
#
#  85%|████████▌ | 515/603 [00:41<00:07, 11.68it/s]
#
#
#
#  86%|████████▌ | 517/603 [00:41<00:07, 12.19it/s]
#
#
#
#  86%|████████▌ | 519/603 [00:42<00:06, 12.57it/s]
#
#
#
#  86%|████████▋ | 521/603 [00:42<00:06, 12.93it/s]
#
#
#
#  87%|████████▋ | 523/603 [00:42<00:05, 13.60it/s]
#
#
#
#  87%|████████▋ | 525/603 [00:42<00:05, 13.56it/s]
#
#
#
#  87%|████████▋ | 527/603 [00:42<00:05, 13.54it/s]
#
#
#
#  88%|████████▊ | 529/603 [00:42<00:05, 13.89it/s]
#
#
#
#  88%|████████▊ | 531/603 [00:42<00:05, 13.67it/s]
#
#
#
#  88%|████████▊ | 533/603 [00:43<00:05, 13.39it/s]
#
#
#
#  89%|████████▊ | 535/603 [00:43<00:05, 13.26it/s]
#
#
#
#  89%|████████▉ | 537/603 [00:43<00:04, 13.31it/s]
#
#
#
#  89%|████████▉ | 539/603 [00:43<00:04, 13.61it/s]
#
#
#
#  90%|████████▉ | 541/603 [00:43<00:04, 13.33it/s]
#
#
#
#  90%|█████████ | 543/603 [00:43<00:04, 13.05it/s]
#
#
#
#  90%|█████████ | 545/603 [00:43<00:04, 13.07it/s]
#
#
#
#  91%|█████████ | 547/603 [00:44<00:04, 13.07it/s]
#
#
#
#  91%|█████████ | 549/603 [00:44<00:04, 13.19it/s]
#
#
#
#  91%|█████████▏| 551/603 [00:44<00:03, 13.19it/s]
#
#
#
#  92%|█████████▏| 553/603 [00:44<00:03, 13.33it/s]
#
#
#
#  92%|█████████▏| 555/603 [00:44<00:03, 13.29it/s]
#
#
#
#  92%|█████████▏| 557/603 [00:44<00:04, 10.96it/s]
#
#
#
#  93%|█████████▎| 559/603 [00:45<00:03, 11.52it/s]
#
#
#
#  93%|█████████▎| 561/603 [00:45<00:03, 11.80it/s]
#
#
#
#  93%|█████████▎| 563/603 [00:45<00:03, 12.66it/s]
#
#
#
#  94%|█████████▎| 565/603 [00:45<00:02, 12.75it/s]
#
#
#
#  94%|█████████▍| 567/603 [00:45<00:02, 13.26it/s]
#
#
#
#  94%|█████████▍| 569/603 [00:45<00:02, 13.56it/s]
#
#
#
#  95%|█████████▍| 571/603 [00:45<00:02, 13.53it/s]
#
#
#
#  95%|█████████▌| 573/603 [00:46<00:02, 13.46it/s]
#
#
#
#  95%|█████████▌| 575/603 [00:46<00:02, 13.28it/s]
#
#
#
#  96%|█████████▌| 577/603 [00:46<00:01, 13.11it/s]
#
#
#
#  96%|█████████▌| 579/603 [00:46<00:01, 13.16it/s]
#
#
#
#  96%|█████████▋| 581/603 [00:46<00:01, 13.10it/s]
#
#
#
#  97%|█████████▋| 583/603 [00:46<00:01, 13.43it/s]
#
#
#
#  97%|█████████▋| 585/603 [00:47<00:01, 12.87it/s]
#
#
#
#  97%|█████████▋| 587/603 [00:47<00:01, 12.91it/s]
#
#
#
#  98%|█████████▊| 589/603 [00:47<00:01, 13.07it/s]
#
#
#
#  98%|█████████▊| 591/603 [00:47<00:00, 12.84it/s]
#
#
#
#  98%|█████████▊| 593/603 [00:47<00:00, 13.27it/s]
#
#
#
#  99%|█████████▊| 595/603 [00:47<00:00, 13.34it/s]
#
#
#
#  99%|█████████▉| 597/603 [00:47<00:00, 13.15it/s]
#
#
#
#  99%|█████████▉| 599/603 [00:48<00:00, 10.60it/s]
#
#
#
# 100%|█████████▉| 601/603 [00:48<00:00, 11.33it/s]
#
#
#
# 100%|██████████| 603/603 [00:48<00:00, 11.85it/s]

# %%
spectra = np.asarray(interpfluxs)
sigs = np.asarray(sigs)
lamgrid = np.arange(4000,8000)

# %%
# %%time
plt.figure(figsize=(18,3))
plt.plot(adapted_ch_cont(spectra[24],continuum))
plt.plot(continuum)
# Out:
# CPU times: user 63.5 ms, sys: 2.37 ms, total: 65.9 ms
# Wall time: 17.5 ms

# %%
wdtable['spectrum'] = spectra
wdtable['ivar'] = sigs

# %%
clamgrid = np.linspace(4000,7000,3000)

# %%
norms = [norm_dataspec(np.asarray(wdtable['spectrum'][ii]),np.asarray(wdtable['ivar'][ii])) for ii in range(len(wdtable))]
wdtable['normspectrum'] = np.asarray(norms)[:,0]
wdtable['normivar'] = np.asarray(norms)[:,0]

# %% [markdown]
# # Fitting

# %%
lines = ((lamgrid > hbeta-200) & (lamgrid < hbeta + 300)) | ((lamgrid > halpha-250) & (lamgrid < halpha + 300))\
        | ((lamgrid > hgamma-120) & (lamgrid < hgamma + 400))| ((lamgrid > hdelta-90) & (lamgrid < hdelta + 150))
def spectrum_sampler(wl,teff,logg,trans):
    label = sc.transform(np.asarray(np.stack((teff,logg)).reshape(1,-1)))
    synth = dopplerShift(wl,np.ravel(
                        msc.inverse_transform(
                                model.predict(label))[0]
                        ), trans*1000
                    )[0]
    return (np.ravel(synth).astype('float64'))

def norm_spectrum_sampler(wl,teff,logg,trans):
    synth = spectrum_sampler(lamgrid,teff,logg,trans)
    return synth[lines]

def chisquare(residual):
    return sum(residual**2)

def get_prior_teff(array):
    spec = np.asarray(array)
    priorfitter = lmfit.Model(spectrum_sampler)
    priorparams = priorfitter.make_params()
    priorparams['logg'].set(value = 8., vary = False)
    priorparams['teff'].set(value = 10000,min = 5500, max = 80000)
    priorparams['trans'].set(value = 0., vary = False)
    priorfitter.eval(priorparams, wl = lamgrid)
    prior_result = priorfitter.fit(spec, priorparams, wl = lamgrid, method = 'Powell', nan_policy = 'omit');
    #print(prior_result.fit_report())
    return prior_result.params['teff'].value

def get_posteriors(array, n_eval = 3000):
    spec = array
    normspec = adapted_ch_cont(spec,continuum)
    def chisq(params):
        teff,logg,trans = params
        res = normspec[lines] - norm_spectrum_sampler(lamgrid,teff,logg,trans)
        res = res[~np.isnan(res)]
        chisq = np.sum(res**2)
        return chisq
    teff_init = get_prior_teff(spec)
   # p = scipy.optimize.minimize(chisq, bounds = [(5500,80000),(6.5,9.5),(-3,3)], x0 = [teff_init, 8., 0],\
                             #  method = 'dual_annealing')
    p = scipy.optimize.dual_annealing(chisq,bounds = [(5500,80000),(6.5,9.5),(-3,3)],maxfun = n_eval,\
                                      x0 = [teff_init, 8., 0])
    #p = scipy.optimize.differential_evolution(chisq,bounds = [(5500,80000),(6.5,9.5),(-3,3)],\
       #                              disp = True)
    
#     plt.plot(normspec[lines])
#     plt.plot(norm_spectrum_sampler(lamgrid,p.x[0],p.x[1],p.x[2]))
    return p.x

# %% [markdown]
# #### Evaluate NFev

# %% [raw]
# evals = [50,100,250,500,750,1000,1500,2000,2500,3000,4000,5000];
#
# evals
#
# ps = [];
# for i in range(len(evals)):
#     p = get_posteriors(interpfluxs[124],evals[i])
#     ps.append(p)
#
# ps = np.asarray(ps)
#
# plt.plot(evals,ps[:,0])

# %% [markdown]
# ### Evaluate on Synthetics

# %% [raw]
# searchparameter = '_'
#
# prefilenames = os.listdir('koester2/')
# filenames = []
# for i in range(len(prefilenames)):
#     if searchparameter in prefilenames[i]:
#         filenames.append(prefilenames[i])
#
# len(filenames)

# %% [raw]
# modelspectra = [];
# modelwl = [];
# loggs = [];
# teffs = [];
# for i in (filenames):
#     specname=i
#     f = open('koester2/'+specname)
#     data = f.readlines()
#     f.close()
#     headerdata = data[0:7]
#     spectraldata = data[6:]
#     lam = []
#     flux = []
#
#     for i in range(len(spectraldata)):
#         l=float(spectraldata[i].split()[0])
#         lam.append(l)
#         f = float(spectraldata[i].split()[1])
#         flux.append(f)
#
#     lam = np.asarray(lam)
#     flux = np.asarray(flux) / 1e7
#
#     teff = float(headerdata[1].split()[3])
#     logg = float(headerdata[2].split()[3])
#
#     in1 = find_nearest(lam,4000)
#     in2 = find_nearest(lam,8000)
#
#     flux = flux[in1:in2]
#     lam = lam[in1:in2]
#
#     flux = flux[:-1][~ (np.diff(lam) == 0)]
#     lam = lam[:-1][~ (np.diff(lam) == 0)]
#
#     lamgrid = np.arange(4000,8000)
#
#     func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
#     flux = func(lamgrid)
#
#     modelspectra.append(flux)
#     modelwl.append(lam)
#     teffs.append(teff)
#     loggs.append(logg)
#
# modelspectra = np.asarray(modelspectra)
# loggs = np.asarray(loggs)
# teffs = np.asarray(teffs)

# %% [markdown]
# ### Test on Model Spectra

# %% [raw]
# fitparams = [];
# for ii in tqdm(range(len(modelspectra[np.random.randint(0,1040,100)]))):
#     fitparams.append(get_posteriors(modelspectra[ii]))
# fitparams = np.asarray(fitparams)

# %% [raw]
# resid = teffs[0:len(fitparams)]-fitparams[:,0]
# mask = fitparams[:,0] < 25000
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(teffs[0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');
# plt.figure()
# resid = loggs[0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(loggs[0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# mask = (fitparams[:,0] > 10000)&(fitparams[:,0] < 50000)
# resid = teffs[0:len(fitparams)][mask]-fitparams[:,0][mask]
#
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(teffs[0:len(fitparams)][mask],fitparams[:,0][mask])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');
# plt.figure()
# resid = loggs[0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(loggs[0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
#
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [markdown]
# ### Fit SDSS

# %% [raw]
# fitparams = [];
# for ii in tqdm(range(len(wdtable))):
#     fitparams.append(get_posteriors(wdtable['spectrum'][ii]))
#
# fitparams = np.asarray(fitparams)

# %% [raw]
# fitparams = np.asarray(fitparams)

# %% [raw]
# resid = wdtable['Teff'][0:len(fitparams)]-fitparams[:,0]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['Teff'][0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['log_g'][0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['log_g'][0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['spec_Teff'][0:len(fitparams)]-fitparams[:,0]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['spec_Teff'][0:len(fitparams)],fitparams[:,0])
# plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [raw]
# resid = wdtable['spec_logg'][0:len(fitparams)]-fitparams[:,1]
# rms = np.sqrt(np.mean(resid**2))
# f = plt.scatter(wdtable['spec_logg'][0:len(fitparams)],fitparams[:,1])
# plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
# x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
# y = x
# plt.plot(x,y,'r--')
# plt.figure()
# plt.hist(resid, histtype = 'step');

# %% [markdown]
# ### MCMC Fitting

# %% [raw]
# results = [];
# for ii in tqdm(range(len(wdtable[0:25]))):
#     spec = interpfluxs[ii]
#     sig = sigs[ii]
#     normspec,normsig = norm_dataspec(spec,sig)
#     normspec = normspec[lines]
#     normsig = normsig[lines]
#     teff_prior = get_prior_teff(spec)
#     def lnlike(prms):
#         ivar = normsig
#         model = norm_spectrum_sampler(lamgrid,prms[0],prms[1],prms[2])
#         diff = model - normspec
#         diff = diff[~np.isnan(model)]
#         ivar = ivar[~np.isnan(model)]
#         chisq = np.sum(diff**2 * ivar)
#         lnlike = -0.5 * chisq
#     #     plt.plot(model)
#     #     plt.plot(normspec)
#         return lnlike
#
#     def lnprior(prms):
#         if prms[0] < 6000 or prms[0] > 80000:
#             return -np.Inf
#         elif prms[1] < 6.5 or prms[1] > 9.5:
#             return -np.Inf
#         elif prms[2] < -3 or prms[2] > 3:
#             return -np.Inf
#
#         mu = teff_prior
#         sigma = 5000
#         return 0#np.log(1.0/(np.sqrt(2*np.pi)*sigma))-0.5*(prms[0]-mu)**2/sigma**2
#
#     def lnprob(prms):
#         lp = lnprior(prms)
#         if not np.isfinite(lp):
#             return -np.Inf
#         return lp + lnlike(prms)
#
#
#     ndim,nwalkers = 3,50
#
#
#     steps = 250
#     burn = 25
#
#     nll = lambda *args: -lnlike(*args)
#
#
#     p = scipy.optimize.dual_annealing(nll,bounds = [(5500,80000),(6.5,9.5),(-3,3)],maxfun = 5000,\
#                                       x0 = [teff_prior, 8., 0])
#
#     param_disps = [0.01]*3
#     #p0 = np.asarray(get_posteriors(spec))
#     p0 = p.x
#     pos0 = np.zeros((nwalkers,ndim))
#     for jj in range(ndim):
#         pos0[:,jj] = ( p0[jj] + param_disps[jj]*p0[jj]*np.random.randn(nwalkers) )
#
#
#
#     sampler = emcee.EnsembleSampler(nwalkers,ndim,lnprob,threads = 1)
#     b = sampler.run_mcmc(pos0,burn)
#     sampler.reset()
#     s = sampler.run_mcmc(b[0],steps)
#     values = np.median(sampler.flatchain,0)
#     meanvalues = np.mean(sampler.flatchain,0)
#     modevalues = stats.mode(sampler.flatchain,0)[0]
#     mlevalues = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
#     lower = np.quantile(sampler.flatchain,.3173,axis=0)
#     upper = np.quantile(sampler.flatchain,.6827,axis=0)
#     std = np.std(sampler.flatchain,axis=0)
#
#     results.append([values, meanvalues, modevalues, mlevalues, lower, upper, std])
#
#     fig,axs = plt.subplots(2,2,figsize=(10,10))
#     f = corner.corner(sampler.flatchain[:,0:2],show_titles = True,smooth = 0,truths = (wdtable['spec_Teff'][ii],\
#             wdtable['spec_logg'][ii]),labels = ('$T_{eff}$','logg'),title_kwargs={'fontsize':18}, fig = fig)
#     plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_corner.png')
#
#     plt.figure(figsize = (15,5))
#     plt.title('Gaia '+str(wdtable[ii]['source_id']))
#     plt.plot(normspec,'k', label = 'Data Spectrum')
#     plt.plot(norm_spectrum_sampler(lamgrid,mlevalues[0],mlevalues[1],mlevalues[2]),'r',\
#              label = 'Fitted Synthetic',linewidth=2)
#     #plt.legend()
#     plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_fit.png')
#     #plt.close()
#     plt.show()

# %%
plt.hist(1e5*(wdtable['centre_beta']-hbeta)/hbeta, range = (-100,100), histtype = 'step', bins = 25);
plt.hist(1e5*(wdtable['centre_alpha']-halpha)/halpha, range = (-100,100), histtype = 'step', bins = 25);

# %%
plt.hist((1e5*(wdtable['centre_beta']-hbeta)/hbeta) - (1e5*(wdtable['centre_alpha']-halpha)/halpha), range = (-100,100));

# %%
50e-5 * hbeta
# Out:
# 2.43134

# %%
# %%timeit

norm_spectrum_sampler(lamgrid,15000,8.,0)
# Out:
# 838 µs ± 49.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit 

spectrum_sampler(lamgrid,15000,8.,0)
# Out:
# 901 µs ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit

msc.inverse_transform(model.predict(sc.transform(np.asarray([15000,8]).reshape(-1,1).T)))
# Out:
# 375 µs ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
plt.figure(figsize = (15,3))
plt.plot(normspec)
plt.plot(spectrum_sampler(lamgrid,8190,8.2,0.13)[lines])

# %%
lnlike([8190,8.2,0.13])
# Out:
# -23299.942195546948

# %%
teffgrid = np.linspace(6000,80000,100)
logggrid = np.linspace(6.5,9.5,100)
from itertools import product

searchgrid = (np.vstack((product(teffgrid,logggrid)  )))

# %%
results = [];
for ii in tqdm(range(len(wdtable))):
    
    spec = wdtable['spectrum'][ii]
    sig = wdtable['ivar'][ii]
    normspec,normsig = norm_dataspec(spec,sig)
    normspec = np.asarray(normspec[lines])
    normsig = np.asarray(normsig[lines])
    def lnlike(prms):
        ivar = normsig
        model = norm_spectrum_sampler(lamgrid,prms[0],prms[1],prms[2])
        diff = model - normspec
        
#         plt.plot(model)
#         plt.plot(normspec)
#         plt.plot(diff)
        
        diff = diff[~np.isnan(model)]
        ivar = ivar[~np.isnan(model)]
        chisq = np.sum(diff**2 * ivar)
        lnlike = -0.5 * chisq
    #     plt.plot(model)
    #     plt.plot(normspec)
        return lnlike

    def lnprior(prms):
        if prms[0] < 6000 or prms[0] > 80000:
            return -np.Inf
        elif prms[1] < 6.5 or prms[1] > 9.5:
            return -np.Inf
        elif prms[2] < -3 or prms[2] > 3:
            return -np.Inf

        mu = teff_prior
        sigma = 5000
        return 0

    def lnprob(prms):
        lp = lnprior(prms)
        if not np.isfinite(lp):
            return -np.Inf
        return lp + lnlike(prms)


    ndim,nwalkers = 3,100


    steps = 100
    burn_step = 25
    total_burned = 0
        

    sampler = emcee.EnsembleSampler(nwalkers,ndim,lnprob,threads = 1)
    
    acorrtime = 1e5
    #Initialize sampler
    print('Finding MLE Point...')
    
    mlept = [15000,8.]
    maxlik = -1e10
    for searchpoint in searchgrid:
        lik = lnlike([searchpoint[0],searchpoint[1],0])
        if lik > maxlik:
            mlept = searchpoint;
            maxlik = lik
            
    print('MLE Gridpoint: %i K, %.2f dex'%(mlept[0],mlept[1]))
    mlpt = np.asarray([mlept[0],mlept[1],0])
    pos1 = np.zeros((nwalkers,ndim))
    ballsigmas = [500, 0.1, 0.05]
    for jj in range(ndim):
        pos1[:,jj] = (mlpt[jj] + ballsigmas[jj] * np.random.randn(nwalkers))
    

    
    b = sampler.run_mcmc(pos1,1) #Initialize
    
    while acorrtime > (0.1 * total_burned):
        print('Burning in %i samples... (%i done)'%(burn_step,total_burned))
        b = sampler.run_mcmc(b[0],burn_step)
        total_burned = total_burned + burn_step
        try:
            acorr_teff = emcee.autocorr.function(sampler.chain[0][:,0])
            acorrtime_teff = np.argmax(acorr_teff < (1/np.exp(1)))
            acorr_logg = emcee.autocorr.function(sampler.chain[0][:,1])
            acorrtime_logg = np.argmax(acorr_logg < (1/np.exp(1)))
            acorrtime = np.mean([acorrtime_teff, acorrtime_logg])
            print('Autocorr Time = %i samples.'%int(acorrtime))
        except :
            print('Chain too short.')
            continue;
            
        if (total_burned > 1000) and (acorrtime != 1e5):
            print('Maximum burn time reached.')
            break;
    
    print('Burn-in terminated with correlation fraction = %.2f'%(acorrtime/total_burned))
    
    n_draws = np.max([acorrtime, 100]) 
    print('Sampling %i draws from posterior'%n_draws)
    
    sampler.reset()
    s = sampler.run_mcmc(b[0],int(n_draws))
    values = np.median(sampler.flatchain,0)
    meanvalues = np.mean(sampler.flatchain,0)
    modevalues = stats.mode(sampler.flatchain,0)[0]
    mlevalues = sampler.flatchain[np.argmax(sampler.flatlnprobability)]
    chi2 = -2*lnlike(mlevalues)
    lower = np.quantile(sampler.flatchain,.3173,axis=0)
    upper = np.quantile(sampler.flatchain,.6827,axis=0)
    std = np.std(sampler.flatchain,axis=0)
    
    results.append([values, meanvalues, modevalues, mlevalues, lower, upper, std, chi2])
    
    fig,axs = plt.subplots(2,2,figsize=(10,10))
    f = corner.corner(sampler.flatchain[:,0:2],show_titles = True,smooth = 0,truths = (mlevalues[0],\
            mlevalues[1]),labels = ('$T_{eff}$','$\log{g}$'),title_kwargs={'fontsize':18}, fig = fig)
    plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_corner.png')
    plt.close()
    plt.figure(figsize = (15,5))
    plt.title('Gaia '+str(wdtable[ii]['source_id']))
    plt.plot(normspec,'k', label = 'Data Spectrum')
    plt.plot(norm_spectrum_sampler(lamgrid,mlevalues[0],mlevalues[1],mlevalues[2]),'r',\
             label = 'Fitted Synthetic',linewidth=2)
    #plt.legend()
    plt.savefig('plots/synthmc/'+str(wdtable[ii]['source_id'])+'_fit.png')
    plt.close()
# Out:
#   0%|          | 0/603 [00:00<?, ?it/s]
# Finding MLE Point...
# MLE Gridpoint: 23191 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   0%|          | 1/603 [00:28<4:46:43, 28.58s/it]
# Finding MLE Point...
# MLE Gridpoint: 28424 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   0%|          | 2/603 [00:49<4:22:18, 26.19s/it]
# Finding MLE Point...
# MLE Gridpoint: 14222 K, 8.26 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   0%|          | 3/603 [01:13<4:14:50, 25.48s/it]
# Finding MLE Point...
# MLE Gridpoint: 7494 K, 8.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 18 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   1%|          | 4/603 [01:47<4:42:18, 28.28s/it]
# Finding MLE Point...
# MLE Gridpoint: 11232 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   1%|          | 5/603 [02:07<4:15:53, 25.67s/it]
# Finding MLE Point...
# MLE Gridpoint: 30666 K, 7.65 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   1%|          | 6/603 [02:36<4:26:59, 26.83s/it]
# Finding MLE Point...
# MLE Gridpoint: 37393 K, 8.14 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 3 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#   1%|          | 7/603 [02:59<4:12:27, 25.42s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   1%|▏         | 8/603 [03:21<4:02:23, 24.44s/it]
# Finding MLE Point...
# MLE Gridpoint: 23191 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   1%|▏         | 9/603 [03:43<3:54:35, 23.70s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   2%|▏         | 10/603 [04:04<3:48:18, 23.10s/it]
# Finding MLE Point...
# MLE Gridpoint: 17212 K, 7.98 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   2%|▏         | 11/603 [04:25<3:39:30, 22.25s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   2%|▏         | 12/603 [04:50<3:48:11, 23.17s/it]
# Finding MLE Point...
# MLE Gridpoint: 8242 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   2%|▏         | 13/603 [05:10<3:37:14, 22.09s/it]
# Finding MLE Point...
# MLE Gridpoint: 12727 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   2%|▏         | 14/603 [05:36<3:48:39, 23.29s/it]
# Finding MLE Point...
# MLE Gridpoint: 50101 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   2%|▏         | 15/603 [06:04<4:02:46, 24.77s/it]
# Finding MLE Point...
# MLE Gridpoint: 14222 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 25 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 29 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 32 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 32 samples.
# Burning in 25 samples... (250 done)
# Autocorr Time = 32 samples.
# Burning in 25 samples... (275 done)
# Autocorr Time = 30 samples.
# Burning in 25 samples... (300 done)
# Autocorr Time = 31 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   3%|▎         | 16/603 [06:50<5:06:25, 31.32s/it]
# Finding MLE Point...
# MLE Gridpoint: 33656 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   3%|▎         | 17/603 [07:11<4:33:07, 27.97s/it]
# Finding MLE Point...
# MLE Gridpoint: 20202 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   3%|▎         | 18/603 [07:37<4:29:23, 27.63s/it]
# Finding MLE Point...
# MLE Gridpoint: 12727 K, 8.17 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   3%|▎         | 19/603 [08:00<4:13:38, 26.06s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 22 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   3%|▎         | 20/603 [08:37<4:46:50, 29.52s/it]
# Finding MLE Point...
# MLE Gridpoint: 9737 K, 8.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 19 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   3%|▎         | 21/603 [09:15<5:08:41, 31.82s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 9.17 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   4%|▎         | 22/603 [09:41<4:51:32, 30.11s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 8.17 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   4%|▍         | 23/603 [10:05<4:32:57, 28.24s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   4%|▍         | 24/603 [10:26<4:13:49, 26.30s/it]
# Finding MLE Point...
# MLE Gridpoint: 17212 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   4%|▍         | 25/603 [10:55<4:18:56, 26.88s/it]
# Finding MLE Point...
# MLE Gridpoint: 52343 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   4%|▍         | 26/603 [11:14<3:57:26, 24.69s/it]
# Finding MLE Point...
# MLE Gridpoint: 31414 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   4%|▍         | 27/603 [11:38<3:54:26, 24.42s/it]
# Finding MLE Point...
# MLE Gridpoint: 11979 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   5%|▍         | 28/603 [12:06<4:05:02, 25.57s/it]
# Finding MLE Point...
# MLE Gridpoint: 8242 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 24 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 25 samples.
# Burning in 25 samples... (250 done)
# Autocorr Time = 27 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   5%|▍         | 29/603 [12:48<4:51:58, 30.52s/it]
# Finding MLE Point...
# MLE Gridpoint: 29171 K, 8.02 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   5%|▍         | 30/603 [13:15<4:39:35, 29.28s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 16 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   5%|▌         | 31/603 [13:47<4:48:31, 30.26s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 17 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   5%|▌         | 32/603 [14:22<5:01:34, 31.69s/it]
# Finding MLE Point...
# MLE Gridpoint: 22444 K, 8.08 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 24 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 24 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 25 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 25 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   5%|▌         | 33/603 [15:02<5:23:38, 34.07s/it]
# Finding MLE Point...
# MLE Gridpoint: 12727 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   6%|▌         | 34/603 [15:24<4:48:01, 30.37s/it]
# Finding MLE Point...
# MLE Gridpoint: 14222 K, 8.26 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   6%|▌         | 35/603 [15:48<4:29:39, 28.48s/it]
# Finding MLE Point...
# MLE Gridpoint: 30666 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   6%|▌         | 36/603 [16:14<4:22:26, 27.77s/it]
# Finding MLE Point...
# MLE Gridpoint: 51595 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   6%|▌         | 37/603 [16:33<3:58:47, 25.31s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   6%|▋         | 38/603 [16:59<4:00:09, 25.50s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 8.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   6%|▋         | 39/603 [17:23<3:54:47, 24.98s/it]
# Finding MLE Point...
# MLE Gridpoint: 26181 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   7%|▋         | 40/603 [17:47<3:50:52, 24.61s/it]
# Finding MLE Point...
# MLE Gridpoint: 24686 K, 7.29 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   7%|▋         | 41/603 [18:06<3:35:39, 23.02s/it]
# Finding MLE Point...
# MLE Gridpoint: 33656 K, 7.68 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   7%|▋         | 42/603 [18:30<3:37:14, 23.23s/it]
# Finding MLE Point...
# MLE Gridpoint: 10484 K, 8.11 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   7%|▋         | 43/603 [18:52<3:32:15, 22.74s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.62 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   7%|▋         | 44/603 [19:13<3:28:43, 22.40s/it]
# Finding MLE Point...
# MLE Gridpoint: 25434 K, 7.98 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   7%|▋         | 45/603 [19:39<3:38:10, 23.46s/it]
# Finding MLE Point...
# MLE Gridpoint: 21696 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   8%|▊         | 46/603 [20:07<3:50:44, 24.85s/it]
# Finding MLE Point...
# MLE Gridpoint: 23939 K, 8.11 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   8%|▊         | 47/603 [20:27<3:34:59, 23.20s/it]
# Finding MLE Point...
# MLE Gridpoint: 57575 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   8%|▊         | 48/603 [20:50<3:36:23, 23.39s/it]
# Finding MLE Point...
# MLE Gridpoint: 14969 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   8%|▊         | 49/603 [21:14<3:37:41, 23.58s/it]
# Finding MLE Point...
# MLE Gridpoint: 20949 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   8%|▊         | 50/603 [21:43<3:50:12, 24.98s/it]
# Finding MLE Point...
# MLE Gridpoint: 8989 K, 8.56 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 24 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 25 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (250 done)
# Autocorr Time = 26 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   8%|▊         | 51/603 [22:24<4:35:16, 29.92s/it]
# Finding MLE Point...
# MLE Gridpoint: 26181 K, 7.20 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   9%|▊         | 52/603 [22:46<4:11:53, 27.43s/it]
# Finding MLE Point...
# MLE Gridpoint: 29171 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   9%|▉         | 53/603 [23:07<3:55:15, 25.67s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#   9%|▉         | 54/603 [23:29<3:43:25, 24.42s/it]
# Finding MLE Point...
# MLE Gridpoint: 10484 K, 8.47 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   9%|▉         | 55/603 [23:55<3:47:09, 24.87s/it]
# Finding MLE Point...
# MLE Gridpoint: 32909 K, 7.26 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#   9%|▉         | 56/603 [24:14<3:31:38, 23.22s/it]
# Finding MLE Point...
# MLE Gridpoint: 21696 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 18 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#   9%|▉         | 57/603 [24:51<4:08:38, 27.32s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 7.77 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  10%|▉         | 58/603 [25:15<3:58:23, 26.25s/it]
# Finding MLE Point...
# MLE Gridpoint: 25434 K, 7.71 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  10%|▉         | 59/603 [25:34<3:39:18, 24.19s/it]
# Finding MLE Point...
# MLE Gridpoint: 8989 K, 8.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 15 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  10%|▉         | 60/603 [26:10<4:10:40, 27.70s/it]
# Finding MLE Point...
# MLE Gridpoint: 35898 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  10%|█         | 61/603 [26:41<4:18:20, 28.60s/it]
# Finding MLE Point...
# MLE Gridpoint: 22444 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  10%|█         | 62/603 [27:07<4:10:51, 27.82s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 16 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  10%|█         | 63/603 [27:42<4:31:18, 30.14s/it]
# Finding MLE Point...
# MLE Gridpoint: 20949 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  11%|█         | 64/603 [28:08<4:19:14, 28.86s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 13 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  11%|█         | 65/603 [28:41<4:29:54, 30.10s/it]
# Finding MLE Point...
# MLE Gridpoint: 6000 K, 9.02 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
# W1006 19:57:49.055336 4368008640 corner.py:542] Too few points to create valid contours
#
#
#
#
#  11%|█         | 66/603 [29:05<4:11:46, 28.13s/it]
# Finding MLE Point...
# MLE Gridpoint: 21696 K, 7.71 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  11%|█         | 67/603 [29:33<4:11:19, 28.13s/it]
# Finding MLE Point...
# MLE Gridpoint: 14969 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  11%|█▏        | 68/603 [30:02<4:13:14, 28.40s/it]
# Finding MLE Point...
# MLE Gridpoint: 11979 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  11%|█▏        | 69/603 [30:33<4:20:33, 29.28s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  12%|█▏        | 70/603 [31:02<4:17:47, 29.02s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  12%|█▏        | 71/603 [31:30<4:15:47, 28.85s/it]
# Finding MLE Point...
# MLE Gridpoint: 22444 K, 8.44 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  12%|█▏        | 72/603 [31:56<4:06:54, 27.90s/it]
# Finding MLE Point...
# MLE Gridpoint: 32161 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 17 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  12%|█▏        | 73/603 [32:31<4:26:58, 30.22s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  12%|█▏        | 74/603 [33:00<4:23:10, 29.85s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 18 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  12%|█▏        | 75/603 [33:39<4:46:10, 32.52s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  13%|█▎        | 76/603 [34:08<4:34:59, 31.31s/it]
# Finding MLE Point...
# MLE Gridpoint: 29919 K, 8.65 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  13%|█▎        | 77/603 [34:36<4:27:45, 30.54s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  13%|█▎        | 78/603 [35:03<4:17:35, 29.44s/it]
# Finding MLE Point...
# MLE Gridpoint: 23191 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  13%|█▎        | 79/603 [35:27<4:03:36, 27.89s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 14 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  13%|█▎        | 80/603 [36:01<4:18:11, 29.62s/it]
# Finding MLE Point...
# MLE Gridpoint: 25434 K, 7.71 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 15 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  13%|█▎        | 81/603 [36:35<4:28:42, 30.89s/it]
# Finding MLE Point...
# MLE Gridpoint: 34404 K, 8.08 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  14%|█▎        | 82/603 [37:06<4:29:01, 30.98s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.32 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  14%|█▍        | 83/603 [37:30<4:10:35, 28.91s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 19 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  14%|█▍        | 84/603 [38:09<4:35:53, 31.90s/it]
# Finding MLE Point...
# MLE Gridpoint: 31414 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 13 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  14%|█▍        | 85/603 [38:42<4:39:10, 32.34s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  14%|█▍        | 86/603 [39:11<4:28:39, 31.18s/it]
# Finding MLE Point...
# MLE Gridpoint: 20949 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  14%|█▍        | 87/603 [39:35<4:09:43, 29.04s/it]
# Finding MLE Point...
# MLE Gridpoint: 35151 K, 7.29 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 13 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  15%|█▍        | 88/603 [40:09<4:21:37, 30.48s/it]
# Finding MLE Point...
# MLE Gridpoint: 12727 K, 7.77 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 3 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  15%|█▍        | 89/603 [40:32<4:02:41, 28.33s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  15%|█▍        | 90/603 [40:59<3:57:29, 27.78s/it]
# Finding MLE Point...
# MLE Gridpoint: 23939 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  15%|█▌        | 91/603 [41:27<3:59:07, 28.02s/it]
# Finding MLE Point...
# MLE Gridpoint: 7494 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  15%|█▌        | 92/603 [41:51<3:48:23, 26.82s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 8.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  15%|█▌        | 93/603 [42:13<3:35:11, 25.32s/it]
# Finding MLE Point...
# MLE Gridpoint: 8989 K, 8.47 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 15 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  16%|█▌        | 94/603 [42:44<3:48:43, 26.96s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  16%|█▌        | 95/603 [43:10<3:46:28, 26.75s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 16 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  16%|█▌        | 96/603 [43:48<4:13:26, 29.99s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  16%|█▌        | 97/603 [44:14<4:04:14, 28.96s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 17 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  16%|█▋        | 98/603 [44:50<4:20:00, 30.89s/it]
# Finding MLE Point...
# MLE Gridpoint: 40383 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  16%|█▋        | 99/603 [45:18<4:13:09, 30.14s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 22 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  17%|█▋        | 100/603 [45:58<4:37:56, 33.15s/it]
# Finding MLE Point...
# MLE Gridpoint: 38141 K, 8.23 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 22 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 20 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  17%|█▋        | 101/603 [46:39<4:55:53, 35.36s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  17%|█▋        | 102/603 [47:02<4:26:25, 31.91s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 7.98 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  17%|█▋        | 103/603 [47:24<3:59:04, 28.69s/it]
# Finding MLE Point...
# MLE Gridpoint: 7494 K, 8.35 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 12 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  17%|█▋        | 104/603 [47:53<4:00:57, 28.97s/it]
# Finding MLE Point...
# MLE Gridpoint: 28424 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  17%|█▋        | 105/603 [48:14<3:39:17, 26.42s/it]
# Finding MLE Point...
# MLE Gridpoint: 10484 K, 8.08 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# ...
# Autocorr Time = 15 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 15 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  95%|█████████▍| 570/603 [4:25:57<18:20, 33.34s/it]
# Finding MLE Point...
# MLE Gridpoint: 20949 K, 8.08 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  95%|█████████▍| 571/603 [4:26:24<16:46, 31.45s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  95%|█████████▍| 572/603 [4:26:48<15:02, 29.10s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 8.02 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  95%|█████████▌| 573/603 [4:27:13<13:55, 27.84s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.95 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  95%|█████████▌| 574/603 [4:27:43<13:49, 28.61s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.77 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 16 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  95%|█████████▌| 575/603 [4:28:19<14:18, 30.67s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.77 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  96%|█████████▌| 576/603 [4:28:46<13:16, 29.48s/it]
# Finding MLE Point...
# MLE Gridpoint: 29171 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 9 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  96%|█████████▌| 577/603 [4:29:15<12:48, 29.56s/it]
# Finding MLE Point...
# MLE Gridpoint: 19454 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 18 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  96%|█████████▌| 578/603 [4:29:53<13:16, 31.86s/it]
# Finding MLE Point...
# MLE Gridpoint: 26929 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  96%|█████████▌| 579/603 [4:30:22<12:24, 31.00s/it]
# Finding MLE Point...
# MLE Gridpoint: 13474 K, 8.56 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 14 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  96%|█████████▌| 580/603 [4:30:55<12:12, 31.84s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.92 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 10 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  96%|█████████▋| 581/603 [4:31:26<11:32, 31.48s/it]
# Finding MLE Point...
# MLE Gridpoint: 23191 K, 7.98 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 15 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 17 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  97%|█████████▋| 582/603 [4:32:02<11:27, 32.72s/it]
# Finding MLE Point...
# MLE Gridpoint: 26181 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 3 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  97%|█████████▋| 583/603 [4:32:24<09:55, 29.76s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.71 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 27 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 28 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 27 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 27 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 27 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 28 samples.
# Burning in 25 samples... (250 done)
# Autocorr Time = 31 samples.
# Burning in 25 samples... (275 done)
# Autocorr Time = 29 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  97%|█████████▋| 584/603 [4:33:11<11:01, 34.79s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 8.53 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 16 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 16 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  97%|█████████▋| 585/603 [4:33:47<10:31, 35.10s/it]
# Finding MLE Point...
# MLE Gridpoint: 48606 K, 8.62 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 12 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 17 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 18 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 14 samples.
# Burn-in terminated with correlation fraction = 0.06
# Sampling 100 draws from posterior
#  97%|█████████▋| 586/603 [4:34:26<10:19, 36.44s/it]
# Finding MLE Point...
# MLE Gridpoint: 14222 K, 8.26 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 10 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  97%|█████████▋| 587/603 [4:34:57<09:15, 34.75s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 8.47 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  98%|█████████▊| 588/603 [4:35:21<07:49, 31.33s/it]
# Finding MLE Point...
# MLE Gridpoint: 25434 K, 8.44 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 11 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 11 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  98%|█████████▊| 589/603 [4:35:51<07:14, 31.00s/it]
# Finding MLE Point...
# MLE Gridpoint: 25434 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 23 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 25 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 27 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (225 done)
# Autocorr Time = 26 samples.
# Burning in 25 samples... (250 done)
# Autocorr Time = 27 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  98%|█████████▊| 590/603 [4:36:35<07:33, 34.91s/it]
# Finding MLE Point...
# MLE Gridpoint: 10484 K, 8.11 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  98%|█████████▊| 591/603 [4:37:00<06:24, 32.01s/it]
# Finding MLE Point...
# MLE Gridpoint: 8242 K, 8.41 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 6 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  98%|█████████▊| 592/603 [4:37:25<05:27, 29.77s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 8.05 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
#  98%|█████████▊| 593/603 [4:37:52<04:50, 29.07s/it]
# Finding MLE Point...
# MLE Gridpoint: 29171 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 6 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  99%|█████████▊| 594/603 [4:38:18<04:13, 28.12s/it]
# Finding MLE Point...
# MLE Gridpoint: 29171 K, 7.89 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  99%|█████████▊| 595/603 [4:38:45<03:41, 27.71s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 8.02 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  99%|█████████▉| 596/603 [4:39:10<03:08, 26.99s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.80 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 2 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
#  99%|█████████▉| 597/603 [4:39:30<02:29, 24.97s/it]
# Finding MLE Point...
# MLE Gridpoint: 16464 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 5 samples.
# Burn-in terminated with correlation fraction = 0.07
# Sampling 100 draws from posterior
#  99%|█████████▉| 598/603 [4:39:55<02:05, 25.01s/it]
# Finding MLE Point...
# MLE Gridpoint: 17959 K, 7.83 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 4 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 9 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 13 samples.
# Burning in 25 samples... (100 done)
# Autocorr Time = 19 samples.
# Burning in 25 samples... (125 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (150 done)
# Autocorr Time = 21 samples.
# Burning in 25 samples... (175 done)
# Autocorr Time = 20 samples.
# Burning in 25 samples... (200 done)
# Autocorr Time = 19 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
#  99%|█████████▉| 599/603 [4:40:33<01:55, 28.89s/it]
# Finding MLE Point...
# MLE Gridpoint: 20949 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
# 100%|█████████▉| 600/603 [4:40:55<01:20, 26.82s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.86 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 5 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 8 samples.
# Burning in 25 samples... (75 done)
# Autocorr Time = 8 samples.
# Burn-in terminated with correlation fraction = 0.09
# Sampling 100 draws from posterior
# 100%|█████████▉| 601/603 [4:41:21<00:53, 26.61s/it]
# Finding MLE Point...
# MLE Gridpoint: 15717 K, 7.47 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 7 samples.
# Burning in 25 samples... (50 done)
# Autocorr Time = 7 samples.
# Burn-in terminated with correlation fraction = 0.10
# Sampling 100 draws from posterior
# 100%|█████████▉| 602/603 [4:41:45<00:25, 25.79s/it]
# Finding MLE Point...
# MLE Gridpoint: 18707 K, 7.74 dex
# Burning in 25 samples... (0 done)
# Autocorr Time = 3 samples.
# Burning in 25 samples... (25 done)
# Autocorr Time = 4 samples.
# Burn-in terminated with correlation fraction = 0.08
# Sampling 100 draws from posterior
# 100%|██████████| 603/603 [4:42:07<00:00, 24.55s/it]

# %%
results = np.asarray(results)
mles = results[:,1]
lowers = results[:,4]
uppers = results[:,5]
stds = results[:,6]
chi2s = results[:,7]/(4000 - 3)

# %% [markdown]
# ### Compare to Tremblay

# %%
plt.rcParams.update({'font.size': 22})

mlespec_Teff = [i[0] for i in mles]
lowspec_Teff = [i[0] for i in stds]
highspec_Teff = [i[0] for i in stds]
plt.figure(figsize=(15,5))
plt.subplot(121)
resid = wdtable['spec_Teff'][0:len(mles)]-mlespec_Teff
rms = np.sqrt(np.mean(resid**2))
f = plt.scatter(wdtable['spec_Teff'][0:len(mles)],mlespec_Teff, c = wdtable['log_g'][0:len(mles)])
plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');

# %%
plt.rcParams.update({'font.size': 27})
mlespec_Teff = [i[0] for i in mles]
mask = np.asarray(mlespec_Teff) < 25000
resid = wdtable['spec_Teff'][0:len(mles)]-mlespec_Teff
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['spec_Teff'][0:len(mles)],mlespec_Teff, yerr = (lowspec_Teff,highspec_Teff), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Tremblay $T_{eff}$ (K)')
plt.ylabel('Fitted $T_{eff}$ (K)')
# Out:
# Text(0, 0.5, 'Fitted $T_{eff}$ (K)')

# %%
## REPLACE TREMBLAY ERRRORS HERE
plt.rcParams.update({'font.size': 30})
mlespec_Teff = [i[0] for i in mles]
mask = (np.abs(wdtable['teff_resids']) < 1000)
resid = wdtable['spec_Teff'][0:len(mles)][mask]-np.asarray(mlespec_Teff)[mask]
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
f.tick_params(top = True,right = True)
plt.errorbar(wdtable['spec_Teff'][0:len(mles)][mask],np.asarray(mlespec_Teff)[mask],\
    yerr = (np.asarray(lowspec_Teff)[mask],np.asarray(highspec_Teff)[mask]), linestyle = 'None', marker = '.',\
            color = 'k', ecolor = 'c', capsize = 3, markersize = 3,\
    xerr = (np.repeat(500,len(mask))[mask],np.repeat(500,len(mask))[mask] ))
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Tremblay $T_{\mathrm{eff}}$ (K)')
plt.ylabel('Fitted $T_{\mathrm{eff}}$ (K)')
f.yaxis.set_ticks(np.arange(5000,50000,10000));
f.xaxis.set_ticks(np.arange(5000,50000,10000));
plt.savefig('teffcompare.pdf')

# %%
mlespec_logg = [i[1] for i in mles]
lowspec_logg = [i[1] for i in stds]
highspec_logg = [i[1] for i in stds]
plt.figure(figsize=(15,5))
resid = wdtable['spec_logg'][0:len(mles)]-mlespec_logg
rms = np.sqrt(np.mean(resid**2))
plt.subplot(121)
f = plt.scatter(wdtable['spec_logg'][0:len(mles)],mlespec_logg, c = chi2s, cmap = 'cool')
plt.colorbar()
plt.text(0.4,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');
plt.tight_layout()

# %%
mlespec_logg = [i[1] for i in mles]
resid = wdtable['spec_logg'][0:len(mles)]-mlespec_logg
mask = np.abs(wdtable['logg_resids']) < 0.5
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['spec_logg'][0:len(mles)][mask],np.asarray(mlespec_logg)[mask], yerr = (np.asarray(lowspec_logg)[mask],np.asarray(highspec_logg)[mask]), linestyle = 'None', marker = '.',\
            color = 'k', ecolor = 'c', capsize = 3,\
            markersize= 3, xerr = (np.repeat(0.06,len(mask))[mask], np.repeat(0.06,len(mask))[mask]))
#plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Tremblay $\log{g}$ (dex)')
plt.ylabel('Fitted $\log{g}$ (dex)')
f.tick_params(top = True,right = True);
plt.savefig('logcomp.pdf')

# %%
wdtable['logg_resids'] = wdtable['spec_logg'][0:len(mles)]-mlespec_logg

# %%
wdtable['teff_resids'] = wdtable['spec_Teff'][0:len(mles)]-mlespec_Teff

# %%
wdtable[np.abs(wdtable['logg_resids']) > 0.8]
# Out:
# <Table masked=True length=5>
#  white_dwarf_name_1_1          designation          ...     teff_resids
#                                                     ...
#        bytes23                   bytes28            ...       float64
# ---------------------- ---------------------------- ... -------------------
# WDJ160217.00+163023.21 Gaia DR2 1199192840852373376 ... -49.700605045380144
# WDJ134734.82-005226.61 Gaia DR2 3662004943247662720 ...   4844.971015529727
# WDJ152839.45+011300.07 Gaia DR2 4417843183603168640 ...  3228.6027357632847
# WDJ134734.82-005226.61 Gaia DR2 3662004943247662720 ...    4805.12897404367
# WDJ152839.45+011300.07 Gaia DR2 4417843183603168640 ...   3188.265982091478

# %% [raw]
# pickle.dump(results,open('223wdfits.p','wb'))

# %%
results = pickle.load(open('223wdfits.p','rb'))

# %% [markdown]
# ### Compare to Fusilio

# %%
mleteff = [i[0] for i in mles]
lowteff = [i[0] for i in stds]
highteff = [i[0] for i in stds]
plt.figure(figsize=(15,5))
plt.subplot(121)
resid = wdtable['Teff'][0:len(mles)]-mleteff
rms = np.sqrt(np.mean(resid**2))
f = plt.scatter(wdtable['Teff'][0:len(mles)],mleteff, color = 'k')
plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');

# %%
mleteff = [i[0] for i in mles]
resid = wdtable['Teff'][0:len(mles)]-mleteff
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['Teff'][0:len(mles)],mleteff, yerr = (lowteff,highteff), linestyle = 'None', marker = '+',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %i K'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'k--')
plt.xlabel('Gaia $T_{eff}$ (K)')
plt.ylabel('Fitted $T_{eff}$ (K)')
# Out:
# Text(0, 0.5, 'Fitted $T_{eff}$ (K)')

# %%
mlelog_g = [i[1] for i in mles]
lowlog_g = [i[1] for i in stds]
highlog_g = [i[1] for i in stds]
plt.figure(figsize=(15,5))
resid = wdtable['log_g'][0:len(mles)]-mlelog_g
rms = np.sqrt(np.mean(resid**2))
plt.subplot(121)
f = plt.scatter(wdtable['log_g'][0:len(mles)],mlelog_g)
plt.text(0.6,0.1,'rms: %.3f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.subplot(122)
plt.hist(resid, histtype = 'step');
plt.tight_layout()

# %%
mlelog_g = [i[1] for i in mles]
resid = wdtable['log_g'][0:len(mles)]-mlelog_g
rms = np.sqrt(np.mean(resid**2))
plt.figure(figsize = (15,10))
f = plt.subplot(111)
plt.errorbar(wdtable['log_g'][0:len(mles)],mlelog_g, yerr = (lowlog_g,highlog_g), linestyle = 'None', marker = '.',\
            color = 'k', ecolor = 'c', capsize = 3)
#plt.text(0.6,0.1,'rms: %.2f dex'%rms,transform = f.axes.transAxes)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')
plt.xlabel('Gaia $\log{g}$ (dex)')
plt.ylabel('Fitted $\log{g}$ (dex)')
# Out:
# Text(0, 0.5, 'Fitted $\\log{g}$ (dex)')
