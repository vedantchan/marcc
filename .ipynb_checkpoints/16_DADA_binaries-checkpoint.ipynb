# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [10, 7]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle
import h5py
import multiprocessing
import itertools
from multiprocessing import sharedctypes
import scipy
from PyAstronomy.pyasl import dopplerShift
from astroquery.sdss import SDSS
from astropy.coordinates import SkyCoord
import glob
import astropy.io.votable as votable
from PyAstronomy.pyasl import crosscorrRV, quadExtreme
# %matplotlib inline
# Out:
# /Users/vedantchandra/anaconda3/lib/python3.7/site-packages/astroquery/sdss/__init__.py:29: UserWarning: Experimental: SDSS has not yet been refactored to have its API match the rest of astroquery (but it's nearly there).
#   warnings.warn("Experimental: SDSS has not yet been refactored to have its API "

# %% [raw]
# VO = votable.parse_single_table('xmatch.vot')

# %% [raw]
# table = VO.to_table()

# %% [raw]
# table.remove_columns(['epoch_photometry_url','datalink_url','designation','phot_variable_flag'])

# %% [raw]
# table.write('xmatch.fits', overwrite = True)

# %%
table = Table.read('filetable.fits')

# %%
table
# Out:
# <Table masked=True length=26606>
#   white_dwarf_name_1   ...
#        bytes23         ...
# ---------------------- ...
# WDJ025854.43+003040.34 ...
# WDJ030342.24+005310.43 ...
# WDJ030451.07+010644.99 ...
# WDJ025709.00+004627.95 ...
# WDJ025740.28+005103.15 ...
# WDJ025746.40+010106.05 ...
# WDJ025645.67+005321.34 ...
# WDJ025942.60+043849.21 ...
# WDJ031602.35+043228.05 ...
# WDJ031646.27+044553.90 ...
#                    ... ...
# WDJ204559.64-062441.05 ...
# WDJ204658.84-055100.04 ...
# WDJ204349.78-060511.49 ...
# WDJ204546.81-054355.62 ...
# WDJ204642.89-053816.63 ...
# WDJ204738.99-052332.62 ...
# WDJ204724.87-051910.93 ...
# WDJ205515.90-051841.77 ...
# WDJ204421.20-051856.00 ...
# WDJ204140.74-045234.88 ...

# %% [markdown]
# ## Classification Cuts - White Dwarfs, Main Sequence, Uncertain Region

# %% [markdown]
# #### Define Spectrum Processing Functions

# %%
spec_files = glob.glob('ks_spec/*')
lamgrid = np.arange(4000,8000)

def planck(wl,c1,c2):
    return 1e21*c1 / (wl**5 * (np.exp(1e4*c2/wl) - 1 ))

def planck(wl, c1, c2):
    return c1*wl + c2

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

def get_raw_spectrum(source_id):
    path = table[table['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        raise OSError('Spectrum file missing...')
    
    return lam,flux#,fluxsig


def continuum_normalize(flux,lam,sigarray = None):
    spec = flux
    pixels = lam-4000
    continuum = (pixels > 2900) + (pixels < 2200)*(pixels > 1050) + (pixels < 650)*(pixels > 530) \
             + (pixels < 220)*(pixels > 200) + (pixels < 35)*(pixels > 20) + (pixels < -200)*(pixels > -450)
    
    notnan = (~np.isnan(spec))+(~np.isnan(lam))
    skylinemask = (lam > 5578.5 - 10)*(lam < 5578.5 + 10) + (lam > 5894.6 - 10)*(lam < 5894.6 + 10)\
        + (lam > 6301.7 - 10)*(lam < 6301.7 + 10) + (lam > 7246.0 - 10)*(lam < 7246.0 + 10)
        
    pwfunc = pwlf.PiecewiseLinFit(lam[continuum*notnan],spec[continuum*notnan])
    breakpoints = np.asarray([-350,-200,20,35,200,220,400,530,650,850,1050,1400,1800,2200,2900,3200,3400,3800]) + 4000
    breaks = pwfunc.fit_with_breaks(breakpoints)
    cont = pwfunc.predict(lam)
    contcorr = spec / cont
    contcorr[skylinemask] = 1
    where = np.isnan(contcorr)+(contcorr > 1.25) + (contcorr < 0)
    contcorr[where] = 1
    if sigarray is not None:
        stdev = np.sqrt(1.0/sigarray)
        contsigarray = stdev / cont
        normivar = (1.0/contsigarray)**2
        return contcorr,normivar
    
#     plt.figure(figsize = (15,5))
#     plt.plot(lam[continuum*notnan],spec[continuum*notnan])
#     plt.plot(lam,cont)
#     plt.figure(figsize = (15,5))
#     plt.plot(contcorr)
#     plt.plot(continuum)
#     plt.figure(figsize = (15,5))
    return contcorr

def rv_corr(normflux,lam):
    alphaline = find_nearest(lam,halpha)
    betaline = find_nearest(lam,hbeta)
    gammaline = find_nearest(lam,hgamma)
    deltaline = find_nearest(lam,hdelta)
    cores = (lam == alphaline) + (lam == betaline) + (lam == gammaline) + (lam == deltaline)
    cores = cores.astype(int)
    xcorrs = crosscorrRV(lam,1-normflux,lam,cores, -100, 100, 5, 'doppler', skipedge = 25)
    corrs = xcorrs[1]
    rvs = xcorrs[0]
    try:
        specrv = quadExtreme(rvs,corrs, 'max', (10,10), fullOutput = True)[0]
    except:
        specrv = 0
    shift_flux,shift_lam = dopplerShift(lam,normflux,specrv, edgeHandling = 'fillValue', fillValue = 1)
    return shift_flux,shift_lam

def interpolate_flux(normflux,lam):
    func = interp1d(lam,normflux,kind='linear',assume_sorted = True)
    interpflux = func(lamgrid)
    return interpflux

def get_spectrum(source_id):
    path = table[table['source_id'] == source_id][0]['specpath']
    try:
        with fits.open(path) as f:
            flux = f[1].data['flux']
            loglam = f[1].data['loglam']
            fluxsig = f[1].data['ivar']
            lam = 10**loglam
            f.close()
    except:
        raise FileNotFoundError('Spectrum file missing...')
        return
    ## RV Correction and Interpolation
    
    normalized_spectrum = continuum_normalize(flux,lam)
    rv_corrected_flux,rv_corrected_lam = rv_corr(normalized_spectrum,lam)
    interpolated_flux = interpolate_flux(rv_corrected_flux, rv_corrected_lam)
    
    return interpolated_flux

# %%
plt.plot(lamgrid,get_spectrum(table['source_id'][7543]))

# %% [markdown]
# ## Build Dataset

# %% [markdown]
# ##### For this demonstration, we are training a binary classifier to identify DA white dwarf spectra that are 1) identified as DA by Kepler AND 2) belong in the high-confidence white dwarf section of our color magnitude diagram. During the training step, the model is fed both high-confidence sdA's and high-confidence DA's - where Kepler's labels agree with our visual expectation from the CMD. Later on, we will apply this classifier to stars in the uncertain strip between the main sequence and white dwarf tracks.

# %%
filetable = table

DA = filetable['spectral_class'] == 'DA'
filetable = filetable[DA]
len(filetable)
# Out:
# 15491

# %%
spectra = [];
for jj in tqdm(range(len(filetable))):
    obj = filetable[jj]
    try:
        spec = get_spectrum(obj['source_id'])
        spectra.append(spec)
    except:
        spectra.append(np.repeat(np.nan,4000))
# Out:
# 100%|██████████| 15491/15491 [11:32<00:00, 22.38it/s]

# %%
spectra = np.asarray(spectra)
len(spectra)
cleanspec = ~np.max(np.isnan(spectra),1)
cleantable = filetable[cleanspec]
cleanspectra = spectra[cleanspec]

# %%
def make_binary(spectrum1, spectrum2, relrv, relfraction):
    spectrum2 = dopplerShift(lamgrid,spectrum2,relrv, edgeHandling = 'fillValue', fillValue = 1)
    func = interp1d(spectrum2[1],spectrum2[0], fill_value = 'extrapolate', kind = 'linear')
    spectrum2 = func(lamgrid)
    binary = relfraction*spectrum1 + (1-relfraction)*spectrum2
    return binary

# %%
ii = np.random.randint(len(cleantable))
jj = np.random.randint(len(cleantable))
rv = np.random.randint(-1000,1000)
frac = 0.5

plt.figure(figsize = (15,5))
plt.title('Components')
plt.plot(cleanspectra[ii])
plt.plot(cleanspectra[jj]+1)

plt.figure(figsize = (15,5))
plt.plot(make_binary(cleanspectra[ii],cleanspectra[jj],rv,frac))
plt.title('Composite Binary')
# Out:
# Text(0.5, 1.0, 'Composite Binary')

# %%
def generate_random_binary():
    ii = np.random.randint(0, len(cleanspectra))
    jj = np.random.randint(0, len(cleanspectra))
    rv = np.random.randint(-1000,1000) ### Parameterize this with actual RV distribution
    frac = np.random.random()
    return make_binary(cleanspectra[ii], cleanspectra[jj], rv, frac)
def generate_random_single():
    ii = np.random.randint(0, len(cleanspectra))
    return cleanspectra[ii]

# %%
plt.plot(generate_random_binary())

# %%
def samplegen(coinflip):
    if coinflip == 0:
        return generate_random_single()
    elif coinflip == 1:
        return generate_random_binary()

# %%
def batchgen(batchsize):
    coinflips = np.random.binomial(1, 0.5, batchsize)
    samples = np.asarray([samplegen(coinflip) for coinflip in coinflips])
    return samples, coinflips

# %% [markdown]
# ## Bayesian Neural Network Classifier

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler,OneHotEncoder
import astroNN.nn.layers as annlayers
import astroNN.nn.losses as annlosses
from sklearn.metrics import roc_curve, roc_auc_score, auc
# Out:
# Using TensorFlow backend.

# %%
reg = 1e-10

def nn():
    x = Input(shape=(4000,))
    y = Dense(256,activation='relu', kernel_regularizer = l2(reg))(x)
    #y = annlayers.MCDropout(0.1)(y)
    y = Dense(128,activation='relu', kernel_regularizer = l2(reg))(y)
    #y = annlayers.MCDropout(0.1)(y)
    y = Dense(64,activation='relu',kernel_regularizer = l2(reg))(y)
    #y = annlayers.MCDropout(0.1)(y)
    y = Dense(32,activation='relu',kernel_regularizer = l2(reg))(y)

    out = Dense(2,activation='softmax')(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adamax(), loss = 'binary_crossentropy', \
                  metrics = ['binary_accuracy'])
    return model

history = np.asarray([]);
vhistory = np.asarray([]);
model = nn()
#model.load_weights('corbett.h5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4000)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               1024256
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 1,067,554
# Trainable params: 1,067,554
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
encoder = OneHotEncoder(categories = 'auto')
batchsize = 50000


for i in tqdm(range(1000)): 
    print('Training batch %i'%i)
    X_train,y_train = batchgen(batchsize)
    y_train = encoder.fit_transform(y_train.reshape(-1,1)).toarray()
    n_epochs = 10
    minibatchsize = 64

    print('Stochastic sample generated...')
    h = model.fit(X_train,y_train, epochs = n_epochs, verbose = 1, batch_size = minibatchsize)
    history = np.append(history, h.history['binary_accuracy'])
    vhistory = np.append(vhistory, h.history['loss'])
    model.save_weights('corbett.h5')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training batch 0
# W1031 17:26:40.330940 4557010368 deprecation_wrapper.py:119] From /Users/vedantchandra/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.6943 - binary_accuracy: 0.5763
# Epoch 2/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.6092 - binary_accuracy: 0.6645
# Epoch 3/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.5747 - binary_accuracy: 0.6936
# Epoch 4/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.5522 - binary_accuracy: 0.7135
# Epoch 5/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.5449 - binary_accuracy: 0.7202
# Epoch 6/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.5292 - binary_accuracy: 0.7268
# Epoch 7/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.5112 - binary_accuracy: 0.7379
# Epoch 8/10
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.4896 - binary_accuracy: 0.7511
# Epoch 9/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.4881 - binary_accuracy: 0.7527
# Epoch 10/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.4784 - binary_accuracy: 0.7586
#   0%|          | 1/1000 [02:08<35:33:01, 128.11s/it]
# Training batch 1
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 239us/step - loss: 0.4789 - binary_accuracy: 0.7603
# Epoch 2/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.4727 - binary_accuracy: 0.7611
# Epoch 3/10
# 50000/50000 [==============================] - 12s 235us/step - loss: 0.4747 - binary_accuracy: 0.7610
# Epoch 4/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4721 - binary_accuracy: 0.7648
# Epoch 5/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.4640 - binary_accuracy: 0.7698
# Epoch 6/10
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.4618 - binary_accuracy: 0.7720
# Epoch 7/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4598 - binary_accuracy: 0.7724
# Epoch 8/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4549 - binary_accuracy: 0.7742
# Epoch 9/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4514 - binary_accuracy: 0.7787
# Epoch 10/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4548 - binary_accuracy: 0.7752
#   0%|          | 2/1000 [04:17<35:37:11, 128.49s/it]
# Training batch 2
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.4622 - binary_accuracy: 0.7710
# Epoch 2/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.4581 - binary_accuracy: 0.7733
# Epoch 3/10
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.4581 - binary_accuracy: 0.7732
# Epoch 4/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.4634 - binary_accuracy: 0.7674
# Epoch 5/10
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.4536 - binary_accuracy: 0.7763
# Epoch 6/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.4502 - binary_accuracy: 0.7785
# Epoch 7/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4506 - binary_accuracy: 0.7773
# Epoch 8/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4460 - binary_accuracy: 0.7780
# Epoch 9/10
# 50000/50000 [==============================] - 10s 205us/step - loss: 0.4447 - binary_accuracy: 0.7794
# Epoch 10/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4432 - binary_accuracy: 0.7802
#   0%|          | 3/1000 [06:21<35:13:05, 127.17s/it]
# Training batch 3
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 10s 207us/step - loss: 0.4538 - binary_accuracy: 0.7772
# Epoch 2/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4469 - binary_accuracy: 0.7802
# Epoch 3/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4443 - binary_accuracy: 0.7815
# Epoch 4/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4420 - binary_accuracy: 0.7836
# Epoch 5/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4438 - binary_accuracy: 0.7818
# Epoch 6/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4416 - binary_accuracy: 0.7827
# Epoch 7/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4402 - binary_accuracy: 0.7846
# Epoch 8/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4380 - binary_accuracy: 0.7853
# Epoch 9/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.4362 - binary_accuracy: 0.7886
# Epoch 10/10
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.4373 - binary_accuracy: 0.7880
#   0%|          | 4/1000 [08:25<34:52:47, 126.07s/it]
# Training batch 4
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 250us/step - loss: 0.4447 - binary_accuracy: 0.7816
# Epoch 2/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.4494 - binary_accuracy: 0.7760
# Epoch 3/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4366 - binary_accuracy: 0.7875
# Epoch 4/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.4406 - binary_accuracy: 0.7834
# Epoch 5/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.4386 - binary_accuracy: 0.7850
# Epoch 6/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4333 - binary_accuracy: 0.7859
# Epoch 7/10
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.4363 - binary_accuracy: 0.7868
# Epoch 8/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.4399 - binary_accuracy: 0.7845
# Epoch 9/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.4296 - binary_accuracy: 0.7905
# Epoch 10/10
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.4309 - binary_accuracy: 0.7908
#   0%|          | 5/1000 [10:32<34:58:44, 126.56s/it]
# Training batch 5
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.4375 - binary_accuracy: 0.7880
# Epoch 2/10
# 50000/50000 [==============================] - 13s 265us/step - loss: 0.4438 - binary_accuracy: 0.7827
# Epoch 3/10
# 50000/50000 [==============================] - 12s 247us/step - loss: 0.4304 - binary_accuracy: 0.7930
# Epoch 4/10
# 50000/50000 [==============================] - 12s 239us/step - loss: 0.4372 - binary_accuracy: 0.7876
# Epoch 5/10
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.4315 - binary_accuracy: 0.7905
# Epoch 6/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.4306 - binary_accuracy: 0.7917
# Epoch 7/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.4241 - binary_accuracy: 0.7981
# Epoch 8/10
# 50000/50000 [==============================] - 12s 245us/step - loss: 0.4277 - binary_accuracy: 0.7939
# Epoch 9/10
# 50000/50000 [==============================] - 12s 248us/step - loss: 0.4234 - binary_accuracy: 0.7969
# Epoch 10/10
# 50000/50000 [==============================] - 14s 284us/step - loss: 0.4308 - binary_accuracy: 0.7908
#   1%|          | 6/1000 [12:48<35:42:18, 129.31s/it]
# Training batch 6
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.4336 - binary_accuracy: 0.7910
# Epoch 2/10
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.4332 - binary_accuracy: 0.7894
# Epoch 3/10
# 50000/50000 [==============================] - 13s 256us/step - loss: 0.4310 - binary_accuracy: 0.7929
# Epoch 4/10
# 50000/50000 [==============================] - 12s 250us/step - loss: 0.4312 - binary_accuracy: 0.7916
# Epoch 5/10
# 50000/50000 [==============================] - 12s 248us/step - loss: 0.4306 - binary_accuracy: 0.7921
# Epoch 6/10
# 50000/50000 [==============================] - 13s 261us/step - loss: 0.4265 - binary_accuracy: 0.7954
# Epoch 7/10
# 50000/50000 [==============================] - 12s 250us/step - loss: 0.4266 - binary_accuracy: 0.7936
# Epoch 8/10
# 50000/50000 [==============================] - 12s 247us/step - loss: 0.4281 - binary_accuracy: 0.7932
# Epoch 9/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.4251 - binary_accuracy: 0.7939
# Epoch 10/10
# 50000/50000 [==============================] - 13s 251us/step - loss: 0.4249 - binary_accuracy: 0.7959
#   1%|          | 7/1000 [15:06<36:22:55, 131.90s/it]
# Training batch 7
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.4238 - binary_accuracy: 0.7957
# Epoch 2/10
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.4294 - binary_accuracy: 0.7935
# Epoch 3/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.4245 - binary_accuracy: 0.7963
# Epoch 4/10
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.4336 - binary_accuracy: 0.7913
# Epoch 5/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.4232 - binary_accuracy: 0.7953
# Epoch 6/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.4212 - binary_accuracy: 0.7980
# Epoch 7/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.4225 - binary_accuracy: 0.7959
# Epoch 8/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.4227 - binary_accuracy: 0.7968
# Epoch 9/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.4212 - binary_accuracy: 0.7976
# Epoch 10/10
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.4210 - binary_accuracy: 0.7988
#   1%|          | 8/1000 [17:08<35:31:32, 128.92s/it]
# Training batch 8
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4208 - binary_accuracy: 0.7999
# Epoch 2/10
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.4192 - binary_accuracy: 0.7979
# Epoch 3/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.4185 - binary_accuracy: 0.7994
# Epoch 4/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.4129 - binary_accuracy: 0.8042
# Epoch 5/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.4152 - binary_accuracy: 0.8008
# Epoch 6/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.4166 - binary_accuracy: 0.8008
# Epoch 7/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.4133 - binary_accuracy: 0.8036
# Epoch 8/10
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.4116 - binary_accuracy: 0.8036
# Epoch 9/10
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.4091 - binary_accuracy: 0.8066
# Epoch 10/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.4193 - binary_accuracy: 0.7999
#   1%|          | 9/1000 [19:17<35:30:49, 129.01s/it]
# Training batch 9
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.4177 - binary_accuracy: 0.8019
# Epoch 2/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.4191 - binary_accuracy: 0.8002
# Epoch 3/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.4138 - binary_accuracy: 0.8039
# Epoch 4/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.4077 - binary_accuracy: 0.8073
# Epoch 5/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4038 - binary_accuracy: 0.8100
# Epoch 6/10
# 50000/50000 [==============================] - 12s 238us/step - loss: 0.4058 - binary_accuracy: 0.8084
# Epoch 7/10
# 50000/50000 [==============================] - 12s 245us/step - loss: 0.4081 - binary_accuracy: 0.8089
# Epoch 8/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.4031 - binary_accuracy: 0.8106
# Epoch 9/10
# 50000/50000 [==============================] - 13s 255us/step - loss: 0.4028 - binary_accuracy: 0.8101
# Epoch 10/10
# 50000/50000 [==============================] - 13s 251us/step - loss: 0.4022 - binary_accuracy: 0.8120
#   1%|          | 10/1000 [21:31<35:53:49, 130.53s/it]
# Training batch 10
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.4124 - binary_accuracy: 0.8048
# Epoch 2/10
# 50000/50000 [==============================] - 12s 249us/step - loss: 0.4115 - binary_accuracy: 0.8057
# Epoch 3/10
# 50000/50000 [==============================] - 13s 252us/step - loss: 0.4106 - binary_accuracy: 0.8062
# Epoch 4/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.4111 - binary_accuracy: 0.8061
# Epoch 5/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.4082 - binary_accuracy: 0.8083
# Epoch 6/10
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.4099 - binary_accuracy: 0.8070
# Epoch 7/10
# 50000/50000 [==============================] - 13s 252us/step - loss: 0.4040 - binary_accuracy: 0.8097
# Epoch 8/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.4097 - binary_accuracy: 0.8069
# Epoch 9/10
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.4029 - binary_accuracy: 0.8113
# Epoch 10/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.4046 - binary_accuracy: 0.8098
#   1%|          | 11/1000 [23:45<36:05:39, 131.38s/it]
# Training batch 11
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 13s 262us/step - loss: 0.4089 - binary_accuracy: 0.8086
# Epoch 2/10
# 50000/50000 [==============================] - 14s 272us/step - loss: 0.4073 - binary_accuracy: 0.8109
# Epoch 3/10
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.4058 - binary_accuracy: 0.81120s - loss: 0.4060 - binary_accuracy: 0
# Epoch 4/10
# 50000/50000 [==============================] - 14s 282us/step - loss: 0.4057 - binary_accuracy: 0.8094
# Epoch 5/10
# 50000/50000 [==============================] - 12s 248us/step - loss: 0.4099 - binary_accuracy: 0.8064
# Epoch 6/10
# 50000/50000 [==============================] - 12s 234us/step - loss: 0.3994 - binary_accuracy: 0.8138
# Epoch 7/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.4063 - binary_accuracy: 0.8087
# Epoch 8/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.4029 - binary_accuracy: 0.8124
# Epoch 9/10
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.3967 - binary_accuracy: 0.8157
# Epoch 10/10
# 50000/50000 [==============================] - 13s 267us/step - loss: 0.3958 - binary_accuracy: 0.8159
#   1%|          | 12/1000 [26:06<36:51:54, 134.33s/it]
# Training batch 12
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 13s 253us/step - loss: 0.3984 - binary_accuracy: 0.8139
# Epoch 2/10
# 50000/50000 [==============================] - 12s 244us/step - loss: 0.3950 - binary_accuracy: 0.8174
# Epoch 3/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.3992 - binary_accuracy: 0.8133
# Epoch 4/10
# 50000/50000 [==============================] - 13s 251us/step - loss: 0.3979 - binary_accuracy: 0.8147
# Epoch 5/10
# 50000/50000 [==============================] - 13s 257us/step - loss: 0.3978 - binary_accuracy: 0.8137
# Epoch 6/10
# 50000/50000 [==============================] - 14s 270us/step - loss: 0.3933 - binary_accuracy: 0.8165
# Epoch 7/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.3954 - binary_accuracy: 0.8161
# Epoch 8/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3997 - binary_accuracy: 0.8114
# Epoch 9/10
# 50000/50000 [==============================] - 12s 236us/step - loss: 0.3903 - binary_accuracy: 0.8199
# Epoch 10/10
# 50000/50000 [==============================] - 13s 268us/step - loss: 0.3927 - binary_accuracy: 0.8181
#   1%|▏         | 13/1000 [28:24<37:10:11, 135.57s/it]
# Training batch 13
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.4000 - binary_accuracy: 0.8139
# Epoch 2/10
# 50000/50000 [==============================] - 12s 241us/step - loss: 0.3980 - binary_accuracy: 0.8153
# Epoch 3/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.3969 - binary_accuracy: 0.8159
# Epoch 4/10
# 50000/50000 [==============================] - 12s 248us/step - loss: 0.3953 - binary_accuracy: 0.8159
# Epoch 5/10
# 50000/50000 [==============================] - 12s 236us/step - loss: 0.3937 - binary_accuracy: 0.8173
# Epoch 6/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.3918 - binary_accuracy: 0.8201
# Epoch 7/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.3985 - binary_accuracy: 0.8150
# Epoch 8/10
# 50000/50000 [==============================] - 13s 250us/step - loss: 0.3947 - binary_accuracy: 0.8177
# Epoch 9/10
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.3968 - binary_accuracy: 0.8165
# Epoch 10/10
# 50000/50000 [==============================] - 12s 246us/step - loss: 0.3901 - binary_accuracy: 0.8200
#   1%|▏         | 14/1000 [30:38<36:56:21, 134.87s/it]
# Training batch 14
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 14s 275us/step - loss: 0.3923 - binary_accuracy: 0.8212
# Epoch 2/10
# 50000/50000 [==============================] - 14s 270us/step - loss: 0.3927 - binary_accuracy: 0.8199
# Epoch 3/10
# 50000/50000 [==============================] - 13s 266us/step - loss: 0.3894 - binary_accuracy: 0.8223
# Epoch 4/10
# 50000/50000 [==============================] - 14s 279us/step - loss: 0.3897 - binary_accuracy: 0.8216
# Epoch 5/10
# 50000/50000 [==============================] - 14s 283us/step - loss: 0.3898 - binary_accuracy: 0.8216
# Epoch 6/10
# 50000/50000 [==============================] - 14s 285us/step - loss: 0.3905 - binary_accuracy: 0.8209
# Epoch 7/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.3859 - binary_accuracy: 0.8238
# Epoch 8/10
# 50000/50000 [==============================] - 12s 247us/step - loss: 0.3863 - binary_accuracy: 0.8225
# Epoch 9/10
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.3893 - binary_accuracy: 0.8213
# Epoch 10/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.3836 - binary_accuracy: 0.8256
#   2%|▏         | 15/1000 [33:04<37:50:30, 138.31s/it]
# Training batch 15
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3920 - binary_accuracy: 0.8207
# Epoch 2/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3958 - binary_accuracy: 0.8183
# Epoch 3/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.3961 - binary_accuracy: 0.8167
# Epoch 4/10
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3930 - binary_accuracy: 0.8191
# Epoch 5/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3912 - binary_accuracy: 0.8211
# Epoch 6/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3867 - binary_accuracy: 0.8234
# Epoch 7/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3844 - binary_accuracy: 0.8262
# Epoch 8/10
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.3908 - binary_accuracy: 0.8202
# Epoch 9/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.3857 - binary_accuracy: 0.8241
# Epoch 10/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3910 - binary_accuracy: 0.8211
#   2%|▏         | 16/1000 [35:07<36:35:36, 133.88s/it]
# Training batch 16
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3888 - binary_accuracy: 0.8225
# Epoch 2/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3847 - binary_accuracy: 0.8248
# Epoch 3/10
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.3871 - binary_accuracy: 0.8211
# Epoch 4/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3829 - binary_accuracy: 0.8249
# Epoch 5/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3868 - binary_accuracy: 0.8219
# Epoch 6/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.3854 - binary_accuracy: 0.8228
# Epoch 7/10
# 50000/50000 [==============================] - 10s 205us/step - loss: 0.3864 - binary_accuracy: 0.8224
# Epoch 8/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3842 - binary_accuracy: 0.8247
# Epoch 9/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3842 - binary_accuracy: 0.8238
# Epoch 10/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3857 - binary_accuracy: 0.8235
#   2%|▏         | 17/1000 [37:09<35:35:22, 130.34s/it]
# Training batch 17
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3833 - binary_accuracy: 0.8266
# Epoch 2/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3805 - binary_accuracy: 0.8271
# Epoch 3/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3826 - binary_accuracy: 0.8256
# Epoch 4/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3786 - binary_accuracy: 0.8285
# Epoch 5/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3790 - binary_accuracy: 0.8292
# Epoch 6/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3734 - binary_accuracy: 0.8311
# Epoch 7/10
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.3772 - binary_accuracy: 0.8294
# Epoch 8/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.3802 - binary_accuracy: 0.8277
# Epoch 9/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3767 - binary_accuracy: 0.8304
# Epoch 10/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3755 - binary_accuracy: 0.8300
#   2%|▏         | 18/1000 [39:12<34:55:26, 128.03s/it]
# Training batch 18
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.3886 - binary_accuracy: 0.8207
# Epoch 2/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.3875 - binary_accuracy: 0.8212
# Epoch 3/10
# 50000/50000 [==============================] - 10s 209us/step - loss: 0.3811 - binary_accuracy: 0.8266
# Epoch 4/10
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.3815 - binary_accuracy: 0.8250
# Epoch 5/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3803 - binary_accuracy: 0.8254
# Epoch 6/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.3746 - binary_accuracy: 0.8291
# Epoch 7/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3776 - binary_accuracy: 0.8283
# Epoch 8/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3823 - binary_accuracy: 0.8259
# Epoch 9/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3770 - binary_accuracy: 0.8281
# Epoch 10/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3764 - binary_accuracy: 0.8274
#   2%|▏         | 19/1000 [41:15<34:30:14, 126.62s/it]
# Training batch 19
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3845 - binary_accuracy: 0.8254
# Epoch 2/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3806 - binary_accuracy: 0.8262
# Epoch 3/10
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.3806 - binary_accuracy: 0.8271
# Epoch 4/10
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3757 - binary_accuracy: 0.8289
# Epoch 5/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3788 - binary_accuracy: 0.8276
# Epoch 6/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3790 - binary_accuracy: 0.8279
# Epoch 7/10
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.3774 - binary_accuracy: 0.8273
# Epoch 8/10
# 50000/50000 [==============================] - 10s 197us/step - loss: 0.3827 - binary_accuracy: 0.8249
# Epoch 9/10
# 50000/50000 [==============================] - 10s 197us/step - loss: 0.3707 - binary_accuracy: 0.8321
# Epoch 10/10
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.3743 - binary_accuracy: 0.8289
#   2%|▏         | 20/1000 [43:15<33:52:53, 124.46s/it]
# Training batch 20
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.3816 - binary_accuracy: 0.8274
# Epoch 2/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3816 - binary_accuracy: 0.8259
# Epoch 3/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3771 - binary_accuracy: 0.8294
# Epoch 4/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3759 - binary_accuracy: 0.8306
# Epoch 5/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3785 - binary_accuracy: 0.8297
# Epoch 6/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.3742 - binary_accuracy: 0.8319
# Epoch 7/10
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.3758 - binary_accuracy: 0.8292
# Epoch 8/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3772 - binary_accuracy: 0.8309
# Epoch 9/10
# 50000/50000 [==============================] - 12s 233us/step - loss: 0.3725 - binary_accuracy: 0.8326
# Epoch 10/10
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.3723 - binary_accuracy: 0.8330
#   2%|▏         | 21/1000 [45:19<33:47:44, 124.27s/it]
# Training batch 21
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3810 - binary_accuracy: 0.8272
# Epoch 2/10
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.3787 - binary_accuracy: 0.8291
# Epoch 3/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.3793 - binary_accuracy: 0.8282
# Epoch 4/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.3796 - binary_accuracy: 0.8268
# Epoch 5/10
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.3743 - binary_accuracy: 0.8307
# Epoch 6/10
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.3723 - binary_accuracy: 0.8317
# Epoch 7/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.3716 - binary_accuracy: 0.8337
# Epoch 8/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.3787 - binary_accuracy: 0.8294
# Epoch 9/10
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.3697 - binary_accuracy: 0.8347
# Epoch 10/10
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.3715 - binary_accuracy: 0.8322
#   2%|▏         | 22/1000 [47:25<33:57:15, 124.99s/it]
# Training batch 22
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.3756 - binary_accuracy: 0.8299
# Epoch 2/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3725 - binary_accuracy: 0.8314
# Epoch 3/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3740 - binary_accuracy: 0.8301
# Epoch 4/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3728 - binary_accuracy: 0.8336
# Epoch 5/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3687 - binary_accuracy: 0.8345
# Epoch 6/10
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.3701 - binary_accuracy: 0.8335
# Epoch 7/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3653 - binary_accuracy: 0.8355
# Epoch 8/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3692 - binary_accuracy: 0.8358
# Epoch 9/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3742 - binary_accuracy: 0.8308
# Epoch 10/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3701 - binary_accuracy: 0.8334
#   2%|▏         | 23/1000 [49:28<33:43:18, 124.26s/it]
# Training batch 23
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3721 - binary_accuracy: 0.8317
# Epoch 2/10
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.3725 - binary_accuracy: 0.8324
# Epoch 3/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3712 - binary_accuracy: 0.8334
# Epoch 4/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3714 - binary_accuracy: 0.8333
# Epoch 5/10
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.3731 - binary_accuracy: 0.8321
# Epoch 6/10
# 50000/50000 [==============================] - 10s 198us/step - loss: 0.3680 - binary_accuracy: 0.8336
# Epoch 7/10
# 50000/50000 [==============================] - 10s 198us/step - loss: 0.3692 - binary_accuracy: 0.8341
# Epoch 8/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3696 - binary_accuracy: 0.8325
# Epoch 9/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3688 - binary_accuracy: 0.8330
# Epoch 10/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3682 - binary_accuracy: 0.8362
#   2%|▏         | 24/1000 [51:28<33:21:39, 123.05s/it]
# Training batch 24
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3749 - binary_accuracy: 0.8315
# Epoch 2/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3733 - binary_accuracy: 0.8320
# Epoch 3/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3694 - binary_accuracy: 0.8340
# Epoch 4/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3634 - binary_accuracy: 0.8377
# Epoch 5/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3713 - binary_accuracy: 0.8326
# Epoch 6/10
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.3654 - binary_accuracy: 0.8367
# Epoch 7/10
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.3659 - binary_accuracy: 0.8381
# Epoch 8/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3615 - binary_accuracy: 0.8405
# Epoch 9/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3599 - binary_accuracy: 0.8404
# Epoch 10/10
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.3621 - binary_accuracy: 0.8401
#   2%|▎         | 25/1000 [53:31<33:18:18, 122.97s/it]
# Training batch 25
# Stochastic sample generated...
# Epoch 1/10
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3743 - binary_accuracy: 0.8323
# Epoch 2/10
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.3724 - binary_accuracy: 0.8331
# Epoch 3/10
# 50000/50000 [==============================] - 10s 204us/step - loss: 0.3742 - binary_accuracy: 0.8331
# Epoch 4/10
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.3683 - binary_accuracy: 0.8356
# Epoch 5/10
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3662 - binary_accuracy: 0.8356
# Epoch 6/10
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.3688 - binary_accuracy: 0.8354
# Epoch 7/10
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.3716 - binary_accuracy: 0.8335
# Epoch 8/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.3657 - binary_accuracy: 0.8375
# Epoch 9/10
# 29504/50000 [================>.............] - ETA: 5s - loss: 0.3742 - binary_accuracy: 0.8318
# E1031 18:21:49.363179 4557010368 ultratb.py:149] Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-100-c6f9b867a2f8>", line 13, in <module>
#     h = model.fit(X_train,y_train, epochs = n_epochs, verbose = 1, batch_size = minibatchsize)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 1039, in fit
#     validation_steps=validation_steps)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py", line 199, in fit_loop
#     outs = f(ins_batch)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 1458, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/vedantchandra/anaconda3/lib/python3.7/inspect.py", line 732, in getmodule
#     for modname, module in list(sys.modules.items()):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
plt.figure()
#plt.plot(history);
plt.plot(vhistory)
plt.xlabel('Epoch')
plt.ylabel('Loss')
r = 100
plt.figure()
#plt.plot(history[-r:]);
plt.plot(vhistory[-r:]);
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
X_test,y_test = batchgen(10000)
y_test = encoder.transform(y_test.reshape(-1,1)).toarray()


pred_proba = model.predict(X_test)
preds = pred_proba[:,1] > pred_proba[:,0]

fpr,tpr,_ = roc_curve(y_test[:,1],pred_proba[:,1])

plt.plot(fpr,tpr)
x = np.linspace(0,1,100)
plt.plot(x,x,'k--')
plt.title('ROC Curve')
plt.text(0.5,0.1,'AUC = %.3f'%auc(fpr,tpr))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

print("Thresholded Accuracy on validation dataset: %.2f percent"%(sum(preds == y_test[:,1])/len(y_test)*100));

choice_class = model.predict(X_test)[:,1] > model.predict(X_test)[:,0]
print("MLE Classification Accuracy on validation dataset: %.2f percent"\
      %(sum(choice_class == y_test[:,1])/len(y_test)*100));
# Out:
# Thresholded Accuracy on validation dataset: 82.93 percent
# MLE Classification Accuracy on validation dataset: 82.93 percent

# %% [markdown]
# # Apply to Actual Dataset

# %%
bin_prob = model.predict(cleanspectra)

# %%
plt.hist(bin_prob[:,1])
plt.title('Histogram of $P_{binary}$');

# %%
threshold = 0.97

# %%
binaries = bin_prob[:,1] > threshold

# %%
cleantable['bin_prob'] = bin_prob[:,1]

# %%
sum(binaries)
# Out:
# 33

# %%
cont = [];
for obj in cleantable[binaries]:
    if get_spectrum(obj['source_id'])[0] == 0:
        continue
        cont.append(0)
    plt.figure(figsize = (15,5))
    plt.plot(lamgrid,get_spectrum(obj['source_id']),'k')
    plt.title('Gaia '+str(obj['source_id']))
    print(obj['source_id'])
    print('Probability of Binarity = %.2f'%obj['bin_prob'])
    plt.savefig('binary_'+str(obj['source_id'])+'png')
    print(str(obj['ra']) + ' '+str(obj['dec']))
    cont.append(1)
    plt.show()
# Out:
# 323375784298256896
# Probability of Binarity = 0.99
# 21.395780076164524 38.84638882987355
# 598649343628980224
# Probability of Binarity = 0.97
# 132.27719347688713 10.788648640516955
# 601566038739612160
# Probability of Binarity = 0.98
# 128.82693568122374 10.71621235626091
# 613215845472962688
# Probability of Binarity = 0.97
# 148.1266906465553 11.700676891257775
# 651842517886030464
# Probability of Binarity = 0.98
# 127.71708714040139 15.172523902147281
# 665139697978259200
# Probability of Binarity = 0.98
# 130.13095552429124 21.67847565084658
# 850037352876685568
# Probability of Binarity = 0.97
# 163.7066759264088 55.38547792843915
# 876092411200810880
# Probability of Binarity = 0.98
# 121.61679427940149 28.05940499699591
# 898145457653825792
# Probability of Binarity = 0.99
# 110.18063151693275 37.34250803212683
# 898560244120077696
# Probability of Binarity = 0.98
# 112.05284086079094 36.47401658094208
# 898783513699801344
# Probability of Binarity = 0.98
# 111.82235022594568 37.08669267887916
# 908438565821365120
# Probability of Binarity = 0.98
# 124.52934287221785 39.00152950798072
# 923065025408030848
# Probability of Binarity = 0.98
# 119.81875858005313 43.588502398059184
# 1205212804452420992
# Probability of Binarity = 0.99
# 241.60451681497025 21.296992435727635
# 1263434109805753984
# Probability of Binarity = 0.97
# 228.5801535261615 23.229420031280345
# 1448232907440917760
# Probability of Binarity = 0.99
# 202.35850123627915 25.826837682633936
# 1528130466060854528
# Probability of Binarity = 0.97
# 192.07002676684868 41.18090966650559
# 1594358105851106048
# Probability of Binarity = 0.98
# 231.20692202983832 48.86860351220815
# 2709431087334966656
# Probability of Binarity = 0.97
# 336.86280750764894 6.591232689896369
# 3264305235225133312
# Probability of Binarity = 0.98
# 51.56047170091342 -0.19399984221222855
# 3275317320918274944
# Probability of Binarity = 0.99
# 51.744984216566245 4.05196365509747
# 3287002380742315520
# Probability of Binarity = 0.97
# 65.6766331091541 7.689401220369271
# 3302526729012505472
# Probability of Binarity = 0.97
# 58.56793028134737 9.960550339739608
# 3302650084770597760
# Probability of Binarity = 0.99
# 56.6293094582068 9.807447511399756
# 3723086662461423104
# Probability of Binarity = 1.00
# 211.81284733339766 9.390898296170073
# 3828669018866032128
# Probability of Binarity = 0.98
# 153.90659761533666 -3.01793922624864
# 3888062923305972352
# Probability of Binarity = 0.99
# 153.0851600988672 14.460252341686534
# 3888886625018664704
# Probability of Binarity = 0.97
# 157.48302253869375 14.898669036742112
# 3957439461319984640
# Probability of Binarity = 0.99
# 195.84855756010745 25.168878094577398
# 4022827173009555712
# Probability of Binarity = 0.98
# 172.701660422908 30.955724759651698
# 4031828157446980608
# Probability of Binarity = 0.99
# 178.74493141929642 36.8485329369625
# 4563669044268461056
# Probability of Binarity = 1.00
# 248.39460952597108 19.708235379623332
# 6339637226595437184
# Probability of Binarity = 0.99
# 227.37770207080294 -2.100353090480736

# %%
cleantable[cleantable['source_id'] == 1603554764703627520]
# Out:
# <Table masked=True length=0>
#   dist  solution_id source_id random_index ...  dec_2  file_exists bin_prob
#                                            ...
# float64    int64      int64      int64     ... float64    int64    float32
# ------- ----------- --------- ------------ ... ------- ----------- --------

# %%
cleantable
# Out:
# <Table masked=True length=11569>
#          dist              solution_id     ... file_exists  bin_prob
#                                            ...
#        float64                int64        ...    int64     float32
# ---------------------- ------------------- ... ----------- ----------
#  6.886723761375954e-05 1635721458409799680 ...           1 0.09969207
# 0.00020031517001518033 1635721458409799680 ...           1 0.23060729
# 0.00023444092682600368 1635721458409799680 ...           1 0.14429082
# 0.00012204938669488508 1635721458409799680 ...           1 0.18575944
# 0.00015238854033756104 1635721458409799680 ...           1 0.30694765
#  0.0001841498624119707 1635721458409799680 ...           1 0.23596154
#  9.146903804916872e-05 1635721458409799680 ...           1 0.12059663
# 0.00012746218274233128 1635721458409799680 ...           1  0.7725894
# 0.00018467163484252463 1635721458409799680 ...           1  0.4738309
#                    ...                 ... ...         ...        ...
# 0.00012994765114656987 1635721458409799680 ...           1 0.17818582
# 0.00012107772142618723 1635721458409799680 ...           1 0.19150361
# 0.00010097956267357848 1635721458409799680 ...           1 0.24604258
#  6.593410456382458e-05 1635721458409799680 ...           1 0.10504353
# 0.00023141835243388405 1635721458409799680 ...           1 0.12209637
#  6.298560174334227e-05 1635721458409799680 ...           1  0.2381638
#  0.0001614920770715832 1635721458409799680 ...           1 0.24441145
# 0.00014133677660338323 1635721458409799680 ...           1 0.46341532
#   6.97167133688824e-05 1635721458409799680 ...           1 0.19960517
# 1.5641153197304673e-05 1635721458409799680 ...           1 0.46459392
