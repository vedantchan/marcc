# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
plt.style.use('default')
import scipy.stats as stats
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
from lmfit import Model,Minimizer
import corner
import numdifftools
from scipy.ndimage.interpolation import shift
import pickle

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto(device_count={"CPU": 4})
K.tensorflow_backend.set_session(tf.Session(config=config))

# %%
arr = pickle.load(open('modelspecs.p','rb'))
modelspectra = arr[0]
teffs = arr[2]
loggs = arr[1]

# %%
def v_mse(y_true, y_pred):
    return K.mean((1e5*y_pred - 1e5*y_true )**2)

# %%
def labelscaler(array):
    array[:,0] = array[:,0] / 80000
    array[:,1] = array[:,1] / 9.5
    return array

def labelunscaler(array):
    array[:,0] = array[:,0] * 80000
    array[:,1] = array[:,1] * 9.5
    return array

# %%
X = labelscaler(np.stack((teffs,loggs)).transpose())

t = (modelspectra/np.max(modelspectra))

modelscaling = np.max(modelspectra)

# %%
def generator():
    model = Sequential()
    
    model.add(Dense(2,input_shape=X[0].shape))
    model.add(Dense(1024,activation='relu'))
    model.add(Dense(1024,activation='relu'))
    model.add(Dense(4000,activation='sigmoid'))
    model.compile(optimizer = Adam(lr=1e-3), loss = v_mse, \
                  metrics = ['mean_absolute_percentage_error'])
    return model

# %%
model = generator()
model.load_weights('generator100_1024.h5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              3072
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_8 (Dense)              (None, 4000)              4100000
# =================================================================
# Total params: 5,152,678
# Trainable params: 5,152,678
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epoch = 200
batch = 32

history = model.fit(X,t,epochs=epoch,verbose=2,batch_size=batch)
# Out:
# W0725 12:16:18.351281 47674136532288 deprecation.py:323] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/200
#  - 2s - loss: 12149.2196 - mean_absolute_percentage_error: 2.4707
# Epoch 2/200
#  - 0s - loss: 504.9895 - mean_absolute_percentage_error: 0.6308
# Epoch 3/200
#  - 0s - loss: 208.7571 - mean_absolute_percentage_error: 0.4558
# Epoch 4/200
#  - 1s - loss: 180.6587 - mean_absolute_percentage_error: 0.4323
# Epoch 5/200
#  - 0s - loss: 183.0645 - mean_absolute_percentage_error: 0.4404
# Epoch 6/200
#  - 0s - loss: 188.2867 - mean_absolute_percentage_error: 0.4457
# Epoch 7/200
#  - 0s - loss: 218.5205 - mean_absolute_percentage_error: 0.4669
# Epoch 8/200
#  - 0s - loss: 212.3297 - mean_absolute_percentage_error: 0.4848
# Epoch 9/200
#  - 0s - loss: 185.1347 - mean_absolute_percentage_error: 0.4599
# Epoch 10/200
#  - 0s - loss: 211.5190 - mean_absolute_percentage_error: 0.4665
# Epoch 11/200
#  - 0s - loss: 216.0243 - mean_absolute_percentage_error: 0.4659
# Epoch 12/200
#  - 0s - loss: 267.0278 - mean_absolute_percentage_error: 0.4835
# Epoch 13/200
#  - 0s - loss: 349.4277 - mean_absolute_percentage_error: 0.5962
# Epoch 14/200
#  - 0s - loss: 336.6147 - mean_absolute_percentage_error: 0.5455
# Epoch 15/200
#  - 0s - loss: 396.0990 - mean_absolute_percentage_error: 0.5531
# Epoch 16/200
#  - 0s - loss: 303.0525 - mean_absolute_percentage_error: 0.5862
# Epoch 17/200
#  - 0s - loss: 653.5990 - mean_absolute_percentage_error: 0.7748
# Epoch 18/200
#  - 0s - loss: 563.4684 - mean_absolute_percentage_error: 0.6891
# Epoch 19/200
#  - 0s - loss: 253.8447 - mean_absolute_percentage_error: 0.5015
# Epoch 20/200
#  - 0s - loss: 226.6256 - mean_absolute_percentage_error: 0.5034
# Epoch 21/200
#  - 0s - loss: 307.4058 - mean_absolute_percentage_error: 0.5334
# Epoch 22/200
#  - 0s - loss: 488.2130 - mean_absolute_percentage_error: 0.6525
# Epoch 23/200
#  - 0s - loss: 438.0358 - mean_absolute_percentage_error: 0.6148
# Epoch 24/200
#  - 0s - loss: 639.0095 - mean_absolute_percentage_error: 0.8548
# Epoch 25/200
#  - 0s - loss: 541.4852 - mean_absolute_percentage_error: 0.6779
# Epoch 26/200
#  - 0s - loss: 848.3280 - mean_absolute_percentage_error: 0.8467
# Epoch 27/200
#  - 0s - loss: 728.4217 - mean_absolute_percentage_error: 0.7510
# Epoch 28/200
#  - 0s - loss: 551.3090 - mean_absolute_percentage_error: 0.6700
# Epoch 29/200
#  - 0s - loss: 1797.2970 - mean_absolute_percentage_error: 1.1579
# Epoch 30/200
#  - 0s - loss: 1518.6434 - mean_absolute_percentage_error: 1.4534
# Epoch 31/200
#  - 0s - loss: 526.6772 - mean_absolute_percentage_error: 0.7439
# Epoch 32/200
#  - 0s - loss: 870.9828 - mean_absolute_percentage_error: 0.8845
# Epoch 33/200
#  - 0s - loss: 774.6680 - mean_absolute_percentage_error: 0.7057
# Epoch 34/200
#  - 0s - loss: 294.2084 - mean_absolute_percentage_error: 0.5157
# Epoch 35/200
#  - 0s - loss: 286.1906 - mean_absolute_percentage_error: 0.5260
# Epoch 36/200
#  - 0s - loss: 442.9195 - mean_absolute_percentage_error: 0.7539
# Epoch 37/200
#  - 0s - loss: 579.1582 - mean_absolute_percentage_error: 0.6991
# Epoch 38/200
#  - 0s - loss: 383.3150 - mean_absolute_percentage_error: 0.6039
# Epoch 39/200
#  - 0s - loss: 539.1619 - mean_absolute_percentage_error: 0.6626
# Epoch 40/200
#  - 0s - loss: 283.5380 - mean_absolute_percentage_error: 0.5536
# Epoch 41/200
#  - 0s - loss: 254.6232 - mean_absolute_percentage_error: 0.4783
# Epoch 42/200
#  - 0s - loss: 357.4868 - mean_absolute_percentage_error: 0.5868
# Epoch 43/200
#  - 0s - loss: 381.9607 - mean_absolute_percentage_error: 0.5866
# Epoch 44/200
#  - 0s - loss: 619.7751 - mean_absolute_percentage_error: 0.6651
# Epoch 45/200
#  - 0s - loss: 818.0145 - mean_absolute_percentage_error: 0.8247
# Epoch 46/200
#  - 0s - loss: 916.0062 - mean_absolute_percentage_error: 0.8494
# Epoch 47/200
#  - 0s - loss: 997.7455 - mean_absolute_percentage_error: 1.0564
# Epoch 48/200
#  - 0s - loss: 715.2424 - mean_absolute_percentage_error: 0.9204
# Epoch 49/200
#  - 0s - loss: 437.5006 - mean_absolute_percentage_error: 0.6220
# Epoch 50/200
#  - 0s - loss: 337.3987 - mean_absolute_percentage_error: 0.5959
# Epoch 51/200
#  - 0s - loss: 836.8006 - mean_absolute_percentage_error: 0.8901
# Epoch 52/200
#  - 0s - loss: 1111.6063 - mean_absolute_percentage_error: 0.9256
# Epoch 53/200
#  - 0s - loss: 515.5028 - mean_absolute_percentage_error: 0.7969
# Epoch 54/200
#  - 0s - loss: 851.8933 - mean_absolute_percentage_error: 0.8118
# Epoch 55/200
#  - 0s - loss: 1158.7581 - mean_absolute_percentage_error: 0.9355
# Epoch 56/200
#  - 0s - loss: 2125.2754 - mean_absolute_percentage_error: 1.3182
# Epoch 57/200
#  - 0s - loss: 2670.0586 - mean_absolute_percentage_error: 1.5246
# Epoch 58/200
#  - 0s - loss: 1149.4620 - mean_absolute_percentage_error: 0.9618
# Epoch 59/200
#  - 0s - loss: 1687.6243 - mean_absolute_percentage_error: 1.4450
# Epoch 60/200
#  - 0s - loss: 870.2356 - mean_absolute_percentage_error: 0.8329
# Epoch 61/200
#  - 0s - loss: 702.1022 - mean_absolute_percentage_error: 0.9574
# Epoch 62/200
#  - 0s - loss: 330.2238 - mean_absolute_percentage_error: 0.5579
# Epoch 63/200
#  - 0s - loss: 365.6151 - mean_absolute_percentage_error: 0.5815
# Epoch 64/200
#  - 0s - loss: 521.1333 - mean_absolute_percentage_error: 0.6801
# Epoch 65/200
#  - 0s - loss: 293.5626 - mean_absolute_percentage_error: 0.5342
# Epoch 66/200
#  - 0s - loss: 244.5685 - mean_absolute_percentage_error: 0.4868
# Epoch 67/200
#  - 0s - loss: 282.9767 - mean_absolute_percentage_error: 0.5373
# Epoch 68/200
#  - 0s - loss: 270.5958 - mean_absolute_percentage_error: 0.4996
# Epoch 69/200
#  - 0s - loss: 254.4469 - mean_absolute_percentage_error: 0.5234
# Epoch 70/200
#  - 0s - loss: 232.9255 - mean_absolute_percentage_error: 0.4938
# Epoch 71/200
#  - 0s - loss: 323.1514 - mean_absolute_percentage_error: 0.5437
# Epoch 72/200
#  - 0s - loss: 367.5619 - mean_absolute_percentage_error: 0.6351
# Epoch 73/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-414f810a783c> in <module>
#       2 batch = 32
#       3
# ----> 4 history = model.fit(X,t,epochs=epoch,verbose=2,batch_size=batch)
#
# ~/anaconda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plt.plot(np.log(history.history['loss']))

# %%
plt.plot( np.ravel(model.predict(labelscaler(np.asarray([15000,8.]).reshape(1,-1)))) )

# %%
ts = np.arange(5000,20000,10)
#ls = np.linspace(6.5,9.5,50)
lmask = (loggs == 8)*(teffs < 20000)
mods = []

for i in ts:
    mods.append(model.predict(labelscaler(np.asarray([i,8.]).reshape(1, -1))))
mods = np.asarray(mods)

plt.figure(figsize = (8,5))
pixel = 2563
plt.plot(ts,mods[:,0,pixel]*modelscaling,'r',label='Generated Model')
plt.plot(teffs[lmask],modelspectra[:,pixel][lmask],'k.',label='Truth')
plt.title('Spaxel Fit: %i Angstrom'%(pixel+4000))
plt.xlabel('$T_{eff}$ (Kelvin)')
plt.ylabel('Flux')
plt.legend()

# %%
ls = np.linspace(6.5,9.5,100)

tmask = (teffs == 15000)
mods = []

for i in ls:
    mods.append(model.predict(labelscaler(np.asarray([15000,i]).reshape(1, -1))))
mods = np.asarray(mods)

plt.figure(figsize = (8,5))
pixel = 250
plt.plot(ls,mods[:,0,pixel]*modelscaling,'r--',label='Generated Model')
plt.plot(loggs[tmask],modelspectra[:,pixel][tmask],'k.',label='Truth')
plt.title('Spaxel Fit: %i Angstrom'%(pixel+4000))
plt.xlabel('Log(g) (dex)')
plt.ylabel('Flux')
plt.legend()

# %%
ls = np.linspace(6.5,9.5,100)

tmask = (teffs == 15000)
mods = []

for i in ls:
    mods.append(model.predict(labelscaler(np.asarray([15000,i]).reshape(1, -1))))
mods = np.asarray(mods)

plt.figure(figsize = (8,5))
pixel = 500
plt.plot(ls,mods[:,0,pixel]*modelscaling,'r--',label='Generated Model')
plt.plot(loggs[tmask],modelspectra[:,pixel][tmask],'k.',label='Truth')
plt.title('Spaxel Fit: %i Angstrom'%(pixel+4000))
plt.xlabel('Log(g) (dex)')
plt.ylabel('Flux')
plt.legend()

# %%
ls = np.linspace(6.5,9.5,100)

tmask = (teffs == 15000)
mods = []

for i in ls:
    mods.append(model.predict(labelscaler(np.asarray([15000,i]).reshape(1, -1))))
mods = np.asarray(mods)

plt.figure(figsize = (8,5))
pixel = 2563
plt.plot(ls,mods[:,0,pixel]*modelscaling,'r--',label='Generated Model')
plt.plot(loggs[tmask],modelspectra[:,pixel][tmask],'k.',label='Truth')
plt.title('Spaxel Fit: %i Angstrom'%(pixel+4000))
plt.xlabel('Log(g) (dex)')
plt.ylabel('Flux')
plt.legend()

# %%
preds = model.predict(X)

# %%
plt.hist((np.sqrt(np.mean((preds-t)**2,axis=1))));

# %%
model.save_weights('generator100_1024.h5')

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9752549462398630595
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8206211093137545416
# physical_device_desc: "device: XLA_CPU device"
# ]

# %%
# %%bash
#
# sqme
# Out:
# Thu Jul 25 12:14:30 2019
#               USER        JOBID PARTITION      NAME NODES  CPUS PRIORITY TIME_LIMIT     TIME        NODELIST ST REASON
#   vchandr8@jhu.edu     35595225 gpuk80     jupyter_     1    12    47339    2:00:00     2:11          gpu018 R None

# %%
import tensorflow as tf
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# []
