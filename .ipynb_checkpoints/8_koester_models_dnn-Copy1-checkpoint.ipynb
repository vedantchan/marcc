# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
#from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
#from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 15})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [7, 5]
#from IPython.display import Audio, display
#def allDone():
#    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
#import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
#import emcee
import corner
#import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
#from multiprocessing import Pool
#import pickle
#import h5py
#import multiprocessing
#import itertools
#from multiprocessing import sharedctypes
print('imported')
import scipy
# Out:
# imported

# %%
import pandas as pd

# %%
import keras.backend as K

# %%
import tensorflow as tf

# %%
from keras.models import Sequential,Model
from keras.layers import Dense,Input
from keras.optimizers import Adam, Adamax, SGD
#from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler

# %%
## Enter parameter:
searchparameter = '_'

prefilenames = os.listdir('koester2/')
filenames = []
for i in range(len(prefilenames)):
    if searchparameter in prefilenames[i]:
        filenames.append(prefilenames[i])
        
len(filenames)
# Out:
# 1040

# %%
modelspectra = [];
modelwl = [];
loggs = [];
teffs = [];
for i in tqdm(filenames):
    specname=i
    f = open('koester2/'+specname)
    data = f.readlines()
    f.close()
    headerdata = data[0:7]
    spectraldata = data[6:]
    lam = []
    flux = []

    for i in range(len(spectraldata)):
        l=float(spectraldata[i].split()[0])
        lam.append(l)
        f = float(spectraldata[i].split()[1])
        flux.append(f)

    lam = np.asarray(lam)
    flux = np.asarray(flux) / 1e7

    teff = float(headerdata[1].split()[3])
    logg = float(headerdata[2].split()[3])
    
    in1 = find_nearest(lam,4000)
    in2 = find_nearest(lam,8000)

    flux = flux[in1:in2]
    lam = lam[in1:in2]
    
    flux = flux[:-1][~ (np.diff(lam) == 0)]
    lam = lam[:-1][~ (np.diff(lam) == 0)]
    
    lamgrid = np.arange(4000,8000)
    
    func = interp1d(lam,flux,kind='linear',assume_sorted = False,fill_value='extrapolate')
    flux = func(lamgrid)
    
    modelspectra.append(flux)
    modelwl.append(lam)
    teffs.append(teff)
    loggs.append(logg)

modelspectra = np.asarray(modelspectra)
loggs = np.asarray(loggs)
teffs = np.asarray(teffs)
# Out:
# 100%|██████████| 1040/1040 [00:05<00:00, 179.39it/s]

# %%
X = np.stack((teffs,loggs)).transpose()
t = np.log(modelspectra)

sc = MinMaxScaler()
msc = StandardScaler()

X_scaled = sc.fit_transform(X)
t_scaled = msc.fit_transform(t)

# %%
plt.plot(t_scaled[0:205].T);

# %%
H = 128
def generator():
    x = Input(shape=(X[0].shape[0],))
    y = Dense(H,activation='sigmoid')(x)
    y = Dense(H,activation='sigmoid')(y)
    y = Dense(H,activation='sigmoid')(y)
    y = Dense(H,activation='sigmoid')(y)
    out = Dense(4000,activation='linear')(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adamax(), loss = 'mse', \
                  metrics = ['mae'])
    return model
model = generator()
history = [];
#model.load_weights('model_interp.h5')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_87 (Dense)             (None, 128)               384
# _________________________________________________________________
# dense_88 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_89 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_90 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_91 (Dense)             (None, 4000)              516000
# =================================================================
# Total params: 565,920
# Trainable params: 565,920
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
for i in tqdm(range(1000)): 
    print('Training meta-batch %i'%i)
    
    n_epochs = 100
    batch = 32
    
    h = model.fit(X_scaled,t_scaled, epochs = n_epochs, verbose = 1, batch_size = batch, shuffle = True)
    history = np.append(history, h.history['loss'])
    model.save_weights('model_interp_deep.h5')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training meta-batch 0
# Epoch 1/100
# 1040/1040 [==============================] - 1s 1ms/step - loss: 1.0095 - mean_absolute_error: 0.7697
# Epoch 2/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 1.0019 - mean_absolute_error: 0.7720
# Epoch 3/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 1.0003 - mean_absolute_error: 0.7699
# Epoch 4/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0003 - mean_absolute_error: 0.7697
# Epoch 5/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 1.0002 - mean_absolute_error: 0.7680
# Epoch 6/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0002 - mean_absolute_error: 0.7679
# Epoch 7/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0002 - mean_absolute_error: 0.7682
# Epoch 8/100
# 1040/1040 [==============================] - 0s 231us/step - loss: 1.0002 - mean_absolute_error: 0.7693
# Epoch 9/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0003 - mean_absolute_error: 0.7686
# Epoch 10/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 11/100
# 1040/1040 [==============================] - 0s 239us/step - loss: 1.0002 - mean_absolute_error: 0.7690
# Epoch 12/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 1.0001 - mean_absolute_error: 0.7691
# Epoch 13/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 14/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 1.0006 - mean_absolute_error: 0.7693
# Epoch 15/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 1.0002 - mean_absolute_error: 0.7688
# Epoch 16/100
# 1040/1040 [==============================] - 0s 257us/step - loss: 1.0002 - mean_absolute_error: 0.7692
# Epoch 17/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 1.0001 - mean_absolute_error: 0.7691
# Epoch 18/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 1.0001 - mean_absolute_error: 0.7687
# Epoch 19/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 1.0002 - mean_absolute_error: 0.7683
# Epoch 20/100
# 1040/1040 [==============================] - 0s 240us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 21/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 22/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 23/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 1.0002 - mean_absolute_error: 0.7687
# Epoch 24/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 1.0004 - mean_absolute_error: 0.7690
# Epoch 25/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 26/100
# 1040/1040 [==============================] - 0s 239us/step - loss: 1.0001 - mean_absolute_error: 0.7686
# Epoch 27/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 1.0001 - mean_absolute_error: 0.7686
# Epoch 28/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 1.0001 - mean_absolute_error: 0.7684
# Epoch 29/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0002 - mean_absolute_error: 0.7688
# Epoch 30/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 1.0005 - mean_absolute_error: 0.7692
# Epoch 31/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0002 - mean_absolute_error: 0.7686
# Epoch 32/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0001 - mean_absolute_error: 0.7687
# Epoch 33/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0003 - mean_absolute_error: 0.7686
# Epoch 34/100
# 1040/1040 [==============================] - 0s 255us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 35/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 36/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 37/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 38/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0002 - mean_absolute_error: 0.7690
# Epoch 39/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 1.0002 - mean_absolute_error: 0.7690
# Epoch 40/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0002 - mean_absolute_error: 0.7687
# Epoch 41/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 1.0001 - mean_absolute_error: 0.7690
# Epoch 42/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 43/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0002 - mean_absolute_error: 0.7687
# Epoch 44/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0000 - mean_absolute_error: 0.7686
# Epoch 45/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0002 - mean_absolute_error: 0.7686
# Epoch 46/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 47/100
# 1040/1040 [==============================] - 0s 235us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 48/100
# 1040/1040 [==============================] - 0s 236us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 49/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 50/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0001 - mean_absolute_error: 0.7687
# Epoch 51/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0000 - mean_absolute_error: 0.7685
# Epoch 52/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0002 - mean_absolute_error: 0.7686
# Epoch 53/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 54/100
# 1040/1040 [==============================] - 0s 240us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 55/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 1.0001 - mean_absolute_error: 0.7687
# Epoch 56/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0001 - mean_absolute_error: 0.7690
# Epoch 57/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 58/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 59/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 60/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0001 - mean_absolute_error: 0.7686
# Epoch 61/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 62/100
# 1040/1040 [==============================] - 0s 257us/step - loss: 1.0002 - mean_absolute_error: 0.7686
# Epoch 63/100
# 1040/1040 [==============================] - 0s 240us/step - loss: 1.0001 - mean_absolute_error: 0.7685
# Epoch 64/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0004 - mean_absolute_error: 0.7692
# Epoch 65/100
# 1040/1040 [==============================] - 0s 257us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 66/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 67/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 68/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 69/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 70/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0001 - mean_absolute_error: 0.7690
# Epoch 71/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 1.0001 - mean_absolute_error: 0.7691
# Epoch 72/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0001 - mean_absolute_error: 0.7691
# Epoch 73/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0003 - mean_absolute_error: 0.7687
# Epoch 74/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0001 - mean_absolute_error: 0.7687
# Epoch 75/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 76/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 77/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 78/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 79/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 1.0001 - mean_absolute_error: 0.7690
# Epoch 80/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0002 - mean_absolute_error: 0.7692
# Epoch 81/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 1.0001 - mean_absolute_error: 0.7692
# Epoch 82/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0000 - mean_absolute_error: 0.7690
# Epoch 83/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 1.0001 - mean_absolute_error: 0.7690
# Epoch 84/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0000 - mean_absolute_error: 0.7690
# Epoch 85/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 86/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 87/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 88/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 1.0001 - mean_absolute_error: 0.7688
# Epoch 89/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 90/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 91/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 1.0000 - mean_absolute_error: 0.7689
# Epoch 92/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 1.0001 - mean_absolute_error: 0.7689
# Epoch 93/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 1.0003 - mean_absolute_error: 0.7692
# Epoch 94/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 1.0000 - mean_absolute_error: 0.7688
# Epoch 95/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 1.0001 - mean_absolute_error: 0.7686
# Epoch 96/100
# 1040/1040 [==============================] - 0s 259us/step - loss: 1.0000 - mean_absolute_error: 0.7687
# Epoch 97/100
# 1040/1040 [==============================] - 0s 294us/step - loss: 1.0000 - mean_absolute_error: 0.7691
# Epoch 98/100
# 1040/1040 [==============================] - 0s 255us/step - loss: 0.9999 - mean_absolute_error: 0.7690
# Epoch 99/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 0.9995 - mean_absolute_error: 0.7691
# Epoch 100/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 0.9991 - mean_absolute_error: 0.7703
#   0%|          | 1/1000 [00:27<7:39:26, 27.59s/it]
# Training meta-batch 1
# Epoch 1/100
# 1040/1040 [==============================] - 0s 225us/step - loss: 0.9988 - mean_absolute_error: 0.7723
# Epoch 2/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.9974 - mean_absolute_error: 0.7707
# Epoch 3/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.9954 - mean_absolute_error: 0.7700
# Epoch 4/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 0.9926 - mean_absolute_error: 0.7737
# Epoch 5/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.9872 - mean_absolute_error: 0.7730
# Epoch 6/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 0.9794 - mean_absolute_error: 0.7708
# Epoch 7/100
# 1040/1040 [==============================] - 0s 255us/step - loss: 0.9591 - mean_absolute_error: 0.7717
# Epoch 8/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 0.9323 - mean_absolute_error: 0.7647
# Epoch 9/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 0.8922 - mean_absolute_error: 0.7541
# Epoch 10/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 0.8414 - mean_absolute_error: 0.7399
# Epoch 11/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 0.7874 - mean_absolute_error: 0.7227
# Epoch 12/100
# 1040/1040 [==============================] - 0s 239us/step - loss: 0.7135 - mean_absolute_error: 0.6891
# Epoch 13/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 0.6592 - mean_absolute_error: 0.6634
# Epoch 14/100
# 1040/1040 [==============================] - 0s 228us/step - loss: 0.5972 - mean_absolute_error: 0.6287
# Epoch 15/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.5219 - mean_absolute_error: 0.5881
# Epoch 16/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.4649 - mean_absolute_error: 0.5476
# Epoch 17/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.4081 - mean_absolute_error: 0.5031
# Epoch 18/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 0.3526 - mean_absolute_error: 0.4553
# Epoch 19/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.3119 - mean_absolute_error: 0.4105
# Epoch 20/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.2691 - mean_absolute_error: 0.3625
# Epoch 21/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 0.2388 - mean_absolute_error: 0.3195
# Epoch 22/100
# 1040/1040 [==============================] - 0s 240us/step - loss: 0.2199 - mean_absolute_error: 0.2897
# Epoch 23/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.2024 - mean_absolute_error: 0.2657
# Epoch 24/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.1889 - mean_absolute_error: 0.2487
# Epoch 25/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.1774 - mean_absolute_error: 0.2356
# Epoch 26/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.1690 - mean_absolute_error: 0.2319
# Epoch 27/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 0.1615 - mean_absolute_error: 0.2289
# Epoch 28/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.1555 - mean_absolute_error: 0.2285
# Epoch 29/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.1488 - mean_absolute_error: 0.2255
# Epoch 30/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 0.1448 - mean_absolute_error: 0.2276
# Epoch 31/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 0.1388 - mean_absolute_error: 0.2238
# Epoch 32/100
# 1040/1040 [==============================] - 0s 235us/step - loss: 0.1350 - mean_absolute_error: 0.2251
# Epoch 33/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.1332 - mean_absolute_error: 0.2299
# Epoch 34/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.1263 - mean_absolute_error: 0.2219
# Epoch 35/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.1222 - mean_absolute_error: 0.2197
# Epoch 36/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 0.1197 - mean_absolute_error: 0.2223
# Epoch 37/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.1153 - mean_absolute_error: 0.2179
# Epoch 38/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 0.1128 - mean_absolute_error: 0.2196
# Epoch 39/100
# 1040/1040 [==============================] - 0s 242us/step - loss: 0.1068 - mean_absolute_error: 0.2123
# Epoch 40/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.1031 - mean_absolute_error: 0.2097
# Epoch 41/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.1019 - mean_absolute_error: 0.2109
# Epoch 42/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0999 - mean_absolute_error: 0.2122
# Epoch 43/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.0941 - mean_absolute_error: 0.2045
# Epoch 44/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0914 - mean_absolute_error: 0.2022
# Epoch 45/100
# 1040/1040 [==============================] - 0s 239us/step - loss: 0.0896 - mean_absolute_error: 0.2018
# Epoch 46/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0888 - mean_absolute_error: 0.2042
# Epoch 47/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0848 - mean_absolute_error: 0.1992
# Epoch 48/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.0845 - mean_absolute_error: 0.2018
# Epoch 49/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.0796 - mean_absolute_error: 0.1947
# Epoch 50/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.0757 - mean_absolute_error: 0.1905
# Epoch 51/100
# 1040/1040 [==============================] - 0s 257us/step - loss: 0.0730 - mean_absolute_error: 0.1882
# Epoch 52/100
# 1040/1040 [==============================] - 0s 240us/step - loss: 0.0728 - mean_absolute_error: 0.1885
# Epoch 53/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.0703 - mean_absolute_error: 0.1858
# Epoch 54/100
# 1040/1040 [==============================] - 0s 248us/step - loss: 0.0678 - mean_absolute_error: 0.1841
# Epoch 55/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 0.0644 - mean_absolute_error: 0.1782
# Epoch 56/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.0655 - mean_absolute_error: 0.1816
# Epoch 57/100
# 1040/1040 [==============================] - 0s 247us/step - loss: 0.0601 - mean_absolute_error: 0.1745
# Epoch 58/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0617 - mean_absolute_error: 0.1805
# Epoch 59/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0576 - mean_absolute_error: 0.1715
# Epoch 60/100
# 1040/1040 [==============================] - 0s 237us/step - loss: 0.0579 - mean_absolute_error: 0.1740
# Epoch 61/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 0.0566 - mean_absolute_error: 0.1745
# Epoch 62/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0546 - mean_absolute_error: 0.1692
# Epoch 63/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.0526 - mean_absolute_error: 0.1683
# Epoch 64/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 0.0533 - mean_absolute_error: 0.1684
# Epoch 65/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 0.0483 - mean_absolute_error: 0.1622
# Epoch 66/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.0485 - mean_absolute_error: 0.1626
# Epoch 67/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.0452 - mean_absolute_error: 0.1572
# Epoch 68/100
# 1040/1040 [==============================] - 0s 256us/step - loss: 0.0448 - mean_absolute_error: 0.1564
# Epoch 69/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0427 - mean_absolute_error: 0.1524
# Epoch 70/100
# 1040/1040 [==============================] - 0s 252us/step - loss: 0.0418 - mean_absolute_error: 0.1538
# Epoch 71/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0399 - mean_absolute_error: 0.1484
# Epoch 72/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.0394 - mean_absolute_error: 0.1474
# Epoch 73/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 0.0419 - mean_absolute_error: 0.1542
# Epoch 74/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.0361 - mean_absolute_error: 0.1417
# Epoch 75/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0387 - mean_absolute_error: 0.1475
# Epoch 76/100
# 1040/1040 [==============================] - 0s 253us/step - loss: 0.0370 - mean_absolute_error: 0.1437
# Epoch 77/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0360 - mean_absolute_error: 0.1443
# Epoch 78/100
# 1040/1040 [==============================] - 0s 256us/step - loss: 0.0371 - mean_absolute_error: 0.1431
# Epoch 79/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0338 - mean_absolute_error: 0.1401
# Epoch 80/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 0.0325 - mean_absolute_error: 0.1343
# Epoch 81/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.0308 - mean_absolute_error: 0.1320
# Epoch 82/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 0.0315 - mean_absolute_error: 0.1342
# Epoch 83/100
# 1040/1040 [==============================] - 0s 251us/step - loss: 0.0284 - mean_absolute_error: 0.1264
# Epoch 84/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0272 - mean_absolute_error: 0.1240
# Epoch 85/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0262 - mean_absolute_error: 0.1205
# Epoch 86/100
# 1040/1040 [==============================] - 0s 244us/step - loss: 0.0249 - mean_absolute_error: 0.1194
# Epoch 87/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 0.0236 - mean_absolute_error: 0.1140
# Epoch 88/100
# 1040/1040 [==============================] - 0s 241us/step - loss: 0.0229 - mean_absolute_error: 0.1127
# Epoch 89/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0217 - mean_absolute_error: 0.1103
# Epoch 90/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.0207 - mean_absolute_error: 0.1081
# Epoch 91/100
# 1040/1040 [==============================] - 0s 245us/step - loss: 0.0189 - mean_absolute_error: 0.1019
# Epoch 92/100
# 1040/1040 [==============================] - 0s 254us/step - loss: 0.0208 - mean_absolute_error: 0.1070
# Epoch 93/100
# 1040/1040 [==============================] - 0s 243us/step - loss: 0.0165 - mean_absolute_error: 0.0942
# Epoch 94/100
# 1040/1040 [==============================] - 0s 239us/step - loss: 0.0177 - mean_absolute_error: 0.0972
# Epoch 95/100
# 1040/1040 [==============================] - 0s 238us/step - loss: 0.0158 - mean_absolute_error: 0.0916
# Epoch 96/100
# 1040/1040 [==============================] - 0s 250us/step - loss: 0.0133 - mean_absolute_error: 0.0839
# Epoch 97/100
# 1040/1040 [==============================] - 0s 249us/step - loss: 0.0129 - mean_absolute_error: 0.0821
# Epoch 98/100
# 1040/1040 [==============================] - 0s 246us/step - loss: 0.0116 - mean_absolute_error: 0.0764
# Epoch 99/100
#  288/1040 [=======>......................] - ETA: 0s - loss: 0.0128 - mean_absolute_error: 0.0818

# %%
plt.figure()
plt.plot(history);
plt.xlabel('Epoch')
plt.ylabel('Loss')

r = int(len(history)/10)
plt.figure()
plt.plot(history[-r:]);
plt.xlabel('Epoch')
plt.ylabel('Loss')
print('%.3f percent improvement'%(100*(history[0] - history[-1])/history[0]))
# Out:
# 0.322 percent improvement

# %%
n = np.random.randint(0,len(X))
label = X_scaled[n].reshape(1,-1)
true = np.exp(t[n])
pred = np.exp(msc.inverse_transform(model.predict(label)))[0,:]
plt.plot(true,'k--',zorder=8)
plt.plot(pred,'r-')
plt.figure()
plt.plot(pred-true,'g-')

# %%
pixel = 2533
temp = 25000


ts = teffs[teffs == temp]
ls = loggs[teffs == temp]
labels = np.stack((ts,ls)).T
tflux = np.exp(t)[teffs == temp][:,pixel]

plt.scatter(ls,tflux,color='k')

linls = np.linspace(min(ls),max(ls),100)
lints = np.repeat(temp,100)
linlabels = np.stack((lints,linls)).T
lintflux = np.exp(msc.inverse_transform(model.predict(sc.transform(linlabels))))[:,pixel]
plt.plot(linls,lintflux)

# %%
n = 10
ls = np.linspace(8,8,n)
ts = np.linspace(6000,50000,n)
labels = np.stack((ts,ls)).T
preds = np.exp(msc.inverse_transform(model.predict(sc.transform(labels))))
for i in preds:
    plt.plot(i)

# %%
n = 10
ls = np.linspace(6.5,9.5,n)
ts = np.linspace(25000,25000,n)
labels = np.stack((ts,ls)).T
preds = np.exp(msc.inverse_transform(model.predict(sc.transform(labels))))
for i in preds:
    plt.plot(i)

# %%
def ch_cont(array):
    spec = array
    lamgrid = np.linspace(4000,8000,4000)
    p = np.polynomial.chebyshev.chebfit(lamgrid,spec,4)
    contcorr = spec / np.polynomial.chebyshev.chebval(lamgrid,p)
    plt.plot(contcorr)
    return contcorr

# %%
cpreds = [];
diffs = np.repeat(0,4000)
for i in range(len(preds)):
    cpreds.append(ch_cont(preds[i]))
cpreds = np.asarray(cpreds)

# %%
contbool = (np.ptp(cpreds,0) < 0.04)

# %%
plt.plot(lamgrid[contbool],preds[2][contbool],'r.')
