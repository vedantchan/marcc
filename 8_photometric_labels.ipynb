# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler
import multiprocessing
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get Data Spectra

# %%
wdtable = Table.read('wdtable_sn.fits')

good = (
    (wdtable['centre_beta'] < hbeta + 5)*
    (wdtable['centre_beta'] > hbeta - 5)*
    (wdtable['centre_alpha'] > halpha - 5)*
    (wdtable['centre_alpha'] < halpha + 5) * 
    (~np.isnan(wdtable['loggH']))*
    (~np.isnan(wdtable['TeffH']))*
    (wdtable['TeffH'] > 13000) * 
    (wdtable['TeffH'] < 80000) * 
    (wdtable['subclass'] == 'WD')[:,0].data*
    (wdtable['S2N'] > 2.5)
)
notgoodtable = wdtable[~good]
wdtable = wdtable[good]
len(wdtable)
# Out:
# 1188

# %%
plt.scatter(wdtable['TeffH'],wdtable['loggH'])
plt.axhline(6.5)
plt.axhline(9.5)
plt.axvline(13000)
plt.axvline(50000)

# %%
TeffHs = [];
loggHs = [];
specnames = []
spectra = [];

def rvcorr(spectrum):
    lamgrid = np.arange(4000,8000)
    coremask = (lamgrid == 6565)+(lamgrid == 4863)+(lamgrid == 4342)+(lamgrid == 4103)
    coremask = coremask.astype(int)
    trans = np.argmax(np.correlate(1-spectrum,coremask,mode='full'))-4000
    if trans > 5:
        trans = 5;
    elif trans < 5:
        trans = -5;
    else:
        ;
    shiftedspec = interpolation.shift(spectrum,-trans,cval=1)
    return shiftedspec

searchparameter = list(wdtable['specnames'])
bprps = [];
gs = [];
## Enter search parameter, if needed:
inputPath = "../scratch/spec/"

if os.path.exists(inputPath+".DS_Store"):
    os.remove(inputPath+"/.DS_Store")
    
filenames = [i+'.fits' for i in searchparameter]

from scipy.signal import medfilt
from scipy.interpolate import interp1d

len(filenames)

for specname in tqdm(filenames):
    f = fits.open(inputPath+specname)
    loglam = f[1].data['loglam']
    flux = f[1].data['flux']
    lam = 10**loglam
    lam = lam.astype(np.float64)
    flux = flux.astype(np.float64)
    lamgrid = np.arange(4000,8000)
    func = interp1d(lam,flux,kind='cubic',assume_sorted = False,fill_value='extrapolate')
    flux = func(lamgrid)
    spectra.append(flux)
    TeffHs.append(wdtable[wdtable['specnames']==specname[:-5]]['TeffH'][0])
    loggHs.append(wdtable[wdtable['specnames']==specname[:-5]]['loggH'][0])
    bprps.append(wdtable[wdtable['specnames']==specname[:-5]]['bp_rp'][0])
    gs.append(wdtable[wdtable['specnames']==specname[:-5]]['abs_g'][0])
    specnames.append(specname)
spectra = np.asarray(spectra)
TeffHs = np.asarray(TeffHs)
loggHs = np.asarray(loggHs)
bprps = np.asarray(bprps)
gs = np.asarray(gs)
# Out:
# 100%|██████████| 1188/1188 [04:14<00:00,  3.88it/s]

# %%
lam = np.arange(4000,8000)
lamgrid = lam
lines = ((lam > hbeta-300) & (lam < hbeta + 300)) | ((lam > halpha-400) & (lam < halpha + 400))\
        | ((lam > hgamma-400) & (lam < hgamma + 200))

mask = ~lines | ((lam > 4010) & (lam < 4050)) | ((lam > 4190) & (lam < 4230))
def quadratic(array,c1,c2,c3,c4):
    return c1 + c2*array + c3*array**2 + c4*array**3

# %%
normspec = [];

for i in tqdm(range(len(spectra))):
    p,cov = curve_fit(quadratic,lamgrid[mask],spectra[i][mask],p0=[-25,1e-2,1e-5,1e-10])
    contcorr = (spectra[i]/quadratic(lam,p[0],p[1],p[2],p[3]))
    skylinemask = (lamgrid > 5578.5 - 10)*(lamgrid < 5578.5 + 10) + (lamgrid > 5894.6 - 10)*(lamgrid < 5894.6 + 10)\
        + (lamgrid > 6301.7 - 10)*(lamgrid < 6301.7 + 10) + (lamgrid > 7246.0 - 10)*(lamgrid < 7246.0 + 10)
    contcorr[skylinemask] = 1
    #contcorr = rvcorr(contcorr)
    normspec.append(contcorr[0:3000])
normspec = np.asarray(normspec)
len(normspec)
# Out:
# 100%|██████████| 1188/1188 [00:03<00:00, 341.80it/s]
# 1188

# %% [markdown]
# # Train Generator

# %%
sc = StandardScaler()

X = sc.fit_transform(np.stack((bprps,gs)).transpose())
t = normspec
X_train,X_test,y_train,y_test = train_test_split(X,t,test_size=0.1,random_state=13)

# %%
#import keras
def generator():
    x = Input(shape=X[0].shape)
    y = Dense(10,activation='sigmoid')(x)
    y = Dropout(0.5)(y)
    y = Dense(10,activation='sigmoid')(y)
    y = Dropout(0.5)(y)
    out = Dense(3000,activation = 'linear')(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adam(lr=0.01), loss = 'mse', \
                  metrics = ['mean_absolute_percentage_error'])
    return model
model = generator()
print(model.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 16:33:30.804550 47119061607744 deprecation_wrapper.py:119] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 16:33:30.828663 47119061607744 deprecation_wrapper.py:119] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 16:33:30.831150 47119061607744 deprecation_wrapper.py:119] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 16:33:30.841634 47119061607744 deprecation_wrapper.py:119] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0731 16:33:30.847008 47119061607744 deprecation.py:506] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 16:33:30.899487 47119061607744 deprecation_wrapper.py:119] From /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3000)              33000
# =================================================================
# Total params: 33,140
# Trainable params: 33,140
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epoch = 1000
batch = len(X_train)

history = model.fit(X_train,y_train,epochs=epoch,verbose=1,batch_size=batch,validation_data = (X_test,y_test))
# Out:
# Train on 1069 samples, validate on 119 samples
# Epoch 1/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12610.3213 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2896
# Epoch 2/1000
# 1069/1069 [==============================] - 0s 32us/step - loss: 0.0038 - mean_absolute_percentage_error: 12665.2920 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2944
# Epoch 3/1000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0038 - mean_absolute_percentage_error: 12670.8760 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2958
# Epoch 4/1000
# 1069/1069 [==============================] - 0s 27us/step - loss: 0.0037 - mean_absolute_percentage_error: 12552.2363 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.
1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0038 - mean_absolute_percentage_error: 12620.8398 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2893
# Epoch 954/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12599.0166 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2869
# Epoch 955/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12585.0117 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2848
# Epoch 956/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12589.5361 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2831
# Epoch 957/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12558.6885 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2837
# Epoch 958/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12798.2217 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2879
# Epoch 959/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12646.1963 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2932
# Epoch 960/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0037 - mean_absolute_percentage_error: 12627.3447 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2973
# Epoch 961/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12644.5107 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3014
# Epoch 962/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12647.1641 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3037
# Epoch 963/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12604.6094 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3048
# Epoch 964/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12598.1045 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3047
# Epoch 965/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12619.5303 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3025
# Epoch 966/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0037 - mean_absolute_percentage_error: 12565.0439 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2969
# Epoch 967/1000
# 1069/1069 [==============================] - 0s 46us/step - loss: 0.0037 - mean_absolute_percentage_error: 12569.5664 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2909
# Epoch 968/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12607.7939 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2857
# Epoch 969/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12625.3809 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2811
# Epoch 970/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0037 - mean_absolute_percentage_error: 12660.6064 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2767
# Epoch 971/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12622.5312 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2755
# Epoch 972/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12536.3711 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2749
# Epoch 973/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12615.5508 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2786
# Epoch 974/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12578.1709 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2836
# Epoch 975/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12572.9795 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2909
# Epoch 976/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0038 - mean_absolute_percentage_error: 12653.7178 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2979
# Epoch 977/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0037 - mean_absolute_percentage_error: 12581.6338 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3027
# Epoch 978/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12547.2324 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3056
# Epoch 979/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12652.1006 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3053
# Epoch 980/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12607.5449 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.3019
# Epoch 981/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12636.8936 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2980
# Epoch 982/1000
# 1069/1069 [==============================] - 0s 46us/step - loss: 0.0038 - mean_absolute_percentage_error: 12653.5312 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2950
# Epoch 983/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0037 - mean_absolute_percentage_error: 12584.2012 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2936
# Epoch 984/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12587.1377 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2949
# Epoch 985/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12586.2969 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2969
# Epoch 986/1000
# 1069/1069 [==============================] - 0s 46us/step - loss: 0.0038 - mean_absolute_percentage_error: 12753.9717 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2989
# Epoch 987/1000
# 1069/1069 [==============================] - 0s 46us/step - loss: 0.0037 - mean_absolute_percentage_error: 12646.4658 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2976
# Epoch 988/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0037 - mean_absolute_percentage_error: 12540.2705 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2942
# Epoch 989/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0037 - mean_absolute_percentage_error: 12639.7344 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2929
# Epoch 990/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0038 - mean_absolute_percentage_error: 12592.4941 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2930
# Epoch 991/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12563.1055 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2938
# Epoch 992/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12626.0596 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2950
# Epoch 993/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0037 - mean_absolute_percentage_error: 12639.5000 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2961
# Epoch 994/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0037 - mean_absolute_percentage_error: 12645.2734 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2955
# Epoch 995/1000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.0038 - mean_absolute_percentage_error: 12649.8643 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2948
# Epoch 996/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12651.2588 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2946
# Epoch 997/1000
# 1069/1069 [==============================] - 0s 44us/step - loss: 0.0038 - mean_absolute_percentage_error: 12614.7754 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2944
# Epoch 998/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12613.2588 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2928
# Epoch 999/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0038 - mean_absolute_percentage_error: 12641.3545 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2934
# Epoch 1000/1000
# 1069/1069 [==============================] - 0s 45us/step - loss: 0.0037 - mean_absolute_percentage_error: 12567.2129 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 3.2948

# %%
plt.plot((history.history['loss']))
plt.plot((history.history['val_loss']))

# %% [markdown]
# ### Evaluate BP-RP Sensitivity

# %%
plt.figure(figsize=(7,5))
ts = np.linspace(min(bprps),max(bprps),10)
ls = np.linspace(np.mean(gs),np.mean(gs),10)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = model.predict(samples)
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(gens[i][750:1000],label='$BP-RP = %.2f$'%ts[i])
plt.legend(fontsize=10)
plt.title('H-Beta Line')
# Out:
# Text(0.5, 1.0, 'H-Beta Line')

# %% [markdown]
# ### Evaluate G_abs Sensitivity

# %%
plt.figure(figsize=(7,5))
ts = np.linspace(np.mean(bprps),np.mean(bprps),10)
ls = np.linspace(min(gs),max(gs),10)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = model.predict(samples)
for i in range(len(gens)):
    plt.plot(gens[i][750:1000],label='$G_{abs} = %.2f$'%ls[i])

plt.legend(fontsize=10)
plt.title('H-Beta Line')
# Out:
# Text(0.5, 1.0, 'H-Beta Line')

# %% [markdown]
# ### Evaluate Residuals of Random Control Spectra

# %%
resids = y_test - model.predict(X_test)
plt.figure(figsize=(15,10))
ct=0
for i in np.random.randint(0,len(resids),10):
    plt.plot(resids[i] + 0.3*ct,'k')
    plt.axhline(0.3*ct,color='r',linestyle='--')
    ct += 1
plt.title('Sample of Model Residuals')
# Out:
# Text(0.5, 1.0, 'Sample of Model Residuals')

# %%
def spectrum_sampler(wl,teff,logg,trans):
    label = sc.transform(np.asarray(np.stack((teff,logg)).reshape(1,-1)))
    return interpolation.shift(model.predict(label)[0],trans,cval=np.nan)

def chisquare(residual):
    return sum(residual**2)

# %%
lamgrid = np.arange(4000,7000)
fitter = lmfit.Model(spectrum_sampler)
params = fitter.make_params(teff = 20000.,logg=8.,trans=0.)
params['teff'].set(min=min(bprps),max=max(bprps))
params['logg'].set(min=min(gs),max=max(gs))
params['trans'].set(min=-10,max=10)

# %%
fitoutput = np.zeros((len(y_test),5))

for i in tqdm(range(len(y_test))):
    spec = y_test[i]
    fitoutput[i,0] = int(specnames[i][:-12])
    params['teff'].set(value=sc.inverse_transform(X_test)[i,0],vary=False)
    result = fitter.fit(spec[coremask],params,wl=lamgrid[coremask],method="powell",nan_policy='omit',calc_covar=True)
    fitoutput[i,1] = result.params['teff'].value
    fitoutput[i,2] = result.params['teff'].stderr
    fitoutput[i,3] = result.params['logg'].value
    fitoutput[i,4] = result.params['logg'].stderr
    
#     plt.figure(figsize=(7,5))
#     plt.plot(spec)
#     plt.plot(spectrum_sampler(None,result.params['teff'],result.params['logg'],result.params['trans']))
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-345d416d9afc> in <module>
# ----> 1 fitoutput = np.zeros((len(y_test),5))
#       2
#       3 for i in tqdm(range(len(y_test))):
#       4     spec = y_test[i]
#       5     fitoutput[i,0] = int(specnames[i][:-12])
#
# NameError: name 'np' is not defined

# %%
true_labels = sc.inverse_transform(X_test)

# %%
true = true_labels[:,0]
pred = fitoutput[:,1]
f=plt.scatter(true,pred)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')

plt.xlabel('Fusilio $T_{eff}$ (K)')
plt.ylabel('Predicted $T_{eff}$ (K)')
plt.title('Data-Driven Generator')
# Out:
# Text(0.5, 1.0, 'Data-Driven Generator')

# %%
true = true_labels[:,1]
pred = fitoutput[:,3]
f=plt.scatter(true,pred)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')

plt.xlabel('Fusilio $logg$ (dex)')
plt.ylabel('Predicted $logg$ (dex)')
plt.title('Data-Driven Generator')
# Out:
# Text(0.5, 1.0, 'Data-Driven Generator')

# %%
plt.plot(np.log(normspec[1]))
plt.plot(np.log(normspec[3]))
