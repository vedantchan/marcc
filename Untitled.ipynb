# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
from lmfit import Model,Minimizer
import corner

# %%
x = np.linspace(1, 10, 250)
np.random.seed(0)
y = 3.0 * np.exp(-x / 2) - 5.0 * np.exp(-(x - 0.1) / 10.) + 0.1 * np.random.randn(len(x))

# %%
p = lmfit.Parameters()
p.add_many(('a1', 4.), ('a2', 4.), ('t1', 3.), ('t2', 3., True))

def residual(p):
    v = p.valuesdict()
    return v['a1'] * np.exp(-x / v['t1']) + v['a2'] * np.exp(-(x - 0.1) / v['t2']) - y

# %%
mi = lmfit.minimize(residual, p, method='Nelder', nan_policy='omit')
mi.params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2))
# Out:
# /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: overflow encountered in multiply
# /home-4/vchandr8@jhu.edu/anaconda/lib/python3.7/site-packages/lmfit/minimizer.py:166: RuntimeWarning: overflow encountered in multiply
#   return (r*r).sum()

# %%
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', steps=1000,thin=30,burn=300,
                         params=mi.params, is_weighted=False)
# Out:
# Process ForkPoolWorker-18:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-87f28087591a> in <module>
#       1 res = lmfit.minimize(residual, method='emcee', nan_policy='omit', steps=1000,thin=30,burn=300,
# ----> 2                          params=mi.params, is_weighted=False,workers=2)
#
# ~/anaconda/lib/python3.7/site-packages/lmfit/minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2298                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2299                        calc_covar=calc_covar, **fit_kws)
# -> 2300     return fitter.minimize(method=method)
#
# ~/anaconda/lib/python3.7/site-packages/lmfit/minimizer.py in minimize(self, method, params, **kws)
#    1947                         val.lower().startswith(user_method)):
# ...

# %%
f = corner.corner(res.flatchain, labels=res.var_names, truths=list(res.params.valuesdict().values()))

# %%
fitter = Model(linear)
params = fitter.make_params(m = 1,b=1,f=1)

# %%
result = fitter.fit(y,params,x=x,method='emcee',steps = 1000, nwalkers = 100, burn = 300)
print(result.fit_report())
# Out:
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # fitting method   = emcee
#     # function evals   = 100000
#     # data points      = 250
#     # variables        = 3
#     chi-square         = 6034.72811
#     reduced chi-square = 24.4320976
#     Akaike info crit   = 801.956290
#     Bayesian info crit = 812.520673
# [[Variables]]
#     m: -25.7732360 +/- 0.58752981 (2.28%) (init = 1)
#     b:  54.9565120 +/- 0.03536477 (0.06%) (init = 1)
#     f:  4.99170267 +/- 0.00315698 (0.06%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b, f) =  0.980
#     C(m, f) = -0.773
#     C(m, b) = -0.767

# %%
plt.plot(x,y,'k.')
plt.plot(x,linear(x,result.params['m'] , result.params['b'] , result.params['f']),'r--')

# %%
fig = corner.corner(result.flatchain)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
# %%bash
#
# sqme
# Out:
# Fri Jul 26 21:25:32 2019
#               USER        JOBID PARTITION      NAME NODES  CPUS PRIORITY TIME_LIMIT     TIME        NODELIST ST REASON
#   vchandr8@jhu.edu     35613857 express    jupyter_     1     6    38549   12:00:00  5:08:06     compute0716 R None

# %%
from multiprocessing import Pool

# %%
def func(meh):
    sum(range(100000000))

# %%
with Pool(5) as pool:
    pool.map(func,np.arange(0,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1e5aed3c785f> in <module>
#       1 with Pool(5) as pool:
# ----> 2     pool.map(func,np.arange(0,10))
#
# NameError: name 'np' is not defined
