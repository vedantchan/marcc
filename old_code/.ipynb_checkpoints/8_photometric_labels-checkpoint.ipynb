# %%
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
np.seterr(divide='ignore', invalid='ignore');
plt.rcParams.update({'figure.max_open_warning': 0})
import scipy.stats as stats
import astropy.units as u
from astropy.table import Table, Column, MaskedColumn, join
from tqdm import tqdm
from bisect import bisect_left
c = 2.998e10
k = 1.38e-16
h = 6.626e-27
plt.rcParams.update({'font.size': 22})
halpha = 6564.61
hbeta = 4862.68
hgamma = 4341.68
hdelta = 4102.89
plt.rcParams['figure.figsize'] = [15, 10]
from IPython.display import Audio, display
def allDone():
    display(Audio(filename='beep.mp3', autoplay=True))
from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
import lmfit

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
import emcee
import corner
import numdifftools
from scipy.ndimage import interpolation
from scipy.signal import medfilt
from scipy.interpolate import interp1d
from multiprocessing import Pool
import pickle

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize,scale,MinMaxScaler,StandardScaler
import multiprocessing
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get Data Spectra

# %%
wdtable = Table.read('wdtable_sn.fits')

good = (
    (wdtable['centre_beta'] < hbeta + 5)*
    (wdtable['centre_beta'] > hbeta - 5)*
    (wdtable['centre_alpha'] > halpha - 5)*
    (wdtable['centre_alpha'] < halpha + 5) * 
    (~np.isnan(wdtable['loggH']))*
    (~np.isnan(wdtable['TeffH']))*
    (wdtable['TeffH'] > 13000) * 
    (wdtable['TeffH'] < 80000) * 
    (wdtable['subclass'] == 'WD')[:,0].data*
    (wdtable['S2N'] > 2.5)
)
notgoodtable = wdtable[~good]
wdtable = wdtable[good]
len(wdtable)
# Out:
# 1188

# %%
plt.scatter(wdtable['TeffH'],wdtable['loggH'])
plt.axhline(6.5)
plt.axhline(9.5)
plt.axvline(13000)
plt.axvline(50000)

# %%
TeffHs = [];
loggHs = [];
specnames = []
spectra = [];

def rvcorr(spectrum):
    lamgrid = np.arange(4000,8000)
    coremask = (lamgrid == 6565)+(lamgrid == 4863)+(lamgrid == 4342)+(lamgrid == 4103)
    coremask = coremask.astype(int)
    trans = np.argmax(np.correlate(1-spectrum,coremask,mode='full'))-4000
    if trans > 5:
        trans = 5;
    elif trans < 5:
        trans = -5;
    else:
        ;
    shiftedspec = interpolation.shift(spectrum,-trans,cval=1)
    return shiftedspec

searchparameter = list(wdtable['specnames'])
bprps = [];
gs = [];
## Enter search parameter, if needed:
inputPath = "../scratch/spec/"

if os.path.exists(inputPath+".DS_Store"):
    os.remove(inputPath+"/.DS_Store")
    
filenames = [i+'.fits' for i in searchparameter]

from scipy.signal import medfilt
from scipy.interpolate import interp1d

len(filenames)

for specname in tqdm(filenames):
    f = fits.open(inputPath+specname)
    loglam = f[1].data['loglam']
    flux = f[1].data['flux']
    lam = 10**loglam
    lam = lam.astype(np.float64)
    flux = flux.astype(np.float64)
    lamgrid = np.arange(4000,8000)
    func = interp1d(lam,flux,kind='cubic',assume_sorted = False,fill_value='extrapolate')
    flux = func(lamgrid)
    spectra.append(flux)
    TeffHs.append(wdtable[wdtable['specnames']==specname[:-5]]['TeffH'][0])
    loggHs.append(wdtable[wdtable['specnames']==specname[:-5]]['loggH'][0])
    bprps.append(wdtable[wdtable['specnames']==specname[:-5]]['bp_rp'][0])
    gs.append(wdtable[wdtable['specnames']==specname[:-5]]['abs_g'][0])
    specnames.append(specname)
spectra = np.asarray(spectra)
TeffHs = np.asarray(TeffHs)
loggHs = np.asarray(loggHs)
bprps = np.asarray(bprps)
gs = np.asarray(gs)
# Out:
# 100%|██████████| 1188/1188 [01:48<00:00, 10.90it/s]

# %%
lam = np.arange(4000,8000)
lamgrid = lam
lines = ((lam > hbeta-300) & (lam < hbeta + 300)) | ((lam > halpha-400) & (lam < halpha + 400))\
        | ((lam > hgamma-400) & (lam < hgamma + 200))

mask = ~lines | ((lam > 4010) & (lam < 4050)) | ((lam > 4190) & (lam < 4230))
def quadratic(array,c1,c2,c3,c4):
    return c1 + c2*array + c3*array**2 + c4*array**3

# %%
normspec = [];

for i in tqdm(range(len(spectra))):
    p,cov = curve_fit(quadratic,lamgrid[mask],spectra[i][mask],p0=[-25,1e-2,1e-5,1e-10])
    contcorr = (spectra[i]/quadratic(lam,p[0],p[1],p[2],p[3]))
    skylinemask = (lamgrid > 5578.5 - 10)*(lamgrid < 5578.5 + 10) + (lamgrid > 5894.6 - 10)*(lamgrid < 5894.6 + 10)\
        + (lamgrid > 6301.7 - 10)*(lamgrid < 6301.7 + 10) + (lamgrid > 7246.0 - 10)*(lamgrid < 7246.0 + 10)
    contcorr[skylinemask] = 1
    #contcorr = rvcorr(contcorr)
    normspec.append(contcorr[0:3000])
normspec = np.asarray(normspec)
len(normspec)
# Out:
# 100%|██████████| 1188/1188 [00:03<00:00, 383.73it/s]
# 1188

# %% [markdown]
# # Train Generator

# %%
sc = StandardScaler()

X = sc.fit_transform(np.stack((TeffHs,loggHs)).transpose())
t = normspec
X_train,X_test,y_train,y_test = train_test_split(X,t,test_size=0.1,random_state=13)

# %%
#import keras
def generator():
    x = Input(shape=X[0].shape)
    y = Dense(10,activation='sigmoid')(x)
    y = Dropout(0.5)(y)
    y = Dense(10,activation='sigmoid')(y)
    y = Dropout(0.5)(y)
    out = Dense(3000,activation = 'linear')(y)
    
    model = Model(inputs = x, outputs = out)
    model.compile(optimizer = Adam(lr=0.01), loss = 'mse', \
                  metrics = ['mean_absolute_percentage_error'])
    return model
model = generator()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                30
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                110
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 3000)              33000
# =================================================================
# Total params: 33,140
# Trainable params: 33,140
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epoch = 10000
batch = len(X_train)

history = model.fit(X_train,y_train,epochs=epoch,verbose=1,batch_size=batch,validation_data = (X_test,y_test))
# Out:
# Train on 1069 samples, validate on 119 samples
# Epoch 1/10000
# 1069/1069 [==============================] - 1s 538us/step - loss: 0.9441 - mean_absolute_percentage_error: 951.7368 - val_loss: 0.8642 - val_mean_absolute_percentage_error: 95.4581
# Epoch 2/10000
# 1069/1069 [==============================] - 0s 43us/step - loss: 0.8609 - mean_absolute_percentage_error: 725.9435 - val_loss: 0.7715 - val_mean_absolute_percentage_error: 90.0229
# Epoch 3/10000
# 1069/1069 [==============================] - 0s 38us/step - loss: 0.7721 - mean_absolute_percentage_error: 1287.5043 - val_loss: 0.6762 - val_mean_absolute_percentage_error: 84.0747
# Epoch 4/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.6767 - mean_absolute_percentage_error: 1777.6362 - val_loss: 0.5815 - val_mean_absolute_percentage_error: 77.7270
# Epoch 5/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.5816 - mean_absolute_percentage_error: 2121.6655 - val_loss: 0.4895 - val_mean_absolute_percentage_error: 71.0391
# Epoch 6/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.4917 - mean_absolute_percentage_error: 4237.2354 - val_loss: 0.4021 - val_mean_absolute_percentage_error: 64.0557
# Epoch 7/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.4121 - mean_absolute_percentage_error: 4356.2041 - val_loss: 0.3207 - val_mean_absolute_percentage_error: 56.8275
# Epoch 8/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.3286 - mean_absolute_percentage_error: 5649.8169 - val_loss: 0.2467 - val_mean_absolute_percentage_error: 49.4341
# Epoch 9/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.2691 - mean_absolute_percentage_error: 8529.7930 - val_loss: 0.1814 - val_mean_absolute_percentage_error: 41.9854
# Epoch 10/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.2041 - mean_absolute_percentage_error: 7071.5103 - val_loss: 0.1259 - val_mean_absolute_percentage_error: 34.6031
# Epoch 11/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1626 - mean_absolute_percentage_error: 5762.9473 - val_loss: 0.0810 - val_mean_absolute_percentage_error: 27.4242
# Epoch 12/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1259 - mean_absolute_percentage_error: 7583.4790 - val_loss: 0.0471 - val_mean_absolute_percentage_error: 20.6080
# Epoch 13/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.1035 - mean_absolute_percentage_error: 10553.7363 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 14.4157
# Epoch 14/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0946 - mean_absolute_percentage_error: 14085.6025 - val_loss: 0.0114 - val_mean_absolute_percentage_error: 9.4650
# Epoch 15/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0837 - mean_absolute_percentage_error: 10815.4688 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 7.2239
# Epoch 16/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0932 - mean_absolute_percentage_error: 14908.8662 - val_loss: 0.0092 - val_mean_absolute_percentage_error: 8.4141
# Epoch 17/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1007 - mean_absolute_percentage_error: 11408.1562 - val_loss: 0.0146 - val_mean_absolute_percentage_error: 11.3575
# Epoch 18/10000
# 1069/1069 [==============================] - 0s 31us/step - loss: 0.1024 - mean_absolute_percentage_error: 8616.2979 - val_loss: 0.0212 - val_mean_absolute_percentage_error: 14.2821
# Epoch 19/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.1273 - mean_absolute_percentage_error: 16657.2070 - val_loss: 0.0269 - val_mean_absolute_percentage_error: 16.3749
# Epoch 20/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1350 - mean_absolute_percentage_error: 19834.1621 - val_loss: 0.0301 - val_mean_absolute_percentage_error: 17.4049
# Epoch 21/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.1331 - mean_absolute_percentage_error: 10136.8975 - val_loss: 0.0306 - val_mean_absolute_percentage_error: 17.4998
# Epoch 22/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1335 - mean_absolute_percentage_error: 20804.5117 - val_loss: 0.0286 - val_mean_absolute_percentage_error: 16.8229
# Epoch 23/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1351 - mean_absolute_percentage_error: 17180.1641 - val_loss: 0.0248 - val_mean_absolute_percentage_error: 15.5265
# Epoch 24/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.1224 - mean_absolute_percentage_error: 7721.4219 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 13.7877
# Epoch 25/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1092 - mean_absolute_percentage_error: 15303.0879 - val_loss: 0.0151 - val_mean_absolute_percentage_error: 11.7690
# Epoch 26/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.1100 - mean_absolute_percentage_error: 15604.8760 - val_loss: 0.0107 - val_mean_absolute_percentage_error: 9.6297
# Epoch 27/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0955 - mean_absolute_percentage_error: 9630.1787 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 7.6319
# Epoch 28/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0961 - mean_absolute_percentage_error: 16564.2383 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 6.1584
# Epoch 29/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0837 - mean_absolute_percentage_error: 12010.8779 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 5.6994
# Epoch 30/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0703 - mean_absolute_percentage_error: 8819.4658 - val_loss: 0.0065 - val_mean_absolute_percentage_error: 6.3910
# Epoch 31/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0741 - mean_absolute_percentage_error: 10649.3857 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 7.9034
# Epoch 32/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0732 - mean_absolute_percentage_error: 8428.5820 - val_loss: 0.0122 - val_mean_absolute_percentage_error: 9.7496
# Epoch 33/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0667 - mean_absolute_percentage_error: 15103.3916 - val_loss: 0.0158 - val_mean_absolute_percentage_error: 11.5585
# Epoch 34/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0743 - mean_absolute_percentage_error: 9241.5146 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 13.1278
# Epoch 35/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0667 - mean_absolute_percentage_error: 9872.4688 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 14.3835
# Epoch 36/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0680 - mean_absolute_percentage_error: 10449.2744 - val_loss: 0.0252 - val_mean_absolute_percentage_error: 15.3400
# Epoch 37/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0735 - mean_absolute_percentage_error: 8718.0088 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 15.9902
# Epoch 38/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0735 - mean_absolute_percentage_error: 12511.8232 - val_loss: 0.0282 - val_mean_absolute_percentage_error: 16.3560
# Epoch 39/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0723 - mean_absolute_percentage_error: 6774.4854 - val_loss: 0.0284 - val_mean_absolute_percentage_error: 16.4277
# Epoch 40/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0764 - mean_absolute_percentage_error: 10805.7168 - val_loss: 0.0278 - val_mean_absolute_percentage_error: 16.2131
# Epoch 41/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0747 - mean_absolute_percentage_error: 12263.6289 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 15.7571
# Epoch 42/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0688 - mean_absolute_percentage_error: 7089.4624 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 15.0926
# Epoch 43/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0705 - mean_absolute_percentage_error: 14038.6807 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 14.2719
# Epoch 44/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0678 - mean_absolute_percentage_error: 12985.1709 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 13.3527
# Epoch 45/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0683 - mean_absolute_percentage_error: 18063.1855 - val_loss: 0.0171 - val_mean_absolute_percentage_error: 12.3737
# Epoch 46/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0693 - mean_absolute_percentage_error: 12571.3213 - val_loss: 0.0146 - val_mean_absolute_percentage_error: 11.3378
# Epoch 47/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0640 - mean_absolute_percentage_error: 12780.1436 - val_loss: 0.0124 - val_mean_absolute_percentage_error: 10.3268
# Epoch 48/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0659 - mean_absolute_percentage_error: 9952.2480 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 9.3266
# Epoch 49/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0616 - mean_absolute_percentage_error: 15546.2109 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 8.3883
# Epoch 50/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0574 - mean_absolute_percentage_error: 13014.9180 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 7.5878
# Epoch 51/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0622 - mean_absolute_percentage_error: 14843.9619 - val_loss: 0.0062 - val_mean_absolute_percentage_error: 6.9163
# Epoch 52/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0613 - mean_absolute_percentage_error: 8960.4170 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.3469
# Epoch 53/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0634 - mean_absolute_percentage_error: 12522.3740 - val_loss: 0.0048 - val_mean_absolute_percentage_error: 5.9036
# Epoch 54/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0649 - mean_absolute_percentage_error: 15216.6973 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 5.5729
# Epoch 55/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0646 - mean_absolute_percentage_error: 10217.3467 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 5.3503
# Epoch 56/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0606 - mean_absolute_percentage_error: 8181.6958 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 5.2056
# Epoch 57/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0628 - mean_absolute_percentage_error: 16188.0713 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 5.1333
# Epoch 58/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0564 - mean_absolute_percentage_error: 11721.1475 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 5.1279
# Epoch 59/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0584 - mean_absolute_percentage_error: 10042.7129 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 5.2014
# Epoch 60/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0551 - mean_absolute_percentage_error: 7651.6694 - val_loss: 0.0043 - val_mean_absolute_percentage_error: 5.3722
# Epoch 61/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0574 - mean_absolute_percentage_error: 12843.0762 - val_loss: 0.0046 - val_mean_absolute_percentage_error: 5.5813
# Epoch 62/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0593 - mean_absolute_percentage_error: 16637.1113 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 5.8850
# Epoch 63/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0571 - mean_absolute_percentage_error: 13718.4551 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2041
# Epoch 64/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0603 - mean_absolute_percentage_error: 11019.6416 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.5356
# Epoch 65/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0538 - mean_absolute_percentage_error: 15103.1787 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 6.8621
# Epoch 66/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0564 - mean_absolute_percentage_error: 10769.0996 - val_loss: 0.0068 - val_mean_absolute_percentage_error: 7.1474
# Epoch 67/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0531 - mean_absolute_percentage_error: 7715.8999 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 7.4269
# Epoch 68/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0528 - mean_absolute_percentage_error: 11354.6270 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 7.7101
# Epoch 69/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0581 - mean_absolute_percentage_error: 13474.5195 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 7.9261
# Epoch 70/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0540 - mean_absolute_percentage_error: 10562.2520 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 8.1196
# Epoch 71/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0501 - mean_absolute_percentage_error: 11289.4932 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 8.2446
# Epoch 72/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0555 - mean_absolute_percentage_error: 10793.6943 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 8.3071
# Epoch 73/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0520 - mean_absolute_percentage_error: 5645.5713 - val_loss: 0.0087 - val_mean_absolute_percentage_error: 8.3393
# Epoch 74/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0557 - mean_absolute_percentage_error: 7717.7861 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 8.3196
# Epoch 75/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0521 - mean_absolute_percentage_error: 11271.5059 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 8.2373
# Epoch 76/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0499 - mean_absolute_percentage_error: 9450.6270 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 8.1173
# Epoch 77/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0504 - mean_absolute_percentage_error: 10677.9297 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 7.9890
# Epoch 78/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0515 - mean_absolute_percentage_error: 10723.6895 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 7.8202
# Epoch 79/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0529 - mean_absolute_percentage_error: 12464.2285 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 7.6200
# Epoch 80/10000
# 1069/1069 [==============================] - 0s 33us/step - loss: 0.0543 - mean_absolute_percentage_error: 13105.7119 - val_loss: 0.0071 - val_mean_absolute_percentage_error: 7.4108
# Epoch 81/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0523 - mean_absolute_percentage_error: 11562.5586 - val_loss: 0.0067 - val_mean_absolute_percentage_error: 7.1884
# Epoch 82/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0538 - mean_absolute_percentage_error: 10993.1426 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 7.0130
# Epoch 83/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0509 - mean_absolute_percentage_error: 11170.2520 - val_loss: 0.0062 - val_mean_absolute_percentage_error: 6.8733
# Epoch 84/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0499 - mean_absolute_percentage_error: 8928.2051 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 6.7241
# Epoch 85/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0507 - mean_absolute_percentage_error: 6973.2974 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 6.5962
# Epoch 86/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0482 - mean_absolute_percentage_error: 11278.3252 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 6.5064
# Epoch 87/10000
# 1069/1069 [==============================] - 0s 31us/step - loss: 0.0481 - mean_absolute_percentage_error: 11937.2012 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 6.4519
# Epoch 88/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0485 - mean_absolute_percentage_error: 9352.0703 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 6.3949
# Epoch 89/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0485 - mean_absolute_percentage_error: 12040.2520 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 6.3494
# Epoch 90/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0473 - mean_absolute_percentage_error: 11318.0586 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 6.3268
# Epoch 91/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0485 - mean_absolute_percentage_error: 13071.9229 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2854
# Epoch 92/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0489 - mean_absolute_percentage_error: 12955.1865 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2437
# Epoch 93/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0426 - mean_absolute_percentage_error: 11478.5830 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 6.2167
# Epoch 94/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0429 - mean_absolute_percentage_error: 11328.7441 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2297
# Epoch 95/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0477 - mean_absolute_percentage_error: 12213.7861 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2548
# Epoch 96/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0442 - mean_absolute_percentage_error: 11041.0596 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 6.3047
# Epoch 97/10000
# 1069/1069 [==============================] - 0s 31us/step - loss: 0.0453 - mean_absolute_percentage_error: 12483.4580 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 6.3637
# Epoch 98/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0434 - mean_absolute_percentage_error: 8826.5137 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 6.4105
# Epoch 99/10000
# 1069/1069 [==============================] - 0s 32us/step - loss: 0.0439 - mean_absolute_percentage_error: 14001.2676 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 6.4642
# Epoch 100/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0422 - mean_absolute_percentage_error: 9587.7012 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 6.5206
# Epoch 101/10000
# 1069/1069 [==============================] - 0s 30us/step - loss: 0.0433 - mean_absolute_percentage_error: 7817.0962 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.5744
# Epoch 102/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0417 - mean_absolute_percentage_error: 10958.6348 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.6240
# Epoch 103/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0429 - mean_absolute_percentage_error: 7906.9521 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.6375
# Epoch 104/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0432 - mean_absolute_percentage_error: 12177.3779 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 6.6528
# Epoch 105/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0424 - mean_absolute_percentage_error: 9689.8203 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 6.6541
# Epoch 106/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0424 - mean_absolute_percentage_error: 12795.4414 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.6338
# Epoch 107/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0460 - mean_absolute_percentage_error: 11787.8916 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 6.6018
# Epoch 108/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0418 - mean_absolute_percentage_error: 11987.7422 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 6.5444
# Epoch 109/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0401 - mean_absolute_percentage_error: 14347.5703 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 6.4805
# Epoch 110/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0417 - mean_absolute_percentage_error: 9292.4023 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 6.4210
# Epoch 111/10000
# 1069/1069 [==============================] - 0s 28us/step - loss: 0.0420 - mean_absolute_percentage_error: 12727.8594 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 6.3657
# Epoch 112/10000
# 1069/1069 [==============================] - 0s 29us/step - loss: 0.0406 - mean_absolute_percentage_error: 12101.6895 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 6.2912
# Epoch 113/10000

# %%
plt.plot((history.history['loss']))
plt.plot((history.history['val_loss']))

# %% [markdown]
# ### Evaluate TeFF Sensitivity

# %%
plt.figure(figsize=(7,5))
ts = np.linspace(5000,35000,10)
ls = np.linspace(8,8,10)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = model.predict(samples)
tscores = (ts - np.min(ts))/(np.max(ts) - np.min(ts))
for i in range(len(gens)):
    plt.plot(gens[i][750:1000],label='$T_{eff} = %i$ K'%ts[i])
plt.legend(fontsize=10)
plt.title('H-Beta Line')
# Out:
# Text(0.5, 1.0, 'H-Beta Line')

# %% [markdown]
# ### Evaluate logg Sensitivity

# %%
plt.figure(figsize=(7,5))
ts = np.linspace(15000,15000,10)
ls = np.linspace(6.5,9.5,10)
samples = sc.transform(np.stack((ts,ls)).transpose())
gens = model.predict(samples)
for i in range(len(gens)):
    plt.plot(gens[i][750:1000],label='$\log{g} = %.2f$ dex'%ls[i])

plt.legend(fontsize=10)
plt.title('H-Beta Line')
# Out:
# Text(0.5, 1.0, 'H-Beta Line')

# %% [markdown]
# ### Evaluate Residuals of Random Control Spectra

# %%
resids = y_test - model.predict(X_test)
plt.figure(figsize=(15,10))
ct=0
for i in np.random.randint(0,len(resids),10):
    plt.plot(resids[i] + 0.3*ct,'k')
    plt.axhline(0.3*ct,color='r',linestyle='--')
    ct += 1
plt.title('Sample of Model Residuals')
# Out:
# Text(0.5, 1.0, 'Sample of Model Residuals')

# %%
def spectrum_sampler(wl,teff,logg,trans):
    label = sc.transform(np.asarray(np.stack((teff,logg)).reshape(1,-1)))
    return interpolation.shift(model.predict(label)[0],trans,cval=np.nan)

def chisquare(residual):
    return sum(residual**2)

# %%
lamgrid = np.arange(4000,7000)
fitter = lmfit.Model(spectrum_sampler)
params = fitter.make_params(teff = 20000.,logg=8.,trans=0.)
params['teff'].set(min=13000,max=80000)
params['logg'].set(min=6.5,max=9.5)
params['trans'].set(min=-10,max=10)

# %%
clines = 5*lines[0:3000].astype(int)+1

# %%
fitoutput = np.zeros((len(y_test),5))

for i in tqdm(range(len(y_test))):
    spec = y_test[i]
    fitoutput[i,0] = int(specnames[i][:-12])
    params['teff'].set(value=sc.inverse_transform(X_test)[i,0],vary=False)
    result = fitter.fit(spec,params,wl=lamgrid,weights = clines,method="powell",nan_policy='omit',calc_covar=True)
    fitoutput[i,1] = result.params['teff'].value
    fitoutput[i,2] = result.params['teff'].stderr
    fitoutput[i,3] = result.params['logg'].value
    fitoutput[i,4] = result.params['logg'].stderr
    
#     plt.figure(figsize=(7,5))
#     plt.plot(spec)
#     plt.plot(spectrum_sampler(None,result.params['teff'],result.params['logg'],result.params['trans']))
#     plt.show()
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]
#
#
#
#
#   1%|          | 1/119 [00:00<00:26,  4.48it/s]
#
#
#
#
#   2%|▏         | 2/119 [00:00<00:25,  4.58it/s]
#
#
#
#
#   3%|▎         | 3/119 [00:00<00:24,  4.83it/s]
#
#
#
#
#   3%|▎         | 4/119 [00:00<00:23,  4.97it/s]
#
#
#
#
#   4%|▍         | 5/119 [00:00<00:22,  5.13it/s]
#
#
#
#
#   5%|▌         | 6/119 [00:01<00:21,  5.15it/s]
#
#
#
#
#   6%|▌         | 7/119 [00:01<00:21,  5.22it/s]
#
#
#
#
#   7%|▋         | 8/119 [00:01<00:23,  4.66it/s]
#
#
#
#
#   8%|▊         | 9/119 [00:01<00:22,  4.86it/s]
#
#
#
#
#   8%|▊         | 10/119 [00:01<00:21,  5.01it/s]
#
#
#
#
#   9%|▉         | 11/119 [00:02<00:21,  5.06it/s]
#
#
#
#
#  10%|█         | 12/119 [00:02<00:22,  4.84it/s]
#
#
#
#
#  11%|█         | 13/119 [00:02<00:21,  4.93it/s]
#
#
#
#
#  12%|█▏        | 14/119 [00:02<00:21,  4.94it/s]
#
#
#
#
#  13%|█▎        | 15/119 [00:03<00:20,  5.02it/s]
#
#
#
#
#  13%|█▎        | 16/119 [00:03<00:21,  4.90it/s]
#
#
#
#
#  14%|█▍        | 17/119 [00:03<00:20,  4.98it/s]
#
#
#
#
#  15%|█▌        | 18/119 [00:03<00:20,  4.90it/s]
#
#
#
#
#  16%|█▌        | 19/119 [00:03<00:19,  5.03it/s]
#
#
#
#
#  17%|█▋        | 20/119 [00:04<00:19,  5.02it/s]
#
#
#
#
#  18%|█▊        | 21/119 [00:04<00:19,  5.11it/s]
#
#
#
#
#  18%|█▊        | 22/119 [00:04<00:19,  5.05it/s]
#
#
#
#
#  19%|█▉        | 23/119 [00:04<00:19,  5.05it/s]
#
#
#
#
#  20%|██        | 24/119 [00:04<00:18,  5.12it/s]
#
#
#
#
#  21%|██        | 25/119 [00:05<00:19,  4.72it/s]
#
#
#
#
#  22%|██▏       | 26/119 [00:05<00:19,  4.86it/s]
#
#
#
#
#  23%|██▎       | 27/119 [00:05<00:19,  4.64it/s]
#
#
#
#
#  24%|██▎       | 28/119 [00:05<00:21,  4.15it/s]
#
#
#
#
#  24%|██▍       | 29/119 [00:05<00:20,  4.47it/s]
#
#
#
#
#  25%|██▌       | 30/119 [00:06<00:19,  4.50it/s]
#
#
#
#
#  26%|██▌       | 31/119 [00:06<00:18,  4.72it/s]
#
#
#
#
#  27%|██▋       | 32/119 [00:06<00:17,  4.89it/s]
#
#
#
#
#  28%|██▊       | 33/119 [00:06<00:17,  4.95it/s]
#
#
#
#
#  29%|██▊       | 34/119 [00:06<00:16,  5.04it/s]
#
#
#
#
#  29%|██▉       | 35/119 [00:07<00:16,  5.08it/s]
#
#
#
#
#  30%|███       | 36/119 [00:07<00:15,  5.23it/s]
#
#
#
#
#  31%|███       | 37/119 [00:07<00:15,  5.18it/s]
#
#
#
#
#  32%|███▏      | 38/119 [00:07<00:15,  5.25it/s]
#
#
#
#
#  33%|███▎      | 39/119 [00:07<00:15,  5.29it/s]
#
#
#
#
#  34%|███▎      | 40/119 [00:08<00:14,  5.31it/s]
#
#
#
#
#  34%|███▍      | 41/119 [00:08<00:14,  5.36it/s]
#
#
#
#
#  35%|███▌      | 42/119 [00:08<00:14,  5.42it/s]
#
#
#
#
#  36%|███▌      | 43/119 [00:08<00:14,  5.33it/s]
#
#
#
#
#  37%|███▋      | 44/119 [00:08<00:14,  5.24it/s]
#
#
#
#
#  38%|███▊      | 45/119 [00:08<00:13,  5.32it/s]
#
#
#
#
#  39%|███▊      | 46/119 [00:09<00:13,  5.34it/s]
#
#
#
#
#  39%|███▉      | 47/119 [00:09<00:13,  5.35it/s]
#
#
#
#
#  40%|████      | 48/119 [00:09<00:13,  5.39it/s]
#
#
#
#
#  41%|████      | 49/119 [00:09<00:13,  5.13it/s]
#
#
#
#
#  42%|████▏     | 50/119 [00:09<00:13,  5.21it/s]
#
#
#
#
#  43%|████▎     | 51/119 [00:10<00:12,  5.31it/s]
#
#
#
#
#  44%|████▎     | 52/119 [00:10<00:12,  5.22it/s]
#
#
#
#
#  45%|████▍     | 53/119 [00:10<00:12,  5.28it/s]
#
#
#
#
#  45%|████▌     | 54/119 [00:10<00:12,  5.34it/s]
#
#
#
#
#  46%|████▌     | 55/119 [00:10<00:12,  5.10it/s]
#
#
#
#
#  47%|████▋     | 56/119 [00:11<00:12,  5.13it/s]
#
#
#
#
#  48%|████▊     | 57/119 [00:11<00:12,  5.05it/s]
#
#
#
#
#  49%|████▊     | 58/119 [00:11<00:11,  5.17it/s]
#
#
#
#
#  50%|████▉     | 59/119 [00:11<00:11,  5.17it/s]
#
#
#
#
#  50%|█████     | 60/119 [00:11<00:11,  5.31it/s]
#
#
#
#
#  51%|█████▏    | 61/119 [00:12<00:11,  5.12it/s]
#
#
#
#
#  52%|█████▏    | 62/119 [00:12<00:11,  5.16it/s]
#
#
#
#
#  53%|█████▎    | 63/119 [00:12<00:11,  5.07it/s]
#
#
#
#
#  54%|█████▍    | 64/119 [00:12<00:10,  5.17it/s]
#
#
#
#
#  55%|█████▍    | 65/119 [00:12<00:10,  4.96it/s]
#
#
#
#
#  55%|█████▌    | 66/119 [00:13<00:10,  4.85it/s]
#
#
#
#
#  56%|█████▋    | 67/119 [00:13<00:10,  4.96it/s]
#
#
#
#
#  57%|█████▋    | 68/119 [00:13<00:10,  4.95it/s]
#
#
#
#
#  58%|█████▊    | 69/119 [00:13<00:09,  5.15it/s]
#
#
#
#
#  59%|█████▉    | 70/119 [00:13<00:09,  5.00it/s]
#
#
#
#
#  60%|█████▉    | 71/119 [00:14<00:09,  5.09it/s]
#
#
#
#
#  61%|██████    | 72/119 [00:14<00:09,  5.03it/s]
#
#
#
#
#  61%|██████▏   | 73/119 [00:14<00:08,  5.19it/s]
#
#
#
#
#  62%|██████▏   | 74/119 [00:14<00:08,  5.15it/s]
#
#
#
#
#  63%|██████▎   | 75/119 [00:14<00:08,  5.13it/s]
#
#
#
#
#  64%|██████▍   | 76/119 [00:15<00:08,  5.28it/s]
#
#
#
#
#  65%|██████▍   | 77/119 [00:15<00:07,  5.27it/s]
#
#
#
#
#  66%|██████▌   | 78/119 [00:15<00:07,  5.14it/s]
#
#
#
#
#  66%|██████▋   | 79/119 [00:15<00:08,  4.85it/s]
#
#
#
#
#  67%|██████▋   | 80/119 [00:15<00:08,  4.86it/s]
#
#
#
#
#  68%|██████▊   | 81/119 [00:16<00:07,  4.91it/s]
#
#
#
#
#  69%|██████▉   | 82/119 [00:16<00:07,  4.98it/s]
#
#
#
#
#  70%|██████▉   | 83/119 [00:16<00:07,  5.13it/s]
#
#
#
#
#  71%|███████   | 84/119 [00:16<00:06,  5.23it/s]
#
#
#
#
#  71%|███████▏  | 85/119 [00:16<00:06,  5.23it/s]
#
#
#
#
#  72%|███████▏  | 86/119 [00:17<00:06,  5.11it/s]
#
#
#
#
#  73%|███████▎  | 87/119 [00:17<00:06,  5.21it/s]
#
#
#
#
#  74%|███████▍  | 88/119 [00:17<00:06,  5.11it/s]
#
#
#
#
#  75%|███████▍  | 89/119 [00:17<00:05,  5.10it/s]
#
#
#
#
#  76%|███████▌  | 90/119 [00:17<00:05,  5.10it/s]
#
#
#
#
#  76%|███████▋  | 91/119 [00:17<00:05,  5.13it/s]
#
#
#
#
#  77%|███████▋  | 92/119 [00:18<00:05,  5.19it/s]
#
#
#
#
#  78%|███████▊  | 93/119 [00:18<00:04,  5.21it/s]
#
#
#
#
#  79%|███████▉  | 94/119 [00:18<00:04,  5.06it/s]
#
#
#
#
#  80%|███████▉  | 95/119 [00:18<00:04,  4.94it/s]
#
#
#
#
#  81%|████████  | 96/119 [00:18<00:04,  4.90it/s]
#
#
#
#
#  82%|████████▏ | 97/119 [00:19<00:04,  5.02it/s]
#
#
#
#
#  82%|████████▏ | 98/119 [00:19<00:04,  5.12it/s]
#
#
#
#
#  83%|████████▎ | 99/119 [00:19<00:03,  5.24it/s]
#
#
#
#
#  84%|████████▍ | 100/119 [00:19<00:03,  5.26it/s]
#
#
#
#
#  85%|████████▍ | 101/119 [00:19<00:03,  5.21it/s]
#
#
#
#
#  86%|████████▌ | 102/119 [00:20<00:03,  5.29it/s]
#
#
#
#
#  87%|████████▋ | 103/119 [00:20<00:03,  5.30it/s]
#
#
#
#
#  87%|████████▋ | 104/119 [00:20<00:02,  5.20it/s]
#
#
#
#
#  88%|████████▊ | 105/119 [00:20<00:02,  4.95it/s]
#
#
#
#
#  89%|████████▉ | 106/119 [00:20<00:02,  5.12it/s]
#
#
#
#
#  90%|████████▉ | 107/119 [00:21<00:02,  5.13it/s]
#
#
#
#
#  91%|█████████ | 108/119 [00:21<00:02,  5.00it/s]
#
#
#
#
#  92%|█████████▏| 109/119 [00:21<00:01,  5.07it/s]
#
#
#
#
#  92%|█████████▏| 110/119 [00:21<00:01,  4.99it/s]
#
#
#
#
#  93%|█████████▎| 111/119 [00:21<00:01,  4.88it/s]
#
#
#
#
#  94%|█████████▍| 112/119 [00:22<00:01,  4.98it/s]
#
#
#
#
#  95%|█████████▍| 113/119 [00:22<00:01,  5.06it/s]
#
#
#
#
#  96%|█████████▌| 114/119 [00:22<00:00,  5.07it/s]
#
#
#
#
#  97%|█████████▋| 115/119 [00:22<00:00,  5.08it/s]
#
#
#
#
#  97%|█████████▋| 116/119 [00:22<00:00,  4.96it/s]
#
#
#
#
#  98%|█████████▊| 117/119 [00:23<00:00,  5.07it/s]
#
#
#
#
#  99%|█████████▉| 118/119 [00:23<00:00,  5.20it/s]
#
#
#
#
# 100%|██████████| 119/119 [00:23<00:00,  5.04it/s]

# %%
true_labels = sc.inverse_transform(X_test)

# %%
true = true_labels[:,0]
pred = fitoutput[:,1]
f=plt.scatter(true,pred)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')

plt.xlabel('Fusilio $T_{eff}$ (K)')
plt.ylabel('Predicted $T_{eff}$ (K)')
plt.title('Data-Driven Generator')
# Out:
# Text(0.5, 1.0, 'Data-Driven Generator')

# %%
true = true_labels[:,1]
pred = fitoutput[:,3]
f=plt.scatter(true,pred)
x = np.linspace(f.axes.get_xlim()[0],f.axes.get_xlim()[1],1000)
y = x
plt.plot(x,y,'r--')

plt.xlabel('Fusilio $logg$ (dex)')
plt.ylabel('Predicted $logg$ (dex)')
plt.title('Data-Driven Generator')
# Out:
# Text(0.5, 1.0, 'Data-Driven Generator')
